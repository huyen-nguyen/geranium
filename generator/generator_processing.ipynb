# %%
import os

files = [f for f in os.listdir('../data/unified/specs') if not f.endswith('.json')]
files
# Out:
# ['.DS_Store']

# %%
import os
import glob

def count_files_with_extension(directory, extension):
    # Construct the search pattern with the specified extension
    search_pattern = os.path.join(directory, f'*.{extension}')
    
    # Use glob to find all files that match the pattern, and return their count
    files = glob.glob(search_pattern)
    return len(files)

# Example usage
directory = '../data/unified/will_trash'
extension = 'png'  # for example, find all .txt files
num_files = count_files_with_extension(directory, extension)

print(f"Number of files with .{extension} extension: {num_files}")
# Out:
# Number of files with .png extension: 9

# %%
import os
import json

def find_nested_field(data, field_name, field_value):
    """
    Recursively searches for a field_name with the field_value in nested JSON data.
    """
    if isinstance(data, dict):
        for key, value in data.items():
            if key == field_name and value == field_value:
                return True
            elif isinstance(value, (dict, list)):
                if find_nested_field(value, field_name, field_value):
                    return True
    elif isinstance(data, list):
        for item in data:
            if find_nested_field(item, field_name, field_value):
                return True
    return False

def list_json_files_with_nested_field(directory, field_name, field_value):
    matching_files = []
    
    # Loop over all files in the specified directory
    for filename in os.listdir(directory):
        if filename.endswith('.json'):
            # Construct the full path to the file
            file_path = os.path.join(directory, filename)

            try:
                # Open and parse the JSON file
                with open(file_path, 'r', encoding='utf-8') as file:
                    data = json.load(file)
                    
                    # Check if the nested field and value exist in the JSON data
                    if find_nested_field(data, field_name, field_value):
                        matching_files.append(filename)

            except (json.JSONDecodeError, IOError) as e:
                print(f"Error reading {filename}: {e}")

    return matching_files

# Example usage
directory = '../data/unified/specs'
field_name = 'type'
field_value = 'vcf'
matching_json_files = list_json_files_with_nested_field(directory, field_name, field_value)

print("Files with the specified nested field:")
for filename in matching_json_files:
    print(filename)
print(len(matching_json_files))
# Out:
# Files with the specified nested field:
# PBCA-DE-2009e5e7-1796-445b-8677-46b3804fe0bf.json
# BOCA-UK-f86e2d80-911b-7a19-e040-11ac0d486900.json
# PBCA-DE-0609b182-0396-4755-b463-10f949c5b8bb.json
# BTCA-SG-4ef20a13-f107-4654-adca-fc60b8f5be47.json
# BRCA-US-25c76a8f-77c0-4650-bddf-45ed0c10a2e6.json
# BRCA-UK-f393bafe-7503-5c45-e040-11ac0d484511.json
# BOCA-UK-f87d7c27-eeef-920e-e040-11ac0d48388d.json
# PBCA-DE-18f9240e-7acd-41eb-a154-c2a67a1cbe9b.json
# PBCA-DE-6d3d5531-16b4-46ec-bd7e-394946855d62.json
# PBCA-DE-aa4bf69c-a1a6-48dc-96fc-3fe7d2680517.json
# PBCA-DE-b16780b0-75ba-4304-87e0-33f1e321b622.json
# BRCA-EU-fc8130df-897d-5404-e040-11ac0d485e0a.json
# VCF_INDELS_sw_1_0_s_0_7_cc_2.json
# LIRI-JP-bcc74a5e-c622-11e3-bf01-24c6515278c0.json
# BRCA-UK-fc447d51-cdc2-a180-e040-11ac0c4846a4.json
# BRCA-EU-fc8130df-3225-3f96-e040-11ac0d485dfe.json
# VCF_INDELS_sw_0_7_s_1_2_oc.json
# BRCA-US-fc6d77a9-121b-48ab-a899-713c3d1319a2.json
# BRCA-EU-fc8130e0-ad66-b82e-e040-11ac0d485e0e.json
# GBM-US-2c71d542-1653-4d97-8752-f2fd05c7e75d.json
# GBM-US-08ac57ec-0036-4134-a9bb-f22eaa27ab0d.json
# BRCA-UK-fc7f8eeb-9c40-123e-e040-11ac0c484061.json
# GBM-US-7163a0f7-2c69-40b8-8857-8ab3f46f0acf.json
# VCF_INDELS_sw_0_7_s_1_0_cc_0.json
# GBM-US-ece0f3a4-a204-4c52-bb1f-88d44a875b2e.json
# BTCA-SG-bb65d670-0411-4fc5-a6cb-019caec1ab36.json
# BRCA-US-73936e8b-c893-4afd-bd1f-be90c06a4869.json
# PBCA-DE-32a63b4f-3baa-4987-ad30-5bd0c0548088.json
# BRCA-EU-f7e7d61f-e2dc-b523-e040-11ac0c482000.json
# BRCA-EU-fc8130e0-0dcf-b558-e040-11ac0c483285.json
# VCF_INDELS_sw_1_2_s_0_7_cc_0.json
# BRCA-UK-fc93b9ab-760a-5223-e040-11ac0c482177.json
# PBCA-DE-8bda75a6-86b9-458e-948b-05049b4c52ce.json
# BRCA-EU-fc8130df-1f21-c8f9-e040-11ac0d485dfc.json
# PBCA-DE-0db9309e-7b95-4ae3-b0ed-dfd4f38d11b0.json
# BTCA-SG-56cc8740-b132-4cbc-b513-f0b5b2305ca6.json
# BRCA-EU-fc8130e0-a539-dda8-e040-11ac0c48326a.json
# GBM-US-96e3db14-2bb1-4f68-aed6-5e794750c96e.json
# PBCA-DE-8efb116f-4ecf-4191-8ebf-90a94c1880cf.json
# BRCA-US-4d409156-3a36-4c63-9ad6-b6af34f27b06.json
# BRCA-US-1eb62abc-7928-405b-84cc-f091ca5347b2.json
# PBCA-DE-492694a7-bb41-4128-a909-c424e7fc0c9e.json
# LIRI-JP-7789ef18-c623-11e3-bf01-24c6515278c0.json
# BTCA-SG-1e2dcbcc-771c-43c5-8c8d-e0eb77cb3494.json
# BRCA-UK-fc5dc6d8-62d2-76d8-e040-11ac0d4863c3.json
# VCF_INDELS_sw_1_0_s_1_0_cc_0.json
# BRCA-US-2da2b745-068d-408c-9163-3b3a78d4aaed.json
# BRCA-US-fe04d042-a4cc-4a14-8197-415ea40951aa.json
# BRCA-UK-fc68e599-6a40-61dc-e040-11ac0d48700d.json
# BRCA-US-5a535c49-d42e-43c6-9d32-dc76f28d4f0f.json
# VCF_INDELS_sw_1_2_s_1_0_cc_2.json
# PBCA-DE-f2d18ad2-2f18-4c1d-8b35-46f999a82f30.json
# PBCA-DE-909f3c5d-89fc-419b-a654-75ac1dbb149f.json
# VCF_INDELS_sw_0_7_s_0_7_cc_2.json
# BRCA-US-6c65cb6d-8c50-4c7c-bc84-eeebe09fbe01.json
# BRCA-EU-fc8130e0-aed2-bb2f-e040-11ac0d485e12.json
# BOCA-UK-f8593ac0-9480-22a0-e040-11ac0d48697a.json
# BRCA-US-c67409b2-ac25-42a0-8543-4636ef132fe4.json
# ovarian-7a921087-8e62-4a93-a757-fd8cdbe1eb8f.json
# PBCA-DE-ea121956-77f5-4da3-ab15-0b825469eafe.json
# BRCA-US-fb9135d9-2acf-41dd-8552-359e6b8c9470.json
# BRCA-US-ec4d4cbc-d5d1-418d-a292-cad9576624fd.json
# PBCA-DE-93be2990-bceb-45fd-aca5-3358d96e9d5a.json
# PBCA-DE-86ae34f9-e16a-4593-8e55-b1296782bc1f.json
# GBM-US-b60392fb-43d9-4c9c-b91b-ded40492e61c.json
# PBCA-DE-ed1f5a41-921f-469a-bc04-306a5435e067.json
# PBCA-DE-c4c776f8-ee3f-4cce-beb9-8dcf262cdcdf.json
# BRCA-EU-fc8130e0-08dd-b996-e040-11ac0c48327b.json
# PBCA-DE-5f00a760-fbc0-41f0-b92b-b3c553eac0e5.json
# BRCA-UK-f393bb05-ec1c-17be-e040-11ac0d48452f.json
# PBCA-DE-aca4d810-9540-4ce3-8ceb-72d396c9b704.json
# PBCA-DE-924bcc4a-c982-43bf-8bbb-641dc983d65e.json
# BRCA-EU-fc81312a-d451-38fb-e040-11ac0c4832a4.json
# BRCA-US-6c8e9197-fd16-4fed-bfda-e349cab26314.json
# PBCA-DE-031962d6-fc7d-4c6c-9d47-ffa45997b249.json
# GBM-US-4a1ad661-f6ae-44e8-b50b-72ff658ff22b.json
# BRCA-US-7456abd5-303e-4e6f-bf4e-47efefc7310f.json
# BRCA-US-467ef778-f481-44f3-9768-b9900252d2ba.json
# PBCA-DE-589daa3f-0b76-4c9c-b494-048955e36052.json
# BRCA-EU-fc8130e0-0d25-b475-e040-11ac0c483277.json
# GBM-US-f98de26b-c7d6-435d-81fa-1f1869da9087.json
# PBCA-DE-5a5a8409-a8f2-4c7b-85e5-b8bd85f2930c.json
# VCF_POINT_MUTATIONS_sw_1_0_s_0_7_oc.json
# BOCA-UK-f8696c79-b165-92a6-e040-11ac0c4804bf.json
# BRCA-EU-fc8130df-297f-34a3-e040-11ac0d485e02.json
# BRCA-EU-fc8130df-e399-e34d-e040-11ac0c483279.json
# PBCA-DE-2abe2e53-ad9b-4fbc-b9a7-93444f1bea87.json
# BRCA-EU-f7f66114-e321-1d4c-e040-11ac0d48541a.json
# BOCA-UK-f82d213f-bc06-5b51-e040-11ac0c48687e.json
# VCF_POINT_MUTATIONS_sw_1_2_s_1_0_oc.json
# BRCA-UK-f221cbb5-eefa-187f-e040-11ac0c481708.json
# BRCA-UK-f393bb08-5b50-e009-e040-11ac0d484537.json
# BRCA-US-1bb3a1c7-4d7b-4fb6-b54d-e94cbd0e32aa.json
# BRCA-UK-fc63cbab-d27a-5ebb-e040-11ac0c48724f.json
# BRCA-EU-fc8130df-2e39-3814-e040-11ac0d485de0.json
# BRCA-EU-fc8130df-90ba-5d94-e040-11ac0d485e0c.json
# kidney-9ae0744a-9bc1-4cd7-b7cf-c6569ed9e4aa.json
# PBCA-DE-e9d607e8-41c3-4210-870b-a9ab9b1d1c8c.json
# BRCA-EU-fc8130e0-0fde-b756-e040-11ac0c48328b.json
# GBM-US-b2d17671-d2e1-4c97-8b01-a976d5abe1d6.json
# BRCA-EU-fc8130df-8ec8-5b1e-e040-11ac0d485e06.json
# BRCA-EU-fc8130e0-095f-b953-e040-11ac0c483287.json
# PBCA-DE-4d121008-0987-4142-a2b8-7dac58f3110a.json
# PBCA-DE-8a8dd718-c46e-462a-9793-83d88f5caa7f.json
# BRCA-UK-f393bb0c-3ffa-cb72-e040-11ac0d48455c.json
# VCF_INDELS_sw_1_0_s_1_0_cc_1.json
# BRCA-EU-fc8130e3-023d-c7d4-e040-11ac0c483295.json
# GBM-US-fca08ee9-b480-4dc7-be56-f1eb03b56f7c.json
# VCF_INDELS_sw_1_2_s_0_7_cc_1.json
# VCF_POINT_MUTATIONS_sw_1_2_s_1_2_cc_0.json
# BRCA-UK-f393bb08-4121-cad8-e040-11ac0d484535.json
# PBCA-DE-868c95ad-45df-4f8e-9553-b7c2c5679deb.json
# BRCA-US-1c0e384f-7254-4afe-93c0-b3fc6c6a7894.json
# PBCA-DE-6d2a5ee7-9e46-4c09-a982-7b61b5d9bdea.json
# PBCA-DE-3e1180a5-149c-4e6c-9a29-696e3ba567e3.json
# VCF_INDELS_sw_1_0_s_1_0_oc.json
# BRCA-EU-f7c6486a-bb08-f77a-e040-11ac0c482953.json
# VCF_INDELS_sw_0_7_s_1_0_cc_1.json
# BRCA-EU-fc8130e2-f2ef-d096-e040-11ac0c483293.json
# BRCA-US-f9f04e42-63a2-4ee1-ade4-9e5bb5c20cdd.json
# BRCA-US-207f8a42-5b05-4876-b0ae-ebfaeea27844.json
# VCF_INDELS_sw_1_2_s_0_7_oc.json
# PBCA-DE-c6224ab0-74f5-4f0a-9fe0-c083f806c853.json
# PBCA-DE-7bd4d5e2-69ee-4264-93e4-2ba01418c460.json
# BRCA-US-aacaba97-ecde-440b-aae0-0e9c608c4b24.json
# BRCA-US-47b5d831-5287-4f62-b17a-6e5eff2e4184.json
# BOCA-UK-f85add3d-e2e6-31f8-e040-11ac0d48479c.json
# GBM-US-b1e62d8e-24d2-4118-8cd0-3142acebdd5b.json
# BOCA-UK-f85ae2b7-cebf-17a2-e040-11ac0c48033a.json
# GBM-US-0332b017-17d5-4083-8fc4-9d6f8fdbbbde.json
# BOCA-UK-f83f1eb8-b2c8-c3d6-e040-11ac0c48261e.json
# PBCA-DE-aa018d90-5250-4313-9f7c-a3f196765e07.json
# BRCA-US-41f140b8-72b9-4ae3-8b25-6144d9f94d0f.json
# BRCA-EU-f7d7b3db-02af-61cb-e040-11ac0c480c03.json
# BRCA-US-987d41ee-6bab-490c-b0f2-bf28c0089de9.json
# GBM-US-2ce48f01-2f61-49d9-a56a-7438bf4a37d7.json
# PBCA-DE-55c75a2a-f3d2-4469-9d23-604cf539d548.json
# BRCA-US-43f7a2e0-fec9-4e43-872d-18c6c946fa17.json
# BRCA-EU-fc8130df-34f8-22c6-e040-11ac0d485de8.json
# BRCA-UK-f393bb0a-9b20-a0e5-e040-11ac0d48454e.json
# PBCA-DE-37c913e6-9ce5-4338-8849-b5bf7862d36a.json
# ovarian-f1504811-8363-41e6-b43c-62452b1262d3.json
# PBCA-DE-fccb865d-83ed-4bfe-ad84-0689813ae977.json
# BOCA-UK-f86975a2-78a4-ef8c-e040-11ac0c4809da.json
# PBCA-DE-c20cb5c8-a6d0-4150-b72b-3f7e8909d72b.json
# PBCA-DE-90ab64be-2229-4a8e-b864-4260b6cb39e9.json
# VCF_POINT_MUTATIONS_sw_1_2_s_1_2_oc.json
# BRCA-UK-f393bb05-c737-4cc3-e040-11ac0d48452a.json
# BOCA-UK-f87e94a9-ef37-fcba-e040-11ac0c482332.json
# BOCA-UK-f83fc777-5416-c3e9-e040-11ac0d482c8e.json
# BOCA-UK-f860bc4c-f31b-6538-e040-11ac0c48268f.json
# BRCA-US-987528ac-437a-4eb8-a335-4f2076d5c006.json
# BRCA-UK-097a7d36-905b-72be-e050-11ac0d482c9a.json
# PBCA-DE-889fb525-5055-4408-a12e-17f1225c9d29.json
# PBCA-DE-d609ce92-9edd-4286-bd5f-b93304cae9a2.json
# BRCA-EU-fc8130df-24d9-32f1-e040-11ac0d485df0.json
# PBCA-DE-6c642c0b-4dd0-406c-ac68-ea376802d61b.json
# BOCA-UK-f854ae3f-356d-f0ad-e040-11ac0c485dae.json
# BRCA-UK-fc806c50-2f6e-418d-e040-11ac0d485f01.json
# GBM-US-39520be3-a2af-4189-acf4-9d239363333a.json
# LIRI-JP-da5b9926-c622-11e3-bf01-24c6515278c0.json
# PBCA-DE-1bea3a72-3b73-4072-a6bb-96a90119d3ac.json
# VCF_INDELS_sw_0_7_s_1_2_cc_2.json
# PBCA-DE-4d690424-b015-46ae-885d-aa6d9031f66f.json
# PBCA-DE-d17c2123-d262-43f4-9d06-3547f991cde7.json
# BRCA-UK-fc447d56-0d53-e0c3-e040-11ac0c4846a8.json
# BRCA-EU-fc8130e0-0c53-b432-e040-11ac0c483283.json
# GBM-US-b8151614-b08f-49a3-ab6f-2e780f765a17.json
# BRCA-US-98bb3025-0637-4106-8621-12df7b5d662f.json
# BRCA-US-74b57d2c-a83f-4798-b86b-a533975e4cc0.json
# BRCA-US-9c70688d-6e43-4520-9262-eaae4e4d597d.json
# PBCA-DE-4daa2708-d0db-40fe-a07a-763f003adcae.json
# PBCA-DE-9be1246b-3dc1-4928-8b89-2d5ed0c866e8.json
# LIRI-JP-6f395380-c623-11e3-bf01-24c6515278c0.json
# LIRI-JP-5a51a6fc-c623-11e3-bf01-24c6515278c0.json
# BOCA-UK-f8572359-f29a-5945-e040-11ac0d4821cf.json
# PBCA-DE-d8e2af63-afe0-4f15-88b4-78118cf68160.json
# LIRI-JP-df9f8c80-c622-11e3-bf01-24c6515278c0.json
# BRCA-EU-f7c6a336-3126-7580-e040-11ac0c485971.json
# PBCA-DE-cc39b534-5ba1-4ea0-956b-676f6732beec.json
# PBCA-DE-573ee34b-43a7-40d8-95ee-0ced4b46a7c8.json
# VCF_INDELS_sw_1_2_s_1_2_cc_0.json
# PBCA-DE-35b951c0-edb0-47c4-9076-ede346ea7cb1.json
# VCF_INDELS_sw_1_0_s_1_2_cc_2.json
# BRCA-UK-f393bb0a-df7d-645c-e040-11ac0d484550.json
# BOCA-UK-f86b7e84-7040-c751-e040-11ac0c485675.json
# BRCA-EU-fc8130df-2211-cfcc-e040-11ac0d485dde.json
# PBCA-DE-906f6f1e-569d-4ce2-9273-1f305782f77f.json
# BRCA-US-c61ded54-f80e-4da8-b1d8-e22551c96118.json
# VCF_INDELS_sw_1_0_s_1_2_oc.json
# BRCA-EU-fc8130df-18fe-c74d-e040-11ac0d485df2.json
# PBCA-DE-5beafbbb-4613-4bab-977a-11c865e13a84.json
# BRCA-EU-fc8130e0-0bfa-bba4-e040-11ac0c48328d.json
# PBCA-DE-51dd1a39-7349-442c-b7e1-7850fb800569.json
# breast-b27d75ba-5989-4200-bfe9-f1b7d7cf8008.json
# BOCA-UK-f82d213f-caa7-fd59-e040-11ac0d483e46.json
# BRCA-EU-fc8130e0-09f1-b964-e040-11ac0c48326e.json
# BOCA-UK-f221c897-6ad0-0df9-e040-11ac0c4813ef.json
# LIRI-JP-7bdcb78a-c623-11e3-bf01-24c6515278c0.json
# PBCA-DE-436af904-65b2-4196-ad8c-a4e98081ee41.json
# BRCA-EU-f7f3e156-0dde-72b9-e040-11ac0d48542c.json
# BRCA-EU-fc8130df-30a5-3e6a-e040-11ac0d485de2.json
# BRCA-US-97064332-1d4f-4571-93ff-354ffe6d7df9.json
# BRCA-UK-fc9ef456-75a2-5967-e040-11ac0c484477.json
# BRCA-UK-fc447d53-24d1-c83d-e040-11ac0c4846a6.json
# BRCA-US-e55f338f-97e2-4394-ae23-c92606069485.json
# BRCA-US-3585e133-b3c1-4d90-b5f2-2b867e0ae0ec.json
# BRCA-US-9ddf2119-a222-4fa5-a9f3-0bec7eeea36b.json
# GBM-US-7cae6c0b-36fe-411b-bbba-093a4c846d84.json
# PBCA-DE-bdc039d6-4817-4e6f-b8c6-a40b1e8e1a06.json
# GBM-US-41d50a3c-49fc-4d8a-9c25-bbbcd3a5da6f.json
# BRCA-EU-f7b847e5-0f5d-69b4-e040-11ac0c4845fe.json
# GBM-US-5fd77ba9-5015-4d8b-86a0-582e5c76bdd6.json
# GBM-US-a8f86b64-914c-4d89-897b-33bcdd1759f7.json
# PBCA-DE-aa5907cb-3be3-4e23-982d-719417baeb37.json
# PBCA-DE-aed4363b-19b8-4cb5-aa34-a442410d0796.json
# PBCA-DE-6551ec26-4166-4d4f-bee2-444ea2466978.json
# PBCA-DE-b86678f3-c9cf-4ba4-8248-3efb2a7c4884.json
# BRCA-EU-f7f6619b-fae8-3381-e040-11ac0c483f78.json
# PBCA-DE-cd2a045b-fbde-49c6-8be6-c0e3ecee246f.json
# LIRI-JP-7ae872a6-c623-11e3-bf01-24c6515278c0.json
# BRCA-US-9032b7fe-e38a-4641-a45e-67041668adc4.json
# BRCA-EU-fc8130e0-ad63-b804-e040-11ac0d485e10.json
# PBCA-DE-518d6c1b-8234-40be-9560-6d383d5866fa.json
# BOCA-UK-f8467ec8-2d61-ba21-e040-11ac0c483584.json
# BRCA-EU-fc81312a-99ae-7672-e040-11ac0c4832a2.json
# BRCA-US-27f87d1e-2c32-4beb-9677-62f7a286673d.json
# BRCA-US-15f90ef0-831b-40a3-98bd-ec226a9e8b26.json
# BRCA-US-e5593865-5f8e-4a4c-b36f-73fbe64d66da.json
# GBM-US-3914c02e-44ad-4c96-8464-61aa95b42c49.json
# BRCA-US-d8fbb398-d1da-4444-984a-22c8523625da.json
# BTCA-SG-a47c2012-c13d-48ac-88b6-e09bfd50122b.json
# LIRI-JP-97a6f44a-c622-11e3-bf01-24c6515278c0.json
# BRCA-EU-f7ed28a6-8f5f-e87b-e040-11ac0c48120e.json
# VCF_INDELS_sw_1_2_s_1_2_cc_1.json
# VCF_POINT_MUTATIONS_sw_1_2_s_0_7_cc_0.json
# PBCA-DE-cb89cea8-f78e-4024-97c2-8f24debee1bc.json
# BOCA-UK-f8425828-5b0f-23a8-e040-11ac0d484128.json
# VCF_POINT_MUTATIONS_sw_0_7_s_1_0_cc_0.json
# BRCA-US-0448206f-3ade-4087-b1a9-4fb2d14e1367.json
# BRCA-US-dabb5a94-9706-4429-8db0-c328e2004340.json
# VCF_INDELS_sw_0_7_s_1_0_oc.json
# VCF_POINT_MUTATIONS_sw_1_0_s_1_0_cc_0.json
# BRCA-US-74039acd-5aca-4c65-818c-3b577d295be0.json
# BRCA-EU-f7e7b258-b4b2-e6c5-e040-11ac0d486773.json
# BRCA-US-f8f749b7-547d-49fa-9da2-44eed962b6fd.json
# PBCA-DE-12ae2ba1-9484-47fe-8a3f-bba94a6abe0c.json
# BRCA-EU-fc8130e0-a39a-23b5-e040-11ac0c483270.json
# LIRI-JP-2109e1d4-c623-11e3-bf01-24c6515278c0.json
# BRCA-UK-fc9dbf68-4599-3c64-e040-11ac0d481623.json
# BRCA-UK-f393bb00-888d-710f-e040-11ac0d484518.json
# BRCA-UK-f393bb01-6ed7-9533-e040-11ac0d484521.json
# BRCA-UK-f393bb05-53c2-f80a-e040-11ac0d484528.json
# BRCA-US-7cdbe0e8-f614-4f54-b864-fd6b39e8ef1c.json
# BRCA-UK-f393bafd-1baa-e5f4-e040-11ac0d48450b.json
# PBCA-DE-d5f92ce6-796f-480d-bf98-e1080a279207.json
# BRCA-EU-fc8130e0-a94d-d9d0-e040-11ac0c483262.json
# GBM-US-374cbd87-428e-4509-85c1-b7d3302c30a0.json
# PBCA-DE-70990332-7702-45e2-84cb-8bbff773f160.json
# VCF_POINT_MUTATIONS_sw_0_7_s_0_7_oc.json
# PBCA-DE-ed46bb2e-97e3-4914-a086-de80e00d6ee8.json
# PBCA-DE-637208b2-d8b6-45a3-a389-6f34db18fea4.json
# LIRI-JP-7512b38c-c623-11e3-bf01-24c6515278c0.json
# PBCA-DE-13446fc4-9fa6-4bb3-a00a-b9265b41eb12.json
# GBM-US-96ef40c3-8d4c-4fe1-a33a-99f5b205a0bb.json
# LIRI-JP-79b23f34-c623-11e3-bf01-24c6515278c0.json
# PBCA-DE-59bfcb53-91c1-4dce-856a-f4afc8fa6224.json
# GBM-US-eab71331-53d3-4cf5-96c9-5121a3962c27.json
# BRCA-EU-f7b84b5d-8f28-e6b7-e040-11ac0c484704.json
# PBCA-DE-30376989-7edb-4863-9496-1789eccef8c4.json
# PBCA-DE-75e1bdbc-474e-4367-9b4a-963b31f3b297.json
# PBCA-DE-72b62805-76f9-476a-b876-a781e69a2c90.json
# VCF_INDELS_sw_0_7_s_1_2_cc_0.json
# BRCA-UK-fc9f6916-da31-ab17-e040-11ac0c4808f3.json
# PBCA-DE-19aa8223-ee84-4b5c-b11a-6ca2a2680b3c.json
# PBCA-DE-391a949d-217a-472c-a6d4-80e548039684.json
# ovarian serous cystadenocarcinoma-b243adb4-b3e7-4e0e-bc0d-625aa8dbb1be.json
# BRCA-EU-fc8130df-3147-3e94-e040-11ac0d485df8.json
# BRCA-US-aa58c09a-7799-4675-8310-d270224b163e.json
# BRCA-EU-fc8130df-35ac-2304-e040-11ac0d485dda.json
# BTCA-SG-f0e0d978-3e32-4444-a07a-26049b2594e6.json
# BRCA-US-36d1a85e-a09b-4537-86e0-eaf1eb03aed8.json
# PBCA-DE-19b6b9d6-6912-4b85-a4bf-52014bcb170b.json
# BRCA-EU-f7b84c09-15d4-3046-e040-11ac0c4847ff.json
# VCF_INDELS_sw_1_2_s_1_2_oc.json
# BRCA-UK-f393bb0c-4178-ca4a-e040-11ac0d48455f.json
# BRCA-EU-fc8130e0-a8b4-d80d-e040-11ac0c483272.json
# GBM-US-d1132127-1250-43af-9c16-425798a3d1a7.json
# LIRI-JP-78bc2608-c623-11e3-bf01-24c6515278c0.json
# BRCA-EU-fc8130e0-a774-d834-e040-11ac0c483268.json
# BRCA-US-ddc7377d-82c3-480a-be3c-3d1da52c77d4.json
# BRCA-UK-fc813235-5ed8-7695-e040-11ac0d485e3e.json
# PBCA-DE-324adcfa-3fba-45b9-99f0-9d41c0c54d79.json
# BRCA-EU-fc8130e3-01ba-c740-e040-11ac0c483291.json
# BTCA-SG-50e3a421-9741-4cd8-911b-0f47ca518b6a.json
# PBCA-DE-27847313-3b1e-47f2-84f1-acadaf265cf3.json
# BOCA-UK-f82d213f-9ba5-7b6b-e040-11ac0c486882.json
# BRCA-US-db45d81f-695c-4f99-beea-6dbec1ff47fc.json
# PBCA-DE-4c3f733d-5fd5-4f67-af5f-8c36c5b37be2.json
# BRCA-US-cc4f9175-a8c8-424a-99d7-8bd11cae0e52.json
# BRCA-US-f39cc911-36a7-4c06-9e91-4ad86281db3d.json
# sarcoma-7d332cb1-ba25-47e4-8bf8-d25e14f40d59.json
# PBCA-DE-04b9837e-9ab5-4eb9-9a9c-ef49e3a62662.json
# BRCA-UK-fca3f7d0-2231-661c-e040-11ac0c4832fd.json
# BOCA-UK-f86ae246-2492-9785-e040-11ac0d4813b0.json
# PBCA-DE-cc69fe94-0ecf-45ad-a03f-8fb7198e8657.json
# PBCA-DE-edc070db-b768-478f-ae75-4c4012bdc3fe.json
# BTCA-SG-ec399861-7a56-4ffd-8619-700b6e3a4367.json
# BRCA-US-546b982f-60d9-43df-9761-09369afbee2d.json
# GBM-US-914421d2-898e-433e-bb66-b1710eaae2c7.json
# PBCA-DE-7dddd413-d2c6-4f75-bbf6-3b202877546e.json
# PBCA-DE-68956108-2606-4696-b038-462b6c432398.json
# PBCA-DE-14f41457-25c3-4979-8515-4f33322039a5.json
# VCF_INDELS_sw_1_0_s_1_2_cc_0.json
# PBCA-DE-ae464652-2f8c-4d94-8b08-cd8f1d29256e.json
# PBCA-DE-45614404-2149-4468-848c-0796e3757d62.json
# BRCA-UK-fc447d55-95d8-0b34-e040-11ac0d483afa.json
# GBM-US-2fdab641-d73b-4f9a-aa4c-c1944f131a69.json
# BOCA-UK-f87eb1b5-1712-ca1f-e040-11ac0c483848.json
# VCF_INDELS_sw_1_2_s_1_2_cc_2.json
# BRCA-EU-f7c7373c-1972-4968-e040-11ac0d486e80.json
# BRCA-EU-fc8130df-1bc2-c537-e040-11ac0d485de6.json
# VCF_POINT_MUTATIONS_sw_1_0_s_1_2_oc.json
# BRCA-EU-fc8130df-1e8f-c879-e040-11ac0d485df4.json
# BRCA-EU-f80293b8-ddb7-f575-e040-11ac0d48309d.json
# PBCA-DE-b64173fc-abac-4695-902b-f0acf9444e9f.json
# BRCA-US-6dbc5c31-043b-40e9-bf1a-e7b4ec351b4d.json
# PBCA-DE-3b399659-8302-428a-9c97-1e7b455c9c2f.json
# PBCA-DE-5cbd429f-ffab-41ad-8016-422f1c922e99.json
# PBCA-DE-1f8d8720-30ca-4057-90f7-a34b8383eafe.json
# BRCA-EU-fc8130df-8e4e-586b-e040-11ac0d485e08.json
# PBCA-DE-b0d1fde4-928f-4f4c-bff6-33b885582bb5.json
# VCF_POINT_MUTATIONS_sw_0_7_s_1_0_oc.json
# VCF_POINT_MUTATIONS_sw_1_0_s_0_7_cc_0.json
# VCF_INDELS_sw_1_0_s_1_2_cc_1.json
# BRCA-EU-fc8130e0-0db6-b568-e040-11ac0c483281.json
# BRCA-EU-fc8130e0-096a-b991-e040-11ac0c48327d.json
# BRCA-US-13c312ec-0add-4758-ab8d-c193e2e08c6d.json
# BRCA-UK-fc9f6cb0-ceb9-790d-e040-11ac0c480ad1.json
# BRCA-EU-fc8130df-2d5f-3b53-e040-11ac0d485dee.json
# PBCA-DE-d0161ca7-3c33-4fe5-80df-0cc4b3c4e8ee.json
# PBCA-DE-4e361622-f9a8-4e9b-a89e-19bafebe1d6a.json
# BRCA-US-d5372745-95cf-4572-a6e7-e7f5b796911a.json
# BOCA-UK-f86b6ba2-8f4b-ee53-e040-11ac0d485904.json
# BRCA-US-110b5f05-ded7-45ec-b0f6-a941c92d77dd.json
# BRCA-US-6e839eaf-1dbb-43f5-8846-c980e05540c7.json
# PBCA-DE-49fa7e44-c86f-4b1f-8849-e5fe5b9de734.json
# BRCA-UK-fc639186-8302-798e-e040-11ac0c484cec.json
# BRCA-US-8e03e773-5557-4e78-889b-4710c515378f.json
# BRCA-US-f848b66f-bd9e-4fba-afd4-eb58848d1ef4.json
# BRCA-UK-f393cfd8-ddbb-a0e1-e040-11ac0d48516b.json
# BRCA-US-2c6f1862-bb82-4e7e-9cb3-338bdf022ff4.json
# PBCA-DE-880e6970-0131-4966-b13e-8614d33f0df7.json
# PBCA-DE-12d7121a-0345-4808-a819-09d6e3227bd5.json
# BRCA-US-b752b444-f033-4be4-9d24-e5e80b4181af.json
# BOCA-UK-f8515e5a-7de3-6be3-e040-11ac0c480d6d.json
# BTCA-SG-5975deb5-00d2-4d18-b5c0-34ac9947fe11.json
# BTCA-SG-983c14b8-f35b-497b-9fd4-5e5f5f0a7aa7.json
# LIRI-JP-760881cc-c623-11e3-bf01-24c6515278c0.json
# PBCA-DE-4f3c2c94-fa7f-4945-9dff-e4d4dac95f56.json
# BOCA-UK-f866123a-9eb0-e856-e040-11ac0c48717e.json
# BRCA-US-f69e5057-eda6-4391-ba9a-aedbf6b572da.json
# PBCA-DE-5f096d7b-a1ea-4cc2-af73-10108089ae84.json
# BRCA-US-6764e0a2-7a78-45c1-9189-6001c6518ce4.json
# BRCA-US-e8392f20-c9e3-4649-b64f-5b266c393a76.json
# VCF_INDELS_sw_0_7_s_0_7_oc.json
# ovarian-89dad92e-5b3f-479a-a6da-a94ee7df7f8a.json
# BRCA-EU-fc8130e0-0f1a-b6eb-e040-11ac0c48328f.json
# VCF_POINT_MUTATIONS_sw_1_2_s_1_0_cc_0.json
# LIRI-JP-d876d576-c622-11e3-bf01-24c6515278c0.json
# BRCA-US-ea43434b-197e-48ac-ae2e-46bc7f3776de.json
# BRCA-US-7b08e810-f3c9-4155-ac11-f45a3a4f8b41.json
# BRCA-US-2290b078-6a5b-4c83-9dfb-b525bbf14e4e.json
# BRCA-EU-fc8130df-6977-7704-e040-11ac0d485de4.json
# PBCA-DE-147e3496-514e-4da7-be42-7cd9be78ed04.json
# PBCA-DE-f663ff15-c8d3-4bff-8bf9-bf8e983579e0.json
# PBCA-DE-48fadd0f-6561-4294-bff4-d5e4f7dfe79f.json
# GBM-US-4d7f2c74-862b-4aad-98e1-fa831f14a905.json
# BRCA-EU-fc8130e0-0e1f-b54d-e040-11ac0c48326c.json
# VCF_POINT_MUTATIONS_sw_0_7_s_0_7_cc_0.json
# BRCA-US-30dbe353-86d5-40ed-84c2-dbddf7beb17b.json
# GBM-US-c27290e4-6835-448a-abdc-df8ddd5f4630.json
# VCF_INDELS_sw_0_7_s_1_2_cc_1.json
# PBCA-DE-4a698352-25e6-4137-bef8-b6520d5b1b95.json
# PBCA-DE-3166f1ae-678d-42ae-9d44-d3d25d6860c7.json
# BRCA-UK-f393ba16-9361-5df4-e040-11ac0d4844e8.json
# LIRI-JP-5c9b8a2c-c623-11e3-bf01-24c6515278c0.json
# BRCA-EU-f7d77a03-28a0-f446-e040-11ac0c4866fb.json
# PBCA-DE-f8d89ae2-2c7d-40ae-8d40-34b93b16efc9.json
# PBCA-DE-13c7065e-6780-4571-978e-a7c13078ff50.json
# PBCA-DE-bf24366f-fd91-4d84-8b3d-eed80064250d.json
# VCF_INDELS_sw_1_2_s_0_7_cc_2.json
# VCF_POINT_MUTATIONS_sw_0_7_s_1_2_oc.json
# PBCA-DE-209a9b10-7129-48fe-a899-d14ba17efe6f.json
# BRCA-US-a85cf239-ff51-46e7-9b88-4c2cb49c66b9.json
# PBCA-DE-ce6154e9-3f3a-442f-a608-35e1bab66927.json
# VCF_INDELS_sw_0_7_s_1_0_cc_2.json
# BRCA-EU-fc8130df-6bec-7627-e040-11ac0d485e04.json
# BOCA-UK-f82d213f-bc99-5b1d-e040-11ac0c486880.json
# BRCA-UK-fc7eb420-5c13-20bd-e040-11ac0d484574.json
# PBCA-DE-f15989a1-e820-4879-a535-438277acad49.json
# BRCA-UK-f393baf9-2710-9203-e040-11ac0d484504.json
# VCF_INDELS_sw_1_0_s_0_7_cc_0.json
# BOCA-UK-f8407106-8a96-8f85-e040-11ac0d481656.json
# PBCA-DE-b061cb06-e927-4f24-82bb-9e651f7ae0e3.json
# PBCA-DE-03b5268e-881e-49e7-824f-170c3fc8b11b.json
# PBCA-DE-706a1085-5994-4d04-b56b-d301c9ed5afa.json
# BRCA-US-4e84eed6-82a8-4e91-b0fd-61ec6ef69ce9.json
# BRCA-EU-f7e4a2a8-093d-9e36-e040-11ac0d480c7d.json
# BRCA-US-01658141-8398-4585-9f0f-8355dd9b0604.json
# GBM-US-6de41ac1-229b-40b9-a494-5588c284351d.json
# BTCA-SG-796a8782-6d7e-47c8-b322-fcfe1dd240c8.json
# BRCA-UK-fc68c24d-47ad-7961-e040-11ac0c48595c.json
# BRCA-EU-f7d128d2-3964-e3bc-e040-11ac0d481667.json
# PBCA-DE-e76128b3-8629-4ffd-b02a-e3f0aae8b1a9.json
# PBCA-DE-d9338d73-1d5e-4808-91f2-b5a09f7342de.json
# BRCA-EU-fc8130df-2628-304a-e040-11ac0d485dfa.json
# BRCA-UK-f393bb0b-08ed-3335-e040-11ac0d484554.json
# BOCA-UK-f8809cee-8f81-28f8-e040-11ac0d4873bf.json
# PBCA-DE-4d6bb438-86f0-4414-962f-2b1cebee4524.json
# PBCA-DE-0ba8f2e2-935a-4123-86aa-6e7f5de85bf4.json
# GBM-US-9880c3c9-5685-42a7-8fe9-7585ea1a1d37.json
# PBCA-DE-d4ea36e2-1323-4441-8c63-40ce269608f4.json
# ovarian-84ca6ab0-9edc-4636-9d27-55cdba334d7d.json
# BRCA-US-47312f61-5ef4-4f25-9320-8fbb4758790e.json
# BRCA-EU-fc8130e0-0bc1-bba7-e040-11ac0c483289.json
# LIRI-JP-f2b2111c-c622-11e3-bf01-24c6515278c0.json
# LIRI-JP-7034e5f6-c623-11e3-bf01-24c6515278c0.json
# BOCA-UK-f856fa85-fdb8-c0b0-e040-11ac0d480b4e.json
# BRCA-US-e7dc7492-3a84-49c7-8dea-8f508b53dc40.json
# BRCA-US-5b7d5767-2037-4175-aec9-886776343181.json
# PBCA-DE-5fa88c3a-dbc1-43f2-82b2-e0592f35ce57.json
# GBM-US-c065761d-f775-457f-bda0-4c7c257a701e.json
# BRCA-EU-f7fdda4f-7bf7-ede7-e040-11ac0c486e57.json
# BTCA-SG-e7c90af0-4b03-453e-b44f-e07248415088.json
# PBCA-DE-ba5667da-7688-4931-bdb7-d65f391caf60.json
# PBCA-DE-5c775f90-83d4-4c1e-88c2-4e1ed1daa96f.json
# LIRI-JP-e4fd1b3e-c622-11e3-bf01-24c6515278c0.json
# BRCA-US-2b000af3-2c9d-4eaa-af3f-8101b7425c37.json
# BRCA-US-5dbf3203-ce73-41e4-bf9a-32fc856f73f5.json
# PBCA-DE-0624eb1d-3aff-4037-a3c5-fc363a9edd02.json
# GBM-US-841eb82b-347d-4d7f-805f-3f3701a2983d.json
# BRCA-EU-fc8130df-2ca4-39d2-e040-11ac0d485e00.json
# BRCA-US-f6114c69-71a1-47d5-9b28-b0227b1872f7.json
# BRCA-UK-fca6150f-d555-a29e-e040-11ac0d4873b2.json
# GBM-US-25bee010-cc99-4af0-ba2f-fe4dd308be33.json
# LIRI-JP-39458b0e-c623-11e3-bf01-24c6515278c0.json
# VCF_INDELS_sw_0_7_s_0_7_cc_0.json
# GBM-US-04339769-517c-448d-a7ca-951f83608c60.json
# GBM-US-d60f54f5-b154-42c4-99fb-cea4e7a33dc7.json
# BRCA-US-b27d75ba-5989-4200-bfe9-f1b7d7cf8008.json
# VCF_INDELS_sw_1_2_s_1_0_cc_0.json
# PBCA-DE-c59188a8-c6bb-433c-97fe-69f79a126d03.json
# gastric-bc0dee07-de20-44d6-be65-05af7e63ac96.json
# VCF_INDELS_sw_1_0_s_1_0_cc_2.json
# PBCA-DE-cb56e4c2-2fff-4f09-be34-fbdaa3794b35.json
# BRCA-US-84c77098-03d0-4b22-afb1-797703e85c6c.json
# PBCA-DE-a2a4021e-1273-4c18-907c-d20454ab898c.json
# BRCA-US-07b5141f-ac79-439b-883b-b0183bbe7ff5.json
# BRCA-EU-fc8130e0-a38a-23b9-e040-11ac0c48327f.json
# prostate adenocarcinoma-0bfd1043-816e-e3e4-e050-11ac0c4860c5.json
# GBM-US-82d7fa2d-19cd-41b7-8ed1-ea9fb9a544c6.json
# BOCA-UK-fc950c33-faa4-0241-e040-11ac0c486786.json
# BOCA-UK-f82d213f-9843-28eb-e040-11ac0d483e48.json
# breast-fc8edf46-2005-1af4-e040-11ac0d481414.json
# BOCA-UK-f82d2146-70f5-8114-e040-11ac0d483e50.json
# GBM-US-56ffaa35-814c-4c0b-b3c6-d4514d34fec2.json
# PBCA-DE-cdc672cc-35df-4f10-88f1-d3e40dabf601.json
# GBM-US-53dec97d-0464-4ffd-8e2e-95b2b9a03af0.json
# BOCA-UK-f87348df-7186-4c6b-e040-11ac0c482ba9.json
# PBCA-DE-9beb4126-0112-4c06-80a3-e5dd1c2b88d5.json
# BRCA-UK-fc78685a-7053-152a-e040-11ac0c480ded.json
# GBM-US-a6957d15-453c-4f3b-ab8c-c38054dfe548.json
# BRCA-EU-fc8130e0-a538-dda3-e040-11ac0c483264.json
# BRCA-UK-f393bb07-270c-2c93-e040-11ac0d484533.json
# GBM-US-65723119-bdfe-46f0-b629-c171023abd71.json
# BRCA-US-13d05f7a-e16a-40ef-9a15-21257da2cf89.json
# PBCA-DE-8404ef5b-7a64-47fe-98f9-3f63619d2d99.json
# VCF_INDELS_sw_1_2_s_1_0_cc_1.json
# VCF_POINT_MUTATIONS_sw_0_7_s_1_2_cc_0.json
# VCF_INDELS_sw_0_7_s_0_7_cc_1.json
# PBCA-DE-5ab6a1d3-76f8-45d4-a430-d9831daa9ec4.json
# BOCA-UK-f82d2146-726a-d0e0-e040-11ac0c486888.json
# PBCA-DE-e23462f2-cb86-4a3e-8521-221f4bec247c.json
# BRCA-US-df291849-4c35-44e1-b013-8f6b7ee36113.json
# PBCA-DE-2321c412-7730-4694-bc8f-199d7e51a7f8.json
# PBCA-DE-b68f18e1-0117-420c-9405-e8d3a1e8caff.json
# PBCA-DE-97f451e5-a1cc-4f29-8318-0e6ae74efe2f.json
# BRCA-US-a6c14ebc-81a2-44f7-af87-2b7ec85e5696.json
# BOCA-UK-f85397dc-e6e9-4f54-e040-11ac0d48706c.json
# LIRI-JP-2584b428-c623-11e3-bf01-24c6515278c0.json
# BOCA-UK-f843ed5c-0336-3d33-e040-11ac0d48478c.json
# PBCA-DE-34b0c838-bf6c-4d0f-8cd2-d2928adbb539.json
# BRCA-US-6d7f44df-e9f0-4542-a6d8-d14ee7804002.json
# VCF_INDELS_sw_1_0_s_0_7_oc.json
# breast-SRR7890905.json
# breast-SRR7890905_Hartwig.json
# BRCA-EU-fc8130e0-ad8a-b832-e040-11ac0d485e14.json
# VCF_INDELS_sw_1_2_s_1_0_oc.json
# BRCA-EU-fc8130e5-18b8-ef38-e040-11ac0c483297.json
# BRCA-US-7b0b60c7-5fa0-440e-937f-8d82119330d6.json
# BOCA-UK-f841c488-6b8d-6645-e040-11ac0c481418.json
# BRCA-EU-fc8130df-1cdd-cade-e040-11ac0d485dec.json
# PBCA-DE-bd1ce02b-bfaf-4cde-aaac-06097a12e248.json
# BRCA-US-71fda5a9-7049-406f-9348-2c24f7ddf5f4.json
# BRCA-US-a876398c-5b1d-444f-a360-5fe2db697480.json
# PBCA-DE-3f3aff50-d71b-44af-85d4-f81e813ea420.json
# BRCA-UK-fc8edf46-2005-1af4-e040-11ac0d481414.json
# BRCA-EU-f7d70fac-c76f-399e-e040-11ac0c482f9c.json
# PBCA-DE-c955387a-16e5-447c-8e69-e4c04a9861d5.json
# BRCA-EU-f809247c-2bab-ab06-e040-11ac0d482b8a.json
# PBCA-DE-0e1e628b-823a-4861-aa95-bed2fada7349.json
# BRCA-EU-f7b84bac-f161-9eee-e040-11ac0c4847ed.json
# PBCA-DE-d8995dfa-a780-4fe6-b3f8-fb464f51a1cf.json
# BOCA-UK-f845ebba-8c56-b559-e040-11ac0c4863d5.json
# PBCA-DE-ac1bd179-8285-468c-ab9f-7f91151ca0f2.json
# BRCA-EU-fc8130e0-0b9c-bbc9-e040-11ac0c483266.json
# BRCA-US-eddfbfb9-3ae8-449b-b870-46062a2571c1.json
# BRCA-EU-fc8130df-6860-7677-e040-11ac0d485ddc.json
# BOCA-UK-f87cdca1-2c85-49d2-e040-11ac0d485c9d.json
# BRCA-EU-fc8130df-3361-3c8a-e040-11ac0d485dea.json
# PBCA-DE-a65bcd07-c47d-4bda-a2bf-21f68cef2f3b.json
# VCF_POINT_MUTATIONS_sw_1_0_s_1_2_cc_0.json
# VCF_INDELS_sw_1_0_s_0_7_cc_1.json
# VCF_POINT_MUTATIONS_sw_1_0_s_1_0_oc.json
# PBCA-DE-571ce258-b453-4cac-b05e-05755791be84.json
# BRCA-UK-fc447d4f-2532-c8ea-e040-11ac0c48469f.json
# BRCA-US-25e4cad7-2403-4992-9cbc-433574673549.json
# PBCA-DE-7f22b0f7-4040-4c84-939e-894c3050ef5d.json
# BRCA-UK-fca07e09-1fd2-9ef5-e040-11ac0d485bbd.json
# BRCA-US-d8c6d4b8-f279-4edc-aaa3-a1cc266aec4d.json
# LIRI-JP-60f81dba-c623-11e3-bf01-24c6515278c0.json
# VCF_POINT_MUTATIONS_sw_1_2_s_0_7_oc.json
# BRCA-UK-f393bafe-c99f-3725-e040-11ac0d484514.json
# BRCA-US-418e916b-7a4e-4fab-8616-15dcec4d79f8.json
# 535

# %%
import os
import json

def find_files_with_types(folder_path, file_types):
    matching_files = {file_type: [] for file_type in file_types}
    
    try:
        # Loop through all files in the folder
        for filename in os.listdir(folder_path):
            if filename.endswith('.json'):
                file_path = os.path.join(folder_path, filename)
                
                try:
                    # Read and parse each JSON file
                    with open(file_path, 'r') as file:
                        json_data = json.load(file)
                        
                        # Function to recursively search for specified file types in the JSON
                        def search_for_type(obj, file_types):
                            if isinstance(obj, dict):
                                for key, value in obj.items():
                                    if key == "type" and value in file_types:
                                        return value
                                    if isinstance(value, (dict, list)):
                                        result = search_for_type(value, file_types)
                                        if result:
                                            return result
                            elif isinstance(obj, list):
                                for item in obj:
                                    result = search_for_type(item, file_types)
                                    if result:
                                        return result
                            return None
                        
                        # Check if any of the file types are found in the JSON
                        file_type_found = search_for_type(json_data, file_types)
                        if file_type_found:
                            matching_files[file_type_found].append(filename)

                except json.JSONDecodeError as e:
                    print(f"Error reading JSON file {filename}: {e}")
                except Exception as e:
                    print(f"Error processing file {filename}: {e}")
                    
    except Exception as e:
        print(f"Error accessing folder: {e}")
        return {}, 0
    
    # Print results
    for file_type, files in matching_files.items():
        print(f"\nFiles containing 'type':'{file_type}':")
        for file in files:
            print(file)
        print(f"Total number of '{file_type}' files: {len(files)}")
    
    total_files = sum(len(files) for files in matching_files.values())
    return matching_files, total_files

# Example usage
folder_path = "../data/gallery_p1/specs"
file_types = ["vcf", "gff", "bed", "bam"]
files, total_count = find_files_with_types(folder_path, file_types)
# Out:
# Files containing 'type':'vcf':
# VCF_INDELS_sw_0_7_s_1_2.json
# VCF_POINT_MUTATIONS_sw_1_2_s_1_0.json
# VCF_POINT_MUTATIONS_sw_0_7_s_1_0.json
# VCF_INDELS_sw_1_2_s_1_2.json
# VCF_INDELS_sw_1_2_s_0_7.json
# VCF_INDELS_sw_0_7_s_0_7.json
# VCF_POINT_MUTATIONS_sw_1_0_s_1_0.json
# VCF_INDELS_sw_1_0_s_1_2.json
# VCF_INDELS_sw_1_0_s_0_7.json
# VCF_POINT_MUTATIONS_sw_1_0_s_1_2.json
# VCF_INDELS_sw_1_0_s_1_0.json
# VCF_POINT_MUTATIONS_sw_1_0_s_0_7.json
# VCF_POINT_MUTATIONS_sw_1_2_s_1_2.json
# VCF_INDELS_sw_0_7_s_1_0.json
# VCF_INDELS_sw_1_2_s_1_0.json
# VCF_POINT_MUTATIONS_sw_0_7_s_1_2.json
# VCF_POINT_MUTATIONS_sw_0_7_s_0_7.json
# VCF_POINT_MUTATIONS_sw_1_2_s_0_7.json
# Total number of 'vcf' files: 18
#
# Files containing 'type':'gff':
# GFF_DEMO_sw_1_2_s_1_0.json
# GFF_DEMO_sw_0_7_s_1_0.json
# GFF_DEMO_sw_1_0_s_1_0.json
# GFF_DEMO_sw_1_0_s_0_7.json
# GFF_DEMO_sw_1_0_s_1_2.json
# GFF_DEMO_sw_0_7_s_0_7.json
# GFF_DEMO_sw_1_2_s_0_7.json
# GFF_DEMO_sw_1_2_s_1_2.json
# GFF_DEMO_sw_0_7_s_1_2.json
# Total number of 'gff' files: 9
#
# Files containing 'type':'bed':
# BED_DEMO_sw_0_7_s_0_7.json
# Total number of 'bed' files: 1
#
# Files containing 'type':'bam':
# EX_SPEC_PILEUP_sw_1_0_s_0_7.json
# EX_SPEC_CANCER_VARIANT_PROTOTYPE_sw_1_0_s_0_7.json
# EX_SPEC_CANCER_VARIANT_PROTOTYPE_sw_1_0_s_1_2.json
# EX_SPEC_PILEUP_sw_1_0_s_1_2.json
# EX_SPEC_CANCER_VARIANT_PROTOTYPE_sw_0_7_s_0_7.json
# EX_SPEC_PILEUP_sw_1_2_s_0_7.json
# EX_SPEC_PILEUP_sw_0_7_s_0_7.json
# EX_SPEC_CANCER_VARIANT_PROTOTYPE_sw_1_2_s_0_7.json
# EX_SPEC_CANCER_VARIANT_PROTOTYPE_sw_1_2_s_1_2.json
# EX_SPEC_PILEUP_sw_0_7_s_1_2.json
# EX_SPEC_PILEUP_sw_1_2_s_1_2.json
# EX_SPEC_CANCER_VARIANT_PROTOTYPE_sw_0_7_s_1_2.json
# EX_SPEC_PILEUP_sw_0_7_s_1_0.json
# EX_SPEC_CANCER_VARIANT_PROTOTYPE_sw_1_2_s_1_0.json
# EX_SPEC_CANCER_VARIANT_PROTOTYPE_sw_0_7_s_1_0.json
# EX_SPEC_PILEUP_sw_1_2_s_1_0.json
# EX_SPEC_CANCER_VARIANT_PROTOTYPE_sw_1_0_s_1_0.json
# EX_SPEC_PILEUP_sw_1_0_s_1_0.json
# Total number of 'bam' files: 18

# %%
import os
import shutil
import logging
from pathlib import Path
from typing import Set, Dict
from datetime import datetime

class FileMatchProcessor:
    def __init__(self, spec_path: str, imgs_path: str, unmatched_path: str = None):
        """Initialize with paths and set up logging."""
        self.spec_folder = Path(spec_path)
        self.imgs_folder = Path(imgs_path)
        self.unmatched_folder = Path(unmatched_path or f"unmatched_specs_{datetime.now().strftime('%Y%m%d_%H%M%S')}")
        
        # Set up logging
        self._setup_logging()
        
        # Validate paths
        self._validate_paths()

    def _setup_logging(self):
        """Configure logging settings."""
        logging.basicConfig(
            level=logging.INFO,
            format='%(asctime)s - %(levelname)s - %(message)s',
            handlers=[
                logging.FileHandler(f'file_matching_{datetime.now().strftime("%Y%m%d")}.log'),
                logging.StreamHandler()
            ]
        )
        self.logger = logging.getLogger(__name__)

    def _validate_paths(self):
        """Validate that source directories exist."""
        if not self.spec_folder.exists():
            raise FileNotFoundError(f"Spec folder not found: {self.spec_folder}")
        if not self.imgs_folder.exists():
            raise FileNotFoundError(f"Images folder not found: {self.imgs_folder}")

    def _get_files(self, path: Path, extension: str) -> Set[str]:
        """Get set of filenames without extensions for given path and extension."""
        try:
            return {f.stem for f in path.glob(f"*.{extension}")}
        except Exception as e:
            self.logger.error(f"Error reading files from {path}: {str(e)}")
            return set()

    def _create_unmatched_folder(self):
        """Create unmatched folder if it doesn't exist."""
        try:
            self.unmatched_folder.mkdir(parents=True, exist_ok=True)
            self.logger.info(f"Created or verified unmatched folder: {self.unmatched_folder}")
        except Exception as e:
            self.logger.error(f"Error creating unmatched folder: {str(e)}")
            raise

    def _move_file(self, filename: str) -> bool:
        """Move a single file to unmatched folder."""
        src_path = self.spec_folder / f"{filename}.json"
        dst_path = self.unmatched_folder / f"{filename}.json"

        try:
            # Handle case where destination file already exists
            if dst_path.exists():
                new_name = f"{filename}_{datetime.now().strftime('%Y%m%d_%H%M%S')}.json"
                dst_path = self.unmatched_folder / new_name
                self.logger.warning(f"Destination file exists, renaming to {new_name}")

            shutil.move(str(src_path), str(dst_path))
            self.logger.info(f"Successfully moved {filename}.json to {self.unmatched_folder}")
            return True
        except Exception as e:
            self.logger.error(f"Error moving {filename}.json: {str(e)}")
            return False

    def process_files(self) -> Dict[str, int]:
        """Main method to process and move unmatched files."""
        stats = {"total_unmatched": 0, "successfully_moved": 0, "failed_moves": 0}
        
        try:
            # Get files from both directories
            spec_files = self._get_files(self.spec_folder, "json")
            imgs_files = self._get_files(self.imgs_folder, "png")

            # Find unmatched files
            unmatched_files = spec_files - imgs_files
            stats["total_unmatched"] = len(unmatched_files)

            if not unmatched_files:
                self.logger.info("No unmatched files found.")
                return stats

            # Create unmatched folder
            self._create_unmatched_folder()

            # Move unmatched files
            for filename in unmatched_files:
                if self._move_file(filename):
                    stats["successfully_moved"] += 1
                else:
                    stats["failed_moves"] += 1

        except Exception as e:
            self.logger.error(f"Error during file processing: {str(e)}")
            raise

        self.logger.info(f"Processing complete. Stats: {stats}")
        return stats

def main():
    """Main function to run the file matching process."""
    try:
        processor = FileMatchProcessor(
            spec_path="../data/unified/specs",
            imgs_path="../data/unified/imgs",
            unmatched_path="../data/unified/remaining-specs"
        )
        stats = processor.process_files()
        print(f"Processing completed with stats: {stats}")
    except Exception as e:
        print(f"Error: {str(e)}")

if __name__ == "__main__":
    main()
# Out:
# 2025-02-28 20:22:52,038 - INFO - Created or verified unmatched folder: ../data/unified/remaining-specs
# 2025-02-28 20:22:52,039 - INFO - Successfully moved two_by_two_p_3_m_0_sw_1_2_s_0_7_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,039 - INFO - Successfully moved two_vertical_m_12_sw_0_7_s_0_5_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,040 - INFO - Successfully moved two_by_two_p_2_m_17_sw_1_0_s_1_0_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,040 - INFO - Successfully moved two_by_two_p_2_m_14_sw_1_2_s_1_0_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,041 - INFO - Successfully moved two_by_two_p_3_m_8_sw_1_0_s_0_7_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,042 - INFO - Successfully moved two_by_two_uneven_h_p_1_sw_1_2_s_1_0_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,042 - INFO - Successfully moved two_by_two_sq_uneven_h_p_0_sw_1_2_s_1_2_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,043 - INFO - Successfully moved two_by_two_sq_uneven_h_m_13_sw_0_7_s_2_0_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,043 - INFO - Successfully moved two_by_two_p_3_m_10_sw_1_2_s_0_7_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,044 - INFO - Successfully moved two_by_two_p_1_m_2_sw_1_0_s_1_0_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,045 - INFO - Successfully moved two_by_two_uneven_w_m_24_sw_1_2_s_1_2_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,045 - INFO - Successfully moved two_vertical_m_2_sw_0_5_s_2_0_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,046 - INFO - Successfully moved two_by_two_uneven_w_m_22_sw_1_2_s_1_0_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,047 - INFO - Successfully moved two_horizontal_m_2_sw_1_2_s_0_5_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,048 - INFO - Successfully moved two_by_two_uneven_w_m_9_sw_1_2_s_1_0_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,048 - INFO - Successfully moved two_horizontal_m_8_sw_2_0_s_2_0_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,049 - INFO - Successfully moved two_vertical_m_10_sw_0_5_s_0_7_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,049 - INFO - Successfully moved two_by_two_uneven_w_m_12_sw_0_7_s_1_2_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,050 - INFO - Successfully moved two_by_two_p_4_m_1_sw_0_7_s_0_7_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,050 - INFO - Successfully moved two_horizontal_m_13_sw_1_2_s_0_7_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,051 - INFO - Successfully moved two_horizontal_m_2_sw_1_0_s_0_5_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,051 - INFO - Successfully moved two_by_two_p_2_m_23_sw_1_2_s_1_0_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,052 - INFO - Successfully moved two_by_two_uneven_w_m_17_sw_2_0_s_1_0_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,052 - INFO - Successfully moved two_by_two_uneven_w_m_16_sw_1_2_s_1_0_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,053 - INFO - Successfully moved two_by_two_uneven_w_m_16_sw_1_2_s_1_2_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,053 - INFO - Successfully moved two_horizontal_m_4_sw_0_5_s_0_5_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,054 - INFO - Successfully moved two_by_two_sq_uneven_h_m_0_sw_2_0_s_2_0_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,054 - INFO - Successfully moved two_by_two_p_1_m_24_sw_1_2_s_0_7_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,055 - INFO - Successfully moved two_vertical_m_4_sw_1_0_s_1_2_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,055 - INFO - Successfully moved two_by_two_sq_uneven_h_p_1_sw_1_2_s_0_7_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,055 - INFO - Successfully moved two_by_two_p_4_m_1_sw_1_0_s_1_0_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,056 - INFO - Successfully moved two_vertical_m_15_sw_1_0_s_2_0_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,056 - INFO - Successfully moved two_by_two_sq_uneven_h_p_4_sw_1_0_s_1_0_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,056 - INFO - Successfully moved two_by_two_p_2_m_20_sw_1_2_s_0_7_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,057 - INFO - Successfully moved two_by_two_sq_uneven_h_p_0_sw_1_0_s_0_7_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,057 - INFO - Successfully moved two_by_two_p_3_m_12_sw_1_0_s_1_0_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,059 - INFO - Successfully moved two_by_two_p_2_m_20_sw_1_2_s_1_0_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,059 - INFO - Successfully moved two_by_two_uneven_w_m_18_sw_1_2_s_1_0_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,060 - INFO - Successfully moved two_by_two_uneven_w_m_24_sw_0_5_s_1_0_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,060 - INFO - Successfully moved two_by_two_uneven_w_m_9_sw_2_0_s_0_5_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,061 - INFO - Successfully moved two_by_two_uneven_w_m_9_sw_1_2_s_2_0_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,061 - INFO - Successfully moved two_vertical_m_8_sw_1_0_s_0_5_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,061 - INFO - Successfully moved two_vertical_m_5_sw_1_2_s_0_7_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,062 - INFO - Successfully moved two_by_two_uneven_w_m_15_sw_1_0_s_2_0_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,062 - INFO - Successfully moved two_horizontal_m_11_sw_1_2_s_0_7_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,063 - INFO - Successfully moved two_by_two_uneven_h_p_0_sw_1_0_s_1_2_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,063 - INFO - Successfully moved two_vertical_m_7_sw_1_2_s_1_0_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,064 - INFO - Successfully moved two_by_two_p_4_m_3_sw_1_0_s_0_7_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,064 - INFO - Successfully moved two_by_two_uneven_w_m_18_sw_0_5_s_1_2_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,064 - INFO - Successfully moved two_by_two_sq_uneven_h_m_10_sw_0_7_s_0_7_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,065 - INFO - Successfully moved two_by_two_uneven_w_m_4_sw_1_0_s_1_0_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,066 - INFO - Successfully moved two_by_two_uneven_w_m_10_sw_1_0_s_1_2_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,066 - INFO - Successfully moved two_horizontal_m_15_sw_0_5_s_1_2_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,066 - INFO - Successfully moved two_by_two_p_3_m_1_sw_0_7_s_0_7_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,067 - INFO - Successfully moved two_by_two_p_1_m_24_sw_1_2_s_1_0_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,067 - INFO - Successfully moved two_vertical_m_2_sw_2_0_s_0_7_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,067 - INFO - Successfully moved two_by_two_p_3_m_7_sw_1_0_s_1_2_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,068 - INFO - Successfully moved two_vertical_m_2_sw_2_0_s_0_5_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,068 - INFO - Successfully moved two_by_two_uneven_w_m_4_sw_1_2_s_1_0_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,069 - INFO - Successfully moved two_by_two_p_2_m_18_sw_1_2_s_0_7_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,069 - INFO - Successfully moved two_by_two_uneven_w_m_23_sw_1_0_s_0_5_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,070 - INFO - Successfully moved two_by_two_uneven_w_m_15_sw_0_7_s_1_2_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,070 - INFO - Successfully moved two_vertical_m_13_sw_0_7_s_0_7_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,071 - INFO - Successfully moved two_by_two_sq_uneven_h_m_12_sw_1_0_s_1_2_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,071 - INFO - Successfully moved two_horizontal_m_10_sw_2_0_s_2_0_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,072 - INFO - Successfully moved two_by_two_sq_uneven_h_m_13_sw_1_2_s_1_2_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,072 - INFO - Successfully moved two_by_two_p_3_m_24_sw_0_7_s_1_0_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,072 - INFO - Successfully moved two_by_two_uneven_w_m_20_sw_1_0_s_1_2_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,073 - INFO - Successfully moved two_vertical_m_11_sw_1_0_s_0_5_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,073 - INFO - Successfully moved two_by_two_sq_uneven_h_p_3_sw_1_0_s_1_0_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,074 - INFO - Successfully moved two_by_two_uneven_w_m_1_sw_1_0_s_1_0_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,074 - INFO - Successfully moved two_by_two_sq_uneven_h_m_11_sw_1_0_s_0_5_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,074 - INFO - Successfully moved two_horizontal_m_9_sw_1_2_s_2_0_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,075 - INFO - Successfully moved two_by_two_uneven_w_m_6_sw_1_2_s_2_0_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,075 - INFO - Successfully moved two_by_two_uneven_w_m_10_sw_1_0_s_0_7_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,076 - INFO - Successfully moved two_horizontal_m_11_sw_0_7_s_1_0_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,076 - INFO - Successfully moved two_by_two_sq_uneven_h_m_14_sw_1_0_s_0_5_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,076 - INFO - Successfully moved two_by_two_p_4_m_23_sw_1_0_s_0_7_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,077 - INFO - Successfully moved two_vertical_m_4_sw_1_2_s_1_0_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,077 - INFO - Successfully moved two_vertical_m_10_sw_0_7_s_1_0_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,078 - INFO - Successfully moved two_horizontal_m_11_sw_0_5_s_0_5_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,078 - INFO - Successfully moved two_by_two_sq_uneven_h_m_0_sw_1_0_s_2_0_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,078 - INFO - Successfully moved two_vertical_m_8_sw_2_0_s_0_7_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,079 - INFO - Successfully moved two_vertical_m_0_sw_0_5_s_1_2_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,079 - INFO - Successfully moved two_vertical_m_11_sw_1_2_s_0_7_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,079 - INFO - Successfully moved two_horizontal_m_3_sw_1_0_s_1_0_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,080 - INFO - Successfully moved two_by_two_p_2_m_19_sw_1_2_s_1_2_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,080 - INFO - Successfully moved two_horizontal_m_12_sw_1_2_s_2_0_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,080 - INFO - Successfully moved two_by_two_p_1_m_5_sw_1_0_s_1_0_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,081 - INFO - Successfully moved two_by_two_p_3_m_17_sw_1_0_s_1_2_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,081 - INFO - Successfully moved two_by_two_uneven_w_m_7_sw_1_2_s_1_2_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,081 - INFO - Successfully moved two_by_two_p_1_m_20_sw_1_2_s_1_2_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,082 - INFO - Successfully moved two_by_two_uneven_w_m_21_sw_1_0_s_0_7_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,082 - INFO - Successfully moved two_by_two_p_3_m_6_sw_1_2_s_1_0_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,082 - INFO - Successfully moved two_by_two_uneven_w_m_16_sw_2_0_s_1_2_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,083 - INFO - Successfully moved two_horizontal_m_15_sw_0_5_s_2_0_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,083 - INFO - Successfully moved two_by_two_uneven_h_p_0_sw_0_7_s_0_7_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,084 - INFO - Successfully moved two_by_two_p_4_m_14_sw_1_0_s_0_7_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,084 - INFO - Successfully moved two_by_two_uneven_w_p_1_sw_1_0_s_1_2_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,084 - INFO - Successfully moved two_by_two_uneven_w_m_20_sw_2_0_s_1_0_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,085 - INFO - Successfully moved two_horizontal_m_10_sw_1_0_s_1_0_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,085 - INFO - Successfully moved two_vertical_m_11_sw_1_2_s_2_0_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,086 - INFO - Successfully moved two_vertical_m_6_sw_2_0_s_0_7_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,086 - INFO - Successfully moved two_horizontal_m_3_sw_0_7_s_2_0_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,087 - INFO - Successfully moved two_by_two_p_3_m_20_sw_0_7_s_0_7_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,087 - INFO - Successfully moved two_by_two_uneven_w_m_14_sw_0_5_s_1_2_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,088 - INFO - Successfully moved two_by_two_uneven_w_p_3_sw_0_7_s_0_7_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,088 - INFO - Successfully moved two_by_two_p_3_m_17_sw_1_2_s_1_0_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,089 - INFO - Successfully moved two_horizontal_m_5_sw_2_0_s_0_7_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,089 - INFO - Successfully moved two_by_two_p_3_m_21_sw_1_2_s_0_7_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,090 - INFO - Successfully moved two_vertical_m_11_sw_1_0_s_0_7_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,090 - INFO - Successfully moved two_by_two_p_3_m_13_sw_1_2_s_1_0_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,091 - INFO - Successfully moved two_by_two_uneven_w_m_5_sw_1_2_s_1_2_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,091 - INFO - Successfully moved two_by_two_uneven_w_m_14_sw_0_7_s_0_5_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,092 - INFO - Successfully moved two_by_two_p_4_m_13_sw_1_2_s_1_0_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,092 - INFO - Successfully moved two_by_two_uneven_w_m_17_sw_1_2_s_1_0_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,093 - INFO - Successfully moved two_by_two_sq_uneven_h_p_3_sw_1_0_s_1_2_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,093 - INFO - Successfully moved two_by_two_uneven_w_m_16_sw_1_2_s_1_2_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,093 - INFO - Successfully moved two_by_two_p_1_m_24_sw_1_0_s_1_0_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,094 - INFO - Successfully moved two_by_two_uneven_w_m_19_sw_2_0_s_2_0_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,094 - INFO - Successfully moved two_by_two_uneven_w_m_15_sw_0_5_s_1_2_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,095 - INFO - Successfully moved two_vertical_m_1_sw_0_5_s_0_7_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,095 - INFO - Successfully moved two_by_two_p_4_m_4_sw_0_7_s_1_2_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,096 - INFO - Successfully moved two_by_two_p_3_m_5_sw_1_0_s_1_2_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,096 - INFO - Successfully moved two_by_two_uneven_w_m_7_sw_2_0_s_1_2_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,097 - INFO - Successfully moved two_by_two_p_1_m_4_sw_0_7_s_1_0_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,097 - INFO - Successfully moved two_by_two_uneven_w_m_15_sw_1_2_s_2_0_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,098 - INFO - Successfully moved two_by_two_p_4_m_16_sw_1_2_s_0_7_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,098 - INFO - Successfully moved two_by_two_uneven_w_m_8_sw_1_2_s_1_2_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,099 - INFO - Successfully moved two_horizontal_m_3_sw_1_0_s_0_5_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,099 - INFO - Successfully moved two_horizontal_m_3_sw_1_2_s_0_7_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,100 - INFO - Successfully moved two_horizontal_m_1_sw_0_7_s_0_7_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,100 - INFO - Successfully moved two_by_two_p_1_m_23_sw_0_7_s_0_7_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,101 - INFO - Successfully moved two_by_two_uneven_w_m_4_sw_2_0_s_0_5_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,101 - INFO - Successfully moved two_by_two_uneven_w_p_0_sw_0_7_s_1_0_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,101 - INFO - Successfully moved two_horizontal_m_1_sw_2_0_s_2_0_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,102 - INFO - Successfully moved two_vertical_m_4_sw_0_7_s_1_0_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,102 - INFO - Successfully moved two_vertical_m_4_sw_0_5_s_2_0_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,103 - INFO - Successfully moved two_vertical_m_3_sw_2_0_s_2_0_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,104 - INFO - Successfully moved two_by_two_sq_uneven_h_m_10_sw_0_7_s_1_2_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,104 - INFO - Successfully moved two_horizontal_m_6_sw_1_2_s_1_2_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,104 - INFO - Successfully moved two_by_two_uneven_w_m_5_sw_1_0_s_1_0_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,105 - INFO - Successfully moved two_by_two_uneven_w_p_4_sw_0_7_s_0_7_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,105 - INFO - Successfully moved two_by_two_p_3_m_11_sw_1_2_s_0_7_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,106 - INFO - Successfully moved two_vertical_m_1_sw_1_0_s_1_0_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,106 - INFO - Successfully moved two_horizontal_m_14_sw_0_5_s_0_7_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,106 - INFO - Successfully moved two_by_two_p_4_m_20_sw_1_2_s_1_2_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,107 - INFO - Successfully moved two_by_two_uneven_w_m_24_sw_1_2_s_1_2_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,107 - INFO - Successfully moved two_by_two_p_2_m_23_sw_1_0_s_1_0_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,108 - INFO - Successfully moved two_horizontal_m_12_sw_0_7_s_0_7_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,108 - INFO - Successfully moved two_vertical_m_0_sw_1_0_s_1_2_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,109 - INFO - Successfully moved two_horizontal_m_4_sw_2_0_s_1_2_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,109 - INFO - Successfully moved two_horizontal_m_14_sw_2_0_s_2_0_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,109 - INFO - Successfully moved two_by_two_uneven_w_m_20_sw_2_0_s_2_0_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,110 - INFO - Successfully moved two_by_two_p_4_m_3_sw_1_0_s_1_2_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,110 - INFO - Successfully moved two_by_two_p_3_m_1_sw_0_7_s_0_7_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,110 - INFO - Successfully moved two_horizontal_m_4_sw_2_0_s_0_7_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,111 - INFO - Successfully moved two_by_two_uneven_w_m_16_sw_0_5_s_0_7_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,111 - INFO - Successfully moved two_by_two_uneven_w_m_11_sw_2_0_s_0_7_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,112 - INFO - Successfully moved two_by_two_p_3_m_17_sw_1_2_s_1_2_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,112 - INFO - Successfully moved two_by_two_p_3_m_13_sw_1_0_s_1_2_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,112 - INFO - Successfully moved two_vertical_m_15_sw_0_7_s_2_0_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,113 - INFO - Successfully moved two_by_two_p_1_m_22_sw_1_2_s_0_7_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,113 - INFO - Successfully moved two_horizontal_m_12_sw_1_0_s_0_5_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,114 - INFO - Successfully moved two_vertical_m_14_sw_1_0_s_1_0_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,114 - INFO - Successfully moved two_by_two_p_3_m_14_sw_1_0_s_1_2_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,114 - INFO - Successfully moved two_by_two_sq_uneven_h_p_3_sw_1_2_s_0_7_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,115 - INFO - Successfully moved two_by_two_p_3_m_24_sw_1_0_s_0_7_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,115 - INFO - Successfully moved two_by_two_sq_uneven_h_m_13_sw_1_0_s_2_0_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,116 - INFO - Successfully moved two_by_two_uneven_h_m_0_sw_0_5_s_2_0_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,116 - INFO - Successfully moved two_by_two_p_4_m_5_sw_1_2_s_0_7_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,117 - INFO - Successfully moved two_by_two_p_4_m_4_sw_1_0_s_1_2_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,117 - INFO - Successfully moved two_by_two_uneven_w_m_14_sw_2_0_s_0_5_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,117 - INFO - Successfully moved two_horizontal_m_13_sw_2_0_s_2_0_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,118 - INFO - Successfully moved two_vertical_m_0_sw_0_7_s_1_0_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,118 - INFO - Successfully moved two_by_two_uneven_w_m_4_sw_2_0_s_0_5_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,118 - INFO - Successfully moved two_by_two_p_3_m_8_sw_0_7_s_1_2_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,119 - INFO - Successfully moved two_horizontal_m_6_sw_2_0_s_1_0_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,119 - INFO - Successfully moved two_by_two_uneven_h_p_3_sw_1_0_s_1_0_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,120 - INFO - Successfully moved two_by_two_uneven_w_m_20_sw_1_2_s_0_5_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,120 - INFO - Successfully moved two_by_two_uneven_w_m_23_sw_1_0_s_0_7_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,127 - INFO - Successfully moved two_by_two_uneven_w_m_17_sw_0_7_s_0_5_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,128 - INFO - Successfully moved two_by_two_sq_uneven_h_m_0_sw_0_5_s_0_5_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,128 - INFO - Successfully moved two_horizontal_m_5_sw_1_2_s_0_5_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,129 - INFO - Successfully moved two_by_two_uneven_w_m_23_sw_2_0_s_0_7_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,129 - INFO - Successfully moved two_by_two_uneven_w_m_22_sw_0_7_s_0_7_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,130 - INFO - Successfully moved two_by_two_uneven_w_m_13_sw_1_2_s_0_5_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,131 - INFO - Successfully moved two_by_two_uneven_w_m_22_sw_0_5_s_1_2_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,132 - INFO - Successfully moved two_by_two_uneven_w_m_22_sw_1_2_s_2_0_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,132 - INFO - Successfully moved two_by_two_uneven_w_m_18_sw_0_5_s_2_0_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,133 - INFO - Successfully moved two_by_two_p_2_m_5_sw_1_0_s_0_7_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,133 - INFO - Successfully moved two_by_two_sq_uneven_h_m_10_sw_0_7_s_0_7_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,133 - INFO - Successfully moved two_horizontal_m_5_sw_0_7_s_1_0_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,134 - INFO - Successfully moved two_horizontal_m_1_sw_0_7_s_1_2_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,134 - INFO - Successfully moved two_by_two_p_4_m_22_sw_0_7_s_0_7_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,135 - INFO - Successfully moved two_by_two_p_3_m_0_sw_1_2_s_1_0_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,135 - INFO - Successfully moved two_horizontal_m_9_sw_2_0_s_0_5_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,136 - INFO - Successfully moved two_by_two_sq_uneven_h_p_3_sw_1_2_s_1_0_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,136 - INFO - Successfully moved two_vertical_m_1_sw_0_5_s_1_0_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,136 - INFO - Successfully moved two_horizontal_m_11_sw_0_7_s_0_7_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,137 - INFO - Successfully moved two_by_two_uneven_w_m_19_sw_1_2_s_1_0_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,137 - INFO - Successfully moved two_by_two_p_4_m_14_sw_1_0_s_1_0_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,138 - INFO - Successfully moved two_by_two_p_2_m_14_sw_1_0_s_0_7_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,138 - INFO - Successfully moved two_by_two_uneven_h_p_2_sw_1_2_s_1_2_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,139 - INFO - Successfully moved two_by_two_uneven_h_p_3_sw_0_7_s_1_2_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,139 - INFO - Successfully moved two_by_two_uneven_h_p_2_sw_1_0_s_0_7_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,140 - INFO - Successfully moved two_by_two_p_3_m_4_sw_1_2_s_0_7_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,140 - INFO - Successfully moved two_by_two_p_2_m_9_sw_1_2_s_0_7_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,141 - INFO - Successfully moved two_by_two_uneven_w_m_11_sw_1_0_s_1_0_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,141 - INFO - Successfully moved two_by_two_sq_uneven_h_m_13_sw_0_7_s_0_5_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,142 - INFO - Successfully moved two_by_two_p_2_m_13_sw_1_0_s_0_7_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,143 - INFO - Successfully moved two_vertical_m_13_sw_1_2_s_2_0_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,143 - INFO - Successfully moved two_by_two_p_1_m_22_sw_1_0_s_0_7_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,143 - INFO - Successfully moved two_by_two_p_4_m_0_sw_0_7_s_0_7_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,144 - INFO - Successfully moved two_vertical_m_11_sw_0_7_s_2_0_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,144 - INFO - Successfully moved two_by_two_p_3_m_24_sw_0_7_s_1_0_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,145 - INFO - Successfully moved two_by_two_uneven_w_p_4_sw_1_0_s_1_2_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,145 - INFO - Successfully moved two_horizontal_m_12_sw_2_0_s_0_5_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,146 - INFO - Successfully moved two_by_two_sq_uneven_h_p_3_sw_0_7_s_0_7_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,146 - INFO - Successfully moved two_vertical_m_10_sw_1_0_s_1_0_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,147 - INFO - Successfully moved two_by_two_uneven_w_m_20_sw_0_7_s_1_2_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,147 - INFO - Successfully moved two_by_two_sq_uneven_h_m_12_sw_0_5_s_1_0_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,148 - INFO - Successfully moved two_vertical_m_9_sw_1_2_s_2_0_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,148 - INFO - Successfully moved two_by_two_p_3_m_9_sw_1_0_s_0_7_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,148 - INFO - Successfully moved two_vertical_m_6_sw_1_0_s_0_7_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,149 - INFO - Successfully moved two_vertical_m_0_sw_0_5_s_1_2_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,149 - INFO - Successfully moved two_by_two_uneven_w_m_12_sw_0_7_s_1_2_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,149 - INFO - Successfully moved two_by_two_uneven_w_m_1_sw_1_0_s_0_5_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,150 - INFO - Successfully moved two_by_two_sq_uneven_h_m_12_sw_0_7_s_1_2_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,150 - INFO - Successfully moved two_by_two_uneven_w_m_21_sw_1_2_s_0_5_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,152 - INFO - Successfully moved two_by_two_p_4_m_0_sw_0_7_s_0_7_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,152 - INFO - Successfully moved two_by_two_p_2_m_9_sw_1_0_s_1_0_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,153 - INFO - Successfully moved two_by_two_p_4_m_15_sw_1_2_s_1_2_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,153 - INFO - Successfully moved two_by_two_uneven_w_m_14_sw_0_7_s_2_0_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,154 - INFO - Successfully moved two_horizontal_m_3_sw_0_7_s_2_0_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,154 - INFO - Successfully moved two_horizontal_m_8_sw_0_5_s_0_7_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,154 - INFO - Successfully moved two_horizontal_m_10_sw_1_2_s_1_0_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,155 - INFO - Successfully moved two_by_two_p_1_m_20_sw_1_2_s_0_7_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,155 - INFO - Successfully moved two_by_two_uneven_w_m_2_sw_1_0_s_2_0_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,156 - INFO - Successfully moved two_by_two_uneven_w_m_5_sw_1_0_s_1_0_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,156 - INFO - Successfully moved two_horizontal_m_14_sw_1_2_s_0_7_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,157 - INFO - Successfully moved two_by_two_uneven_w_m_21_sw_0_5_s_0_7_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,157 - INFO - Successfully moved two_by_two_p_4_m_18_sw_1_0_s_0_7_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,157 - INFO - Successfully moved two_vertical_m_12_sw_1_2_s_2_0_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,158 - INFO - Successfully moved two_by_two_p_1_m_23_sw_1_2_s_1_0_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,158 - INFO - Successfully moved two_vertical_m_2_sw_0_7_s_1_0_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,159 - INFO - Successfully moved two_by_two_p_2_m_3_sw_1_2_s_1_0_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,159 - INFO - Successfully moved two_vertical_m_6_sw_2_0_s_1_2_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,159 - INFO - Successfully moved two_vertical_m_7_sw_1_2_s_1_0_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,160 - INFO - Successfully moved two_by_two_sq_uneven_h_m_0_sw_1_0_s_0_5_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,160 - INFO - Successfully moved two_vertical_m_11_sw_1_0_s_2_0_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,161 - INFO - Successfully moved two_by_two_p_2_m_8_sw_1_2_s_0_7_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,161 - INFO - Successfully moved two_by_two_p_3_m_1_sw_0_7_s_0_7_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,161 - INFO - Successfully moved two_vertical_m_11_sw_1_2_s_1_2_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,162 - INFO - Successfully moved two_horizontal_m_1_sw_2_0_s_1_0_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,162 - INFO - Successfully moved two_by_two_uneven_w_m_18_sw_1_2_s_2_0_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,162 - INFO - Successfully moved two_vertical_m_14_sw_1_0_s_1_2_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,163 - INFO - Successfully moved two_by_two_sq_uneven_h_p_2_sw_1_2_s_1_0_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,163 - INFO - Successfully moved two_by_two_sq_uneven_h_m_12_sw_1_2_s_0_7_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,164 - INFO - Successfully moved two_by_two_uneven_w_m_11_sw_0_5_s_0_7_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,164 - INFO - Successfully moved two_by_two_uneven_w_p_2_sw_1_2_s_1_0_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,164 - INFO - Successfully moved two_by_two_p_3_m_3_sw_0_7_s_0_7_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,165 - INFO - Successfully moved two_by_two_uneven_w_m_13_sw_0_7_s_2_0_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,165 - INFO - Successfully moved two_by_two_uneven_w_m_19_sw_1_2_s_2_0_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,165 - INFO - Successfully moved two_by_two_p_1_m_24_sw_1_2_s_1_0_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,166 - INFO - Successfully moved warm_heatmap_sw_2_0_s_1_0_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,166 - INFO - Successfully moved two_by_two_p_2_m_24_sw_1_2_s_1_0_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,167 - INFO - Successfully moved two_by_two_p_1_m_22_sw_1_0_s_1_0_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,167 - INFO - Successfully moved two_by_two_uneven_w_m_9_sw_0_7_s_1_0_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,168 - INFO - Successfully moved two_vertical_m_2_sw_1_0_s_1_0_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,168 - INFO - Successfully moved two_by_two_uneven_w_m_19_sw_1_2_s_2_0_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,168 - INFO - Successfully moved two_by_two_p_4_m_10_sw_0_7_s_0_7_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,169 - INFO - Successfully moved two_by_two_p_4_m_23_sw_1_2_s_1_0_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,169 - INFO - Successfully moved two_by_two_p_2_m_20_sw_1_2_s_0_7_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,170 - INFO - Successfully moved two_by_two_p_4_m_8_sw_1_0_s_1_0_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,170 - INFO - Successfully moved two_vertical_m_8_sw_0_5_s_0_5_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,170 - INFO - Successfully moved two_by_two_p_4_m_17_sw_1_2_s_1_2_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,171 - INFO - Successfully moved two_by_two_sq_uneven_h_m_0_sw_0_7_s_1_0_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,171 - INFO - Successfully moved two_by_two_uneven_w_m_2_sw_2_0_s_1_0_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,171 - INFO - Successfully moved two_by_two_p_3_m_9_sw_1_2_s_1_2_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,172 - INFO - Successfully moved two_by_two_uneven_w_m_17_sw_0_5_s_2_0_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,172 - INFO - Successfully moved two_by_two_uneven_w_m_2_sw_0_5_s_0_5_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,173 - INFO - Successfully moved two_by_two_p_3_m_0_sw_0_7_s_1_2_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,173 - INFO - Successfully moved two_by_two_p_3_m_7_sw_0_7_s_1_2_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,173 - INFO - Successfully moved two_horizontal_m_15_sw_1_2_s_2_0_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,173 - INFO - Successfully moved two_by_two_p_4_m_17_sw_1_0_s_1_2_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,174 - INFO - Successfully moved two_by_two_p_3_m_7_sw_0_7_s_1_0_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,174 - INFO - Successfully moved two_by_two_p_3_m_9_sw_0_7_s_0_7_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,175 - INFO - Successfully moved two_by_two_uneven_w_m_0_sw_0_5_s_2_0_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,175 - INFO - Successfully moved two_by_two_uneven_w_m_19_sw_0_7_s_0_5_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,175 - INFO - Successfully moved two_by_two_uneven_w_m_17_sw_1_2_s_0_7_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,176 - INFO - Successfully moved two_horizontal_m_3_sw_0_5_s_1_0_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,176 - INFO - Successfully moved two_by_two_p_3_m_13_sw_1_0_s_1_2_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,177 - INFO - Successfully moved two_by_two_p_4_m_20_sw_1_0_s_1_0_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,177 - INFO - Successfully moved two_horizontal_m_9_sw_0_7_s_0_5_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,178 - INFO - Successfully moved two_by_two_uneven_w_m_8_sw_1_0_s_1_2_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,178 - INFO - Successfully moved two_horizontal_m_4_sw_0_7_s_1_0_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,179 - INFO - Successfully moved two_vertical_m_11_sw_1_0_s_1_0_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,179 - INFO - Successfully moved two_by_two_uneven_w_m_13_sw_1_0_s_1_0_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,179 - INFO - Successfully moved two_by_two_uneven_w_m_16_sw_2_0_s_2_0_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,180 - INFO - Successfully moved two_by_two_uneven_w_m_3_sw_0_7_s_1_0_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,180 - INFO - Successfully moved two_horizontal_m_3_sw_1_0_s_2_0_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,180 - INFO - Successfully moved two_by_two_p_4_m_8_sw_1_2_s_1_2_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,181 - INFO - Successfully moved two_by_two_p_3_m_11_sw_0_7_s_0_7_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,181 - INFO - Successfully moved two_by_two_sq_uneven_h_m_11_sw_0_5_s_1_2_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,181 - INFO - Successfully moved two_vertical_m_0_sw_2_0_s_2_0_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,182 - INFO - Successfully moved two_by_two_p_1_m_20_sw_1_0_s_1_2_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,182 - INFO - Successfully moved two_by_two_p_3_m_22_sw_1_0_s_0_7_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,183 - INFO - Successfully moved two_by_two_uneven_w_m_0_sw_0_7_s_0_7_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,183 - INFO - Successfully moved two_by_two_p_2_m_16_sw_1_0_s_0_7_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,183 - INFO - Successfully moved two_vertical_m_1_sw_2_0_s_0_7_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,184 - INFO - Successfully moved two_by_two_uneven_w_m_9_sw_0_7_s_0_5_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,184 - INFO - Successfully moved two_horizontal_m_6_sw_0_5_s_1_0_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,184 - INFO - Successfully moved two_vertical_m_9_sw_1_2_s_1_0_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,185 - INFO - Successfully moved two_by_two_p_3_m_18_sw_1_0_s_1_0_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,185 - INFO - Successfully moved two_by_two_uneven_h_p_0_sw_0_7_s_1_2_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,185 - INFO - Successfully moved two_horizontal_m_5_sw_1_0_s_0_7_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,186 - INFO - Successfully moved two_vertical_m_12_sw_2_0_s_0_5_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,186 - INFO - Successfully moved two_by_two_uneven_w_m_16_sw_0_7_s_1_2_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,187 - INFO - Successfully moved two_horizontal_m_1_sw_1_2_s_1_0_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,187 - INFO - Successfully moved two_by_two_uneven_w_m_7_sw_2_0_s_1_2_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,187 - INFO - Successfully moved two_by_two_uneven_w_m_4_sw_1_2_s_2_0_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,188 - INFO - Successfully moved two_by_two_p_3_m_21_sw_1_2_s_0_7_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,188 - INFO - Successfully moved two_by_two_uneven_w_m_22_sw_0_5_s_0_5_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,188 - INFO - Successfully moved two_by_two_p_4_m_5_sw_1_0_s_1_2_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,189 - INFO - Successfully moved two_vertical_m_2_sw_0_5_s_0_5_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,189 - INFO - Successfully moved two_horizontal_m_5_sw_1_2_s_0_5_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,190 - INFO - Successfully moved two_horizontal_m_0_sw_0_5_s_0_7_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,190 - INFO - Successfully moved two_vertical_m_15_sw_0_5_s_1_0_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,190 - INFO - Successfully moved two_horizontal_m_13_sw_0_5_s_0_7_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,191 - INFO - Successfully moved two_vertical_m_2_sw_0_7_s_1_2_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,191 - INFO - Successfully moved two_by_two_uneven_w_m_9_sw_0_5_s_0_7_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,192 - INFO - Successfully moved two_vertical_m_13_sw_1_2_s_0_7_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,192 - INFO - Successfully moved two_by_two_p_3_m_9_sw_1_2_s_0_7_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,192 - INFO - Successfully moved two_by_two_uneven_w_m_20_sw_0_5_s_0_7_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,193 - INFO - Successfully moved two_vertical_m_0_sw_0_5_s_0_7_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,193 - INFO - Successfully moved two_by_two_uneven_w_m_5_sw_1_0_s_0_5_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,193 - INFO - Successfully moved two_by_two_uneven_w_m_22_sw_0_5_s_1_2_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,194 - INFO - Successfully moved two_by_two_uneven_h_p_3_sw_1_2_s_1_2_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,194 - INFO - Successfully moved two_vertical_m_6_sw_1_0_s_2_0_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,194 - INFO - Successfully moved two_by_two_uneven_w_m_19_sw_1_0_s_1_2_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,195 - INFO - Successfully moved two_by_two_sq_uneven_h_m_12_sw_1_2_s_1_2_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,195 - INFO - Successfully moved two_vertical_m_7_sw_0_5_s_2_0_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,195 - INFO - Successfully moved two_by_two_p_4_m_15_sw_0_7_s_1_0_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,196 - INFO - Successfully moved two_vertical_m_11_sw_0_7_s_1_0_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,196 - INFO - Successfully moved two_horizontal_m_0_sw_2_0_s_1_2_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,196 - INFO - Successfully moved two_by_two_p_4_m_9_sw_0_7_s_1_0_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,197 - INFO - Successfully moved two_by_two_uneven_w_m_17_sw_2_0_s_1_0_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,197 - INFO - Successfully moved two_by_two_sq_uneven_h_m_12_sw_2_0_s_1_2_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,198 - INFO - Successfully moved two_by_two_uneven_w_m_0_sw_0_5_s_1_2_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,198 - INFO - Successfully moved two_by_two_uneven_w_p_2_sw_0_7_s_1_2_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,199 - INFO - Successfully moved two_vertical_m_9_sw_0_7_s_0_7_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,199 - INFO - Successfully moved two_by_two_p_2_m_3_sw_1_0_s_1_0_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,200 - INFO - Successfully moved two_by_two_uneven_w_m_10_sw_0_5_s_1_0_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,200 - INFO - Successfully moved two_horizontal_m_7_sw_2_0_s_2_0_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,200 - INFO - Successfully moved two_by_two_p_4_m_5_sw_1_2_s_0_7_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,200 - INFO - Successfully moved two_by_two_p_4_m_9_sw_0_7_s_1_2_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,201 - INFO - Successfully moved two_vertical_m_5_sw_0_7_s_0_5_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,201 - INFO - Successfully moved two_by_two_uneven_w_m_22_sw_0_7_s_2_0_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,202 - INFO - Successfully moved two_horizontal_m_2_sw_0_7_s_2_0_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,202 - INFO - Successfully moved two_by_two_p_3_m_5_sw_0_7_s_1_0_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,202 - INFO - Successfully moved two_by_two_uneven_h_p_2_sw_0_7_s_1_2_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,203 - INFO - Successfully moved two_by_two_p_2_m_19_sw_0_7_s_1_0_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,203 - INFO - Successfully moved two_vertical_m_11_sw_0_7_s_1_2_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,204 - INFO - Successfully moved two_by_two_uneven_w_m_11_sw_0_5_s_0_7_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:52,204 - INFO - Successfully moved two_by_two_uneven_w_m_24_sw_1_0_s_0_7_cc_1.json to ../data/unified/remaining-specs
# ...
# 2025-02-28 20:22:55,954 - INFO - Successfully moved two_vertical_m_6_sw_0_7_s_0_5_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,955 - INFO - Successfully moved two_by_two_p_4_m_21_sw_1_2_s_1_2_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,955 - INFO - Successfully moved two_horizontal_m_11_sw_0_5_s_1_2_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,956 - INFO - Successfully moved two_by_two_p_3_m_1_sw_0_7_s_1_2_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,956 - INFO - Successfully moved two_by_two_uneven_w_m_19_sw_0_5_s_1_2_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,956 - INFO - Successfully moved two_by_two_p_3_m_7_sw_1_0_s_0_7_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,957 - INFO - Successfully moved two_by_two_uneven_w_m_7_sw_1_0_s_1_2_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,957 - INFO - Successfully moved two_vertical_m_6_sw_0_7_s_2_0_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,957 - INFO - Successfully moved two_by_two_p_4_m_18_sw_1_2_s_1_0_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,958 - INFO - Successfully moved two_by_two_uneven_w_m_15_sw_1_0_s_1_0_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,958 - INFO - Successfully moved two_vertical_m_3_sw_2_0_s_1_0_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,959 - INFO - Successfully moved two_by_two_p_2_m_15_sw_1_2_s_1_0_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,959 - INFO - Successfully moved two_horizontal_m_10_sw_0_5_s_1_0_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,959 - INFO - Successfully moved two_vertical_m_3_sw_1_0_s_1_0_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,959 - INFO - Successfully moved two_by_two_uneven_w_m_3_sw_0_5_s_2_0_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,960 - INFO - Successfully moved two_by_two_p_1_m_19_sw_1_2_s_1_2_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,960 - INFO - Successfully moved two_by_two_uneven_w_m_8_sw_0_7_s_0_7_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,960 - INFO - Successfully moved two_by_two_p_2_m_5_sw_1_2_s_1_0_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,961 - INFO - Successfully moved two_by_two_p_3_m_4_sw_1_2_s_0_7_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,961 - INFO - Successfully moved two_by_two_uneven_w_m_1_sw_1_2_s_1_2_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,961 - INFO - Successfully moved two_by_two_uneven_h_p_3_sw_1_2_s_1_2_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,962 - INFO - Successfully moved two_horizontal_m_2_sw_1_2_s_0_5_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,962 - INFO - Successfully moved two_by_two_p_3_m_23_sw_0_7_s_0_7_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,962 - INFO - Successfully moved two_by_two_uneven_w_m_22_sw_0_7_s_0_7_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,963 - INFO - Successfully moved two_by_two_uneven_w_m_0_sw_0_7_s_1_0_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,963 - INFO - Successfully moved two_by_two_p_2_m_2_sw_1_0_s_1_2_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,963 - INFO - Successfully moved two_by_two_uneven_w_m_20_sw_1_0_s_0_7_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,964 - INFO - Successfully moved two_horizontal_m_4_sw_2_0_s_1_2_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,964 - INFO - Successfully moved two_by_two_p_4_m_10_sw_1_2_s_1_0_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,964 - INFO - Successfully moved two_by_two_p_2_m_8_sw_1_0_s_1_0_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,964 - INFO - Successfully moved two_by_two_uneven_h_p_2_sw_1_2_s_1_2_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,965 - INFO - Successfully moved two_by_two_p_4_m_3_sw_1_2_s_1_0_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,965 - INFO - Successfully moved two_vertical_m_12_sw_2_0_s_2_0_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,965 - INFO - Successfully moved two_by_two_p_2_m_14_sw_0_7_s_0_7_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,966 - INFO - Successfully moved two_vertical_m_3_sw_0_5_s_0_7_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,966 - INFO - Successfully moved two_vertical_m_2_sw_2_0_s_1_2_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,966 - INFO - Successfully moved two_by_two_p_4_m_0_sw_0_7_s_1_0_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,967 - INFO - Successfully moved two_vertical_m_15_sw_0_5_s_0_7_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,967 - INFO - Successfully moved two_by_two_uneven_w_m_20_sw_0_7_s_0_7_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,967 - INFO - Successfully moved two_by_two_p_4_m_2_sw_0_7_s_1_2_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,968 - INFO - Successfully moved two_by_two_uneven_w_m_1_sw_1_2_s_0_7_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,968 - INFO - Successfully moved two_by_two_p_4_m_4_sw_0_7_s_1_0_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,968 - INFO - Successfully moved two_by_two_p_2_m_5_sw_1_0_s_1_0_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,969 - INFO - Successfully moved two_by_two_p_3_m_21_sw_0_7_s_0_7_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,969 - INFO - Successfully moved two_by_two_uneven_w_m_15_sw_2_0_s_2_0_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,969 - INFO - Successfully moved two_horizontal_m_9_sw_0_7_s_2_0_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,970 - INFO - Successfully moved two_by_two_uneven_h_p_2_sw_1_2_s_1_2_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,970 - INFO - Successfully moved two_vertical_m_14_sw_0_7_s_2_0_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,970 - INFO - Successfully moved two_by_two_p_4_m_10_sw_1_0_s_1_0_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,970 - INFO - Successfully moved two_vertical_m_7_sw_1_2_s_2_0_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,971 - INFO - Successfully moved two_vertical_m_7_sw_2_0_s_1_2_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,971 - INFO - Successfully moved two_by_two_uneven_w_m_8_sw_1_0_s_0_5_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,972 - INFO - Successfully moved two_by_two_uneven_w_m_2_sw_0_5_s_1_2_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,972 - INFO - Successfully moved two_by_two_uneven_w_m_15_sw_1_0_s_1_0_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,972 - INFO - Successfully moved two_by_two_p_4_m_13_sw_1_2_s_1_0_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,973 - INFO - Successfully moved two_by_two_p_4_m_3_sw_1_0_s_1_2_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,973 - INFO - Successfully moved two_by_two_p_4_m_9_sw_1_2_s_0_7_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,974 - INFO - Successfully moved two_by_two_uneven_w_m_11_sw_0_5_s_1_0_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,974 - INFO - Successfully moved two_by_two_p_4_m_22_sw_1_2_s_1_0_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,974 - INFO - Successfully moved two_by_two_p_1_m_21_sw_1_0_s_0_7_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,975 - INFO - Successfully moved two_by_two_uneven_w_m_6_sw_0_7_s_0_7_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,975 - INFO - Successfully moved two_by_two_sq_uneven_h_m_13_sw_0_5_s_0_7_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,975 - INFO - Successfully moved two_by_two_p_3_m_4_sw_1_2_s_1_2_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,976 - INFO - Successfully moved two_by_two_p_2_m_4_sw_1_2_s_1_0_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,976 - INFO - Successfully moved two_by_two_uneven_w_m_19_sw_1_0_s_1_0_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,977 - INFO - Successfully moved two_vertical_m_7_sw_0_7_s_0_7_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,977 - INFO - Successfully moved two_by_two_p_2_m_11_sw_1_2_s_0_7_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,977 - INFO - Successfully moved two_horizontal_m_2_sw_1_2_s_1_0_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,978 - INFO - Successfully moved two_by_two_p_2_m_23_sw_0_7_s_0_7_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,978 - INFO - Successfully moved two_horizontal_m_10_sw_0_7_s_1_0_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,978 - INFO - Successfully moved two_by_two_sq_uneven_h_m_11_sw_1_0_s_1_2_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,979 - INFO - Successfully moved two_by_two_uneven_w_m_0_sw_0_5_s_2_0_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,979 - INFO - Successfully moved two_vertical_m_0_sw_0_7_s_2_0_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,979 - INFO - Successfully moved two_vertical_m_4_sw_1_0_s_2_0_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,980 - INFO - Successfully moved two_by_two_p_1_m_24_sw_1_2_s_1_2_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,980 - INFO - Successfully moved two_by_two_uneven_w_m_6_sw_1_0_s_1_0_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,980 - INFO - Successfully moved two_vertical_m_1_sw_1_0_s_2_0_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,981 - INFO - Successfully moved two_vertical_m_8_sw_2_0_s_1_0_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,981 - INFO - Successfully moved two_horizontal_m_0_sw_1_2_s_1_2_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,982 - INFO - Successfully moved two_vertical_m_13_sw_0_5_s_1_2_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,982 - INFO - Successfully moved two_by_two_uneven_w_m_3_sw_1_0_s_2_0_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,982 - INFO - Successfully moved two_vertical_m_1_sw_2_0_s_2_0_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,983 - INFO - Successfully moved two_by_two_p_4_m_17_sw_0_7_s_1_2_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,983 - INFO - Successfully moved two_horizontal_m_14_sw_1_0_s_2_0_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,983 - INFO - Successfully moved two_by_two_p_4_m_12_sw_1_2_s_0_7_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,984 - INFO - Successfully moved two_by_two_uneven_w_m_4_sw_2_0_s_1_0_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,984 - INFO - Successfully moved two_by_two_uneven_w_m_0_sw_0_7_s_1_2_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,985 - INFO - Successfully moved two_by_two_p_2_m_11_sw_0_7_s_0_7_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,985 - INFO - Successfully moved two_by_two_p_3_m_17_sw_0_7_s_1_0_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,985 - INFO - Successfully moved two_horizontal_m_0_sw_1_0_s_0_5_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,985 - INFO - Successfully moved two_by_two_uneven_w_m_16_sw_0_5_s_0_5_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,986 - INFO - Successfully moved two_by_two_uneven_w_m_11_sw_1_0_s_0_7_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:55,986 - INFO - Successfully moved two_horizontal_m_1_sw_1_2_s_1_2_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:56,001 - INFO - Successfully moved two_by_two_uneven_w_m_2_sw_2_0_s_0_7_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:56,001 - INFO - Successfully moved two_by_two_p_4_m_23_sw_1_2_s_0_7_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:56,001 - INFO - Successfully moved two_vertical_m_13_sw_1_2_s_2_0_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:56,003 - INFO - Successfully moved warm_heatmap_sw_0_7_s_1_0_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:56,004 - INFO - Successfully moved two_vertical_m_0_sw_1_0_s_1_0_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:56,004 - INFO - Successfully moved two_vertical_m_15_sw_1_2_s_2_0_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:56,005 - INFO - Successfully moved two_by_two_p_2_m_9_sw_1_2_s_1_0_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:56,005 - INFO - Successfully moved two_horizontal_m_15_sw_0_5_s_1_2_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:56,006 - INFO - Successfully moved two_by_two_p_1_m_5_sw_1_0_s_0_7_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:56,006 - INFO - Successfully moved two_vertical_m_0_sw_1_2_s_1_0_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:56,006 - INFO - Successfully moved two_by_two_p_3_m_19_sw_1_2_s_1_2_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:56,007 - INFO - Successfully moved two_vertical_m_1_sw_1_0_s_1_0_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:56,008 - INFO - Successfully moved two_by_two_uneven_w_m_20_sw_2_0_s_0_5_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:56,008 - INFO - Successfully moved two_by_two_p_2_m_10_sw_1_0_s_0_7_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:56,009 - INFO - Successfully moved two_by_two_sq_uneven_h_m_14_sw_0_5_s_1_2_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:56,010 - INFO - Successfully moved two_by_two_uneven_w_m_11_sw_2_0_s_1_0_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:56,012 - INFO - Successfully moved two_vertical_m_15_sw_1_0_s_1_0_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:56,014 - INFO - Successfully moved two_horizontal_m_9_sw_2_0_s_0_5_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:56,014 - INFO - Successfully moved two_by_two_p_3_m_7_sw_1_0_s_1_0_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:56,014 - INFO - Successfully moved two_by_two_p_2_m_21_sw_1_0_s_1_2_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:56,015 - INFO - Successfully moved two_by_two_p_1_m_6_sw_1_2_s_1_0_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:56,015 - INFO - Successfully moved two_by_two_p_4_m_0_sw_1_0_s_1_2_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:56,015 - INFO - Successfully moved two_by_two_uneven_w_m_9_sw_0_7_s_1_2_cc_2.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:56,016 - INFO - Successfully moved two_by_two_p_3_m_14_sw_1_2_s_1_2_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:56,016 - INFO - Successfully moved two_by_two_uneven_w_m_0_sw_1_0_s_0_5_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:56,016 - INFO - Successfully moved two_vertical_m_7_sw_1_0_s_0_7_cc_0.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:56,017 - INFO - Successfully moved two_vertical_m_6_sw_1_2_s_1_0_cc_1.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:56,017 - INFO - Successfully moved two_by_two_uneven_w_m_16_sw_0_7_s_0_7_oc.json to ../data/unified/remaining-specs
# 2025-02-28 20:22:56,017 - INFO - Processing complete. Stats: {'total_unmatched': 10093, 'successfully_moved': 10093, 'failed_moves': 0}
# Processing completed with stats: {'total_unmatched': 10093, 'successfully_moved': 10093, 'failed_moves': 0}

# %%
# Compare contents of two folders

import os

# Specify the folder paths
specs_folder = '../data/unified_v3/specs'
imgs_folder = '../data/unified_v3/imgs'

# Extract base file names from the specs folder
specs_files = os.listdir(specs_folder)
specs_base_names = {os.path.splitext(file)[0] for file in specs_files if file.endswith('.json')}

# Extract base file names from the imgs folder
imgs_files = os.listdir(imgs_folder)
imgs_base_names = {os.path.splitext(file)[0] for file in imgs_files if file.endswith('.png')}

# Find overlaps and differences
overlap = specs_base_names.intersection(imgs_base_names)
specs_only = specs_base_names.difference(imgs_base_names)
imgs_only = imgs_base_names.difference(specs_base_names)

# Report results
# print("Overlap:", overlap)
print("Files in specs only:", specs_only)
print("Files in imgs only:", imgs_only)
# Out:
# Files in specs only: set()
# Files in imgs only: set()

# %%
import os
import shutil
from math import ceil

def divide_files_into_folders(source_folder, dest_folder_base, num_folders=5):
    # Get list of files in the source folder
    files = [f for f in os.listdir(source_folder) if os.path.isfile(os.path.join(source_folder, f))]

    # Calculate the number of files per folder
    num_files = len(files)
    files_per_folder = ceil(num_files / num_folders)

    # Ensure destination folders exist
    dest_folders = []
    for i in range(num_folders):
        folder_name = f"{dest_folder_base}_{i+1}"
        dest_folder = os.path.join(source_folder, folder_name)
        os.makedirs(dest_folder, exist_ok=True)
        dest_folders.append(dest_folder)

    # Distribute files to each destination folder
    for index, file in enumerate(files):
        dest_folder = dest_folders[index // files_per_folder]
        shutil.move(os.path.join(source_folder, file), os.path.join(dest_folder, file))

# Example usage
source_folder = '../data/unified/remaining_specs'
dest_folder_base = 'partition'
divide_files_into_folders(source_folder, dest_folder_base)

# %%
import os

def delete_matching_files(folder_a, folder_b):
    # Get lists of files in both directories
    files_in_a = set(os.listdir(folder_a))
    files_in_b = set(os.listdir(folder_b))
    
    # Find the intersection of both sets to get files that exist in both directories
    files_to_delete = files_in_a.intersection(files_in_b)
    
    # Initialize a counter for the number of deletions
    delete_count = 0

    # Delete the files that are present in both directories
    for file_name in files_to_delete:
        file_path_a = os.path.join(folder_a, file_name)
        # Check again to ensure it's a file to avoid directories
        if os.path.isfile(file_path_a):
            os.remove(file_path_a)
            delete_count += 1

    return delete_count

# Example usage:
folder_a = '../data/unified/failed_imgs'
folder_b = '../data/chromoscope/imgs'
count_deleted = delete_matching_files(folder_a, folder_b)
print(f'{count_deleted} files deleted.')
# Out:
# 481 files deleted.

# %%
# compare the file names in the two folders and copy the matching files to rerun

import os
import shutil

# Define the paths to the folders
folder_a_path = '../data/unified/A2_rerun_specs'  # Path to the folder containing JSON files
folder_b_path = '../data/unified/A2_rerun_imgs'   # Path to the folder containing PNG files
rerun_folder_path = '../data/unified/A3_rerun_specs'  # Path to the destination folder

# Create the rerun_specs folder if it doesn't exist
os.makedirs(rerun_folder_path, exist_ok=True)

# Get the list of files in each folder
files_in_a = set(os.listdir(folder_a_path))
files_in_b = set(os.listdir(folder_b_path))

# Find matching file names (ignoring extensions)
for file_a in files_in_a:
    file_name_without_ext, ext = os.path.splitext(file_a)
    if ext.lower() == '.json':
        # Corresponding PNG file name
        file_b = file_name_without_ext + '.png'
        if file_b in files_in_b:
            src_file_path = os.path.join(folder_a_path, file_a)
            dst_file_path = os.path.join(rerun_folder_path, file_a)
            # Copy the file from A_specs to rerun_specs
            shutil.copy(src_file_path, dst_file_path)
            print(f'Copied {file_a} to {rerun_folder_path}')

print('Finished processing.')
# Out:
# Copied breast_cancer_sw_2_0_s_2_0_cc_0.json to ../data/unified/A3_rerun_specs
# Copied VCF_POINT_MUTATIONS_sw_0_7_s_0_7_cc_0.json to ../data/unified/A3_rerun_specs
# Copied breast_cancer_sw_2_0_s_2_0_cc_2.json to ../data/unified/A3_rerun_specs
# Copied VCF_POINT_MUTATIONS_sw_0_7_s_1_2_cc_0.json to ../data/unified/A3_rerun_specs
# Copied breast_cancer_sw_2_0_s_2_0_oc.json to ../data/unified/A3_rerun_specs
# Copied VCF_POINT_MUTATIONS_sw_0_7_s_0_7_oc.json to ../data/unified/A3_rerun_specs
# Copied breast_cancer_sw_2_0_s_2_0_cc_1.json to ../data/unified/A3_rerun_specs
# Copied VCF_POINT_MUTATIONS_sw_1_2_s_1_2_cc_0.json to ../data/unified/A3_rerun_specs
# Copied VCF_POINT_MUTATIONS_sw_0_7_s_1_2_oc.json to ../data/unified/A3_rerun_specs
# Finished processing.

# %%
import os

def check_file_type(directory, file_extension):
    """
    Check if all the files in the directory (including nested directories)
    have the specified file extension. If not, print the files with different extensions.

    """
    incorrect_files = []

    for root, _, files in os.walk(directory):
        for file in files:
            if not file.endswith(file_extension):
                # Append the incorrect file path
                incorrect_files.append(os.path.join(root, file))

    if incorrect_files:
        print("Files with a different extension:")
        for incorrect_file in incorrect_files:
            print(incorrect_file)
        return False

    return True

# Example usage:
directory_path = '../data/unified_v2/gallery_p2/specs'  # Change to your folder path
file_extension = '.json'  # Change to your desired file extension

if check_file_type(directory_path, file_extension):
    print(f"All files in '{directory_path}' and its subdirectories are '{file_extension}' files.")
else:
    print(f"Not all files in '{directory_path}' are '{file_extension}' files.")
# Out:
# Files with a different extension:
# ../data/unified_v2/gallery_p2/specs/.DS_Store
# ../data/unified_v2/gallery_p2/specs/responsive-ideogram/.DS_Store
# ../data/unified_v2/gallery_p2/specs/responsive-circular/.DS_Store
# ../data/unified_v2/gallery_p2/specs/basic-link/.DS_Store
# Not all files in '../data/unified_v2/gallery_p2/specs' are '.json' files.

# %%
import os

def get_all_files_in_directory(directory, file_extension=None):
    """
    Recursively get all files in the directory with the specified extension.
    If no extension is specified, retrieve all files.
    """
    matches = set()
    for root, _, files in os.walk(directory):
        for file in files:
            if file_extension:
                if file.lower().endswith(file_extension.lower()):
                    matches.add(os.path.relpath(os.path.join(root, file), start=directory))
            else:
                matches.add(os.path.relpath(os.path.join(root, file), start=directory))
    return matches

# Define the paths to the folders
folder_a_path = '../data/unified_v2/gallery_p2/specs'  # Path to the folder containing JSON files
folder_b_path = '../data/unified_v2/gallery_p2/imgs'   # Path to the folder containing PNG files

# Get all files with specified extensions
files_in_a = get_all_files_in_directory(folder_a_path, '.json')
files_in_b = get_all_files_in_directory(folder_b_path, '.png')

# Find matching file names (ignoring extensions)
matched = False
for file_a in files_in_a:
    file_name_without_ext = os.path.splitext(file_a)[0]
    file_b = file_name_without_ext + '.png'
    if file_b in files_in_b:
        # print(f"Matching files: {file_a} and {file_b}")
        matched = True
    else:
        print(f"No matching file for {file_a} in folder B")

# Additionally, check for PNGs in folder B without corresponding JSONs
for file_b in files_in_b:
    file_name_without_ext = os.path.splitext(file_b)[0]
    file_a = file_name_without_ext + '.json'
    if file_a not in files_in_a:
        print(f"No matching file for {file_b} in folder A")
        matched = True

if not matched:
    print('No matching files found.')

print('Finished processing.')
# Out:
# No matching file for basic-link/.ipynb_checkpoints/basic-link_p_0_sw_0_7_s_0_7_cc_1-checkpoint.json in folder B
# Finished processing.

# %%
import os
import filecmp

def compare_directories(dir1, dir2):
    # Differ files
    differ_files = []

    # Compare the directories
    dir_cmp = filecmp.dircmp(dir1, dir2)

    # Files that are different
    differ_files.extend(dir_cmp.diff_files)
    
    # Files only present in one of the directories
    if dir_cmp.left_only or dir_cmp.right_only:
        differ_files.extend(dir_cmp.left_only)
        differ_files.extend(dir_cmp.right_only)

    # Recursively compare subdirectories
    for sub_dir in dir_cmp.subdirs:
        differ_files.extend(compare_directories(
            os.path.join(dir1, sub_dir),
            os.path.join(dir2, sub_dir)
        ))
        
    return differ_files

def main():
    folder1 = '../data/gallery_p1/specs_copy'
    folder2 = '../data/gallery_p1/specs'

    # Compare the folders
    diff_files = compare_directories(folder1, folder2)

    # Print out the differing files
    if diff_files:
        print("Differences found in the following files:")
        for file in diff_files:
            print(file)
    else:
        print("The folders are identical.")

if __name__ == "__main__":
    main()
# Out:
# Differences found in the following files:
# DUMMY_TRACK_sw_0_7_s_0_7.json
# EX_SPEC_CANCER_VARIANT_PROTOTYPE_sw_0_7_s_0_7.json
# EX_SPEC_CANCER_VARIANT_PROTOTYPE_sw_0_7_s_1_0.json
# EX_SPEC_CANCER_VARIANT_PROTOTYPE_sw_0_7_s_1_2.json
# EX_SPEC_CANCER_VARIANT_PROTOTYPE_sw_1_0_s_0_7.json
# EX_SPEC_CANCER_VARIANT_PROTOTYPE_sw_1_0_s_1_0.json
# EX_SPEC_CANCER_VARIANT_PROTOTYPE_sw_1_0_s_1_2.json
# EX_SPEC_CANCER_VARIANT_PROTOTYPE_sw_1_2_s_0_7.json
# EX_SPEC_CANCER_VARIANT_PROTOTYPE_sw_1_2_s_1_0.json
# EX_SPEC_CANCER_VARIANT_PROTOTYPE_sw_1_2_s_1_2.json
# EX_SPEC_GENE_ANNOTATION_sw_0_7_s_0_7.json
# EX_SPEC_GIVE_sw_0_7_s_0_7.json
# EX_SPEC_GIVE_sw_0_7_s_1_0.json
# EX_SPEC_GIVE_sw_0_7_s_1_2.json
# EX_SPEC_GIVE_sw_1_0_s_0_7.json
# EX_SPEC_GIVE_sw_1_0_s_1_0.json
# EX_SPEC_GIVE_sw_1_0_s_1_2.json
# EX_SPEC_GIVE_sw_1_2_s_0_7.json
# EX_SPEC_GIVE_sw_1_2_s_1_0.json
# EX_SPEC_GIVE_sw_1_2_s_1_2.json
# EX_SPEC_MATRIX_HFFC6_sw_0_7_s_0_7.json
# EX_SPEC_MATRIX_HFFC6_sw_0_7_s_1_0.json
# EX_SPEC_MATRIX_HFFC6_sw_0_7_s_1_2.json
# EX_SPEC_MATRIX_HFFC6_sw_1_0_s_0_7.json
# EX_SPEC_MATRIX_HFFC6_sw_1_0_s_1_0.json
# EX_SPEC_MATRIX_HFFC6_sw_1_0_s_1_2.json
# EX_SPEC_MATRIX_HFFC6_sw_1_2_s_0_7.json
# EX_SPEC_MATRIX_HFFC6_sw_1_2_s_1_0.json
# EX_SPEC_MATRIX_HFFC6_sw_1_2_s_1_2.json

# %%
import os
import shutil

# Define paths to the folders
folder_a = './geranium_seeds/rerun/heat'
folder_b = '../data/unified/specs'
rerun_specs_folder = './rerun_specs'

# Create the rerun_specs folder if it doesn't exist
if not os.path.exists(rerun_specs_folder):
    os.makedirs(rerun_specs_folder)

def get_filenames_without_extension(directory, extension):
    """Retrieves a set of filenames without the extension from a given directory."""
    return {os.path.splitext(filename)[0] for filename in os.listdir(directory) 
            if os.path.isfile(os.path.join(directory, filename)) and filename.lower().endswith(extension)}

# Get filenames without extensions from folder A for PNG files
folder_a_filenames = get_filenames_without_extension(folder_a, '.png')

# Walk through folder B, find matching JSON files by name, and move them
for filename in os.listdir(folder_b):
    if os.path.isfile(os.path.join(folder_b, filename)) and filename.lower().endswith('.json'):
        # Get the file name without extension
        name_without_ext = os.path.splitext(filename)[0]
        
        # Check if this JSON file's name (excluding extension) matches any PNG file name from folder A
        if name_without_ext in folder_a_filenames:
            # Move the file to the rerun_specs directory
            shutil.move(os.path.join(folder_b, filename), os.path.join(rerun_specs_folder, filename))
            print(f'Moved: {filename} to rerun_specs')
# Out:
# Moved: heatmap_sw_1_0_s_1_0_oc.json to rerun_specs
# Moved: hic_matrix_sw_1_0_s_1_0_oc.json to rerun_specs
# Moved: gray_heatmap_sw_1_0_s_1_0_oc.json to rerun_specs

# %%
# check file type

import os

def check_folders(folders, file_type):
    """
    Checks if all files in the given folders and subfolders are of the specified file type.
    Prints exceptions if any folder contains other file types.
    
    :param folders: List of folder paths to check.
    :param file_type: Allowed file extension (e.g., 'json' or 'png').
    """
    allowed_ext = f".{file_type.lower()}"
    exceptions = {}
    
    for folder in folders:
        for root, _, files in os.walk(folder):
            for file in files:
                if not file.lower().endswith(allowed_ext):
                    if root not in exceptions:
                        exceptions[root] = []
                    exceptions[root].append(file)
    
    if exceptions:
        print("Exceptions found:")
        for folder, files in exceptions.items():
            print(f"Folder: {folder}")
            print("  Contains disallowed files:", ", ".join(files))
    else:
        print(f"All specified folders only contain .{file_type} files.")

# Example usage
if __name__ == "__main__":
    folders_to_check = ["../data/unified_v2/autogosling/imgs", "../data/unified_v2/gallery_p1/imgs", "../data/unified_v2/gallery_p2/imgs"]  # Replace with actual paths
    file_type = "png"  # Change to 'png' if needed
    check_folders(folders_to_check, file_type)
# Out:
# All specified folders only contain .png files.

# %%
from app import init, load_embeddings, text_query_top_k
from os import walk, path
import json

# %%
(model, preprocess, tokenizer, device) = init()

# %%
# Load all embeddings
(
    text_embeddings,
    image_embeddings,
    spec_embeddings,
    text_0_2_4_embeddings,
    text_0_2_4_llm_fs_single_embeddings,
    spec_onhot_embeddings,
) = load_embeddings()

# %%
with open('../evaluation/siblings.json') as f:
    siblings = json.load(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 with open('../evaluation/siblings.json') as f:
#       2     siblings = json.load(f)
#
# File ~/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../evaluation/siblings.json'

# %%
base_path = '../data/test_suite/'
evaluation_result = {}
for query_type in ['alt', 'imgs', 'specs']:
    query_file_names = next(walk(path.join(base_path, query_type)), (None, None, []))[2]

    """
    Debugging
    """
    query_file_names = ['rule-mark_p_0_sw_1_0_s_1_0_cc_2_query.txt']
    if query_type != 'alt':
        continue
    """
    EoDebugging
    """
    
    for query_file_name in query_file_names:
        ground_truths = 
        
        with open(path.join(base_path, query_type, query_file_name), "r") as file:
            content = file.read()
            text_embeddings = text_query_top_k(model, tokenizer, device, content, text_embeddings)

text_embeddings
# Out:
#                                              file_name     dim_0     dim_1  \
# 0        EX_SPEC_ALIGNMENT_CHART_sw_1_2_s_0_7_cc_2.txt -0.018945  0.034008
# 1     BRCA-EU-fc8130e0-a8b4-d80d-e040-11ac0c483272.txt -0.012375 -0.020747
# 2                  breast_cancer_sw_1_0_s_0_5_cc_0.txt -0.005983  0.016782
# 3                   EX_SPEC_CIRCOS_sw_1_0_s_0_7_oc.txt -0.050138 -0.004010
# 4                    rule-mark_p_0_sw_1_2_s_0_7_oc.txt -0.013534  0.004531
# ...                                                ...       ...       ...
# 3195    circular-comb-points_p_1_sw_1_0_s_1_0_cc_0.txt -0.067258 -0.016504
# 3196                             breast-SRR7890905.txt -0.012375 -0.020747
# 3197            circular-bar_p_0_sw_1_2_s_0_7_cc_0.txt -0.076669 -0.040609
# 3198                       combination-four_p_1_oc.txt -0.034323  0.072692
# 3199            circular-bar_p_0_sw_1_0_s_1_2_cc_0.txt -0.076669 -0.040609
#
# ...

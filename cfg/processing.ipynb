# %%
# Reading tsv

import pandas as pd

# Load the TSV file
df = pd.read_csv('leaf_node_values.tsv', sep='\t')

# Remove display limits to see the whole DataFrame
pd.set_option('display.max_rows', None)  # Show all rows
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.width', None)  # Adjust display width
pd.set_option('display.colheader_justify', 'center')  # Center column headers

# Preview the entire file
df
# Out:
#        property                         value_type
# 0        visibility                                               true
# 1       track_count                                             number
# 2        view_count                                             number
# 3         linkingId                                               true
# 4               row                                               true
# 5         alignment                                     overlay, stack
# 6       arrangement             parallel, serial, vertical, horizontal
# 7            layout                                   linear, circular
# 8       orientation                               horizontal, vertical
# 9              mark  point, line, area, bar, rect, text, rule, brus...
# 10  track.data.type  json, csv, bed, beddb, vcf, gff, bigwig, multi...
# 11       data_group                                 sparse, contiguous
# 12           y.type                     quantitative, nominal, genomic
# 13             size                      data_agnostic, data_dependent
# 14            color                      data_agnostic, data_dependent
# 15             text                      data_agnostic, data_dependent

# %%
# try reading leaf node values

import pandas as pd

# Example: Load a DataFrame (e.g., from a TSV file)
df = pd.read_csv('leaf_node_values.tsv', sep='\t')  # Replace 'file.tsv' with your file

# Locate the 'alignment' row and read its Default Value
alignment_default = df.loc[df['property'] == 'arrangement', 'value_type'].values

# Ensure the value is read correctly and process it as a list
if alignment_default.size > 0:
    alignment_default_value = alignment_default[0]
    # Convert to a list if it is a string of values (e.g., "left, center, right")
    alignment_list = [item.strip() for item in alignment_default_value.split(',')]
    print("Default Value for 'alignment' as a list:", alignment_list)
else:
    print("Property 'alignment' not found!")
# Out:
# Default Value for 'alignment' as a list: ['parallel', 'serial', 'vertical', 'horizontal']

# %%
# convert json file to txt

import json

# Path to your JSON file
json_file_path = "chart2vec.json"
text_file_path = "chart2vec.txt"

# Read JSON file
with open(json_file_path, "r") as json_file:
    data = json.load(json_file)  # Load JSON data

# Ensure it's a list of objects
if isinstance(data, list):
    with open(text_file_path, "w") as text_file:
        for obj in data:
            json_string = json.dumps(obj, separators=(',', ':'))  # Convert each object to one line
            text_file.write(json_string + "\n")  # Write each JSON object in a new line
    print("JSON objects saved to text file, each on a new line.")
else:
    print("Error: JSON file must contain a list of objects.")
# Out:
# JSON objects saved to text file, each on a new line.

# %%
# Add all JSON specs into one tsv file

import os
import json
import csv

# Directory where your JSON files are stored
json_dir = "../data/chromoscope/specs"

# Output TSV file
output_tsv = "chromoscope-specs.tsv"

# Collect all JSON files and their content
json_data = []

# Loop through all files in the directory
for file in os.listdir(json_dir):
    if file.endswith(".json"):
        file_path = os.path.join(json_dir, file)
        
        # Read the content of the JSON file
        with open(file_path, 'r', encoding='utf-8') as json_file:
            json_content = json.load(json_file)
        
        # Append the file name and content as a tuple
        json_data.append((file, json.dumps(json_content)))

# Sort the data by file name
json_data.sort(key=lambda x: x[0])

# Write sorted data to a TSV file
with open(output_tsv, 'w', newline='', encoding='utf-8') as tsvfile:
    writer = csv.writer(tsvfile, delimiter='\t')
    
    # Write the header row
    writer.writerow(["File Name", "JSON Content"])
    
    # Write sorted file data
    for file_name, content in json_data:
        writer.writerow([file_name, content])

print(f"TSV file created successfully: {output_tsv}")
# Out:
# TSV file created successfully: chromoscope-specs.tsv

# %%
import json
import os

# Folder containing JSON files
json_folder = "../data/chromoscope/specs"  # Change this to your folder path
output_txt_file = "chromoscope-specs.txt"

# Get a list of JSON files in the folder
json_files = [f for f in os.listdir(json_folder) if f.endswith(".json")]

# Open the text file for writing
with open(output_txt_file, "w") as text_file:
    for json_file in json_files:
        json_path = os.path.join(json_folder, json_file)
        
        # Read JSON file
        with open(json_path, "r") as file:
            data = json.load(file)
        
        # Convert JSON data to a one-line string
        json_string = json.dumps(data, separators=(',', ':'))
        
        # Write each JSON file as one line
        text_file.write(json_string + "\n")

print("All JSON files saved in one text file, each on a separate line.")
# Out:
# All JSON files saved in one text file, each on a separate line.

# %%
# Compare two sets of CFG rules

def compare_cfg_files(file1_path, file2_path):
    """
    Compare two CFG rule files line by line.
    Identify overlapping rules and missing rules to make one a superset of the other.
    
    :param file1_path: Path to the first CFG rule file
    :param file2_path: Path to the second CFG rule file
    :return: Dictionary with common rules, rules missing in file1, and rules missing in file2.
    """
    
    # Helper function to load rules from a file
    def load_rules(file_path):
        with open(file_path, 'r', encoding='utf-8') as file:
            return set(line.strip() for line in file if line.strip())
    
    # Load rules from both files
    rules1 = load_rules(file1_path)
    rules2 = load_rules(file2_path)
    
    # Find common and missing rules
    common_rules = rules1.intersection(rules2)
    missing_in_file1 = rules2 - rules1
    missing_in_file2 = rules1 - rules2

    # Print results
    # print("\n🟩🟩🟩 Common Rules: 🟩🟩🟩")
    # if common_rules:
    #     print(f"Count: {len(common_rules)}")
    #     print("\n".join(common_rules))
    # else:
    #     print("None")

    print(f"\n🟦🟦🟦 Rules missing in {file1_path} (to match {file2_path}): 🟦🟦🟦")
    if missing_in_file1:
        print(f"Count: {len(missing_in_file1)}")
        print("\n".join(missing_in_file1))
    else:
        print("None")

    print(f"\n🟨🟨🟨 Rules missing in {file2_path} (to match {file1_path}): 🟨🟨🟨")
    if missing_in_file2:
        print(f"Count: {len(missing_in_file2)}")
        print("\n".join(missing_in_file2))
    else:
        print("None")

    return {
        "common_rules": common_rules,
        "missing_in_file1": missing_in_file1,
        "missing_in_file2": missing_in_file2
    }

# Example usage
result = compare_cfg_files('gosling-cfg-rules.txt', 'autogosling-cfg-rules.txt')
# Out:
# 🟦🟦🟦 Rules missing in gosling-cfg-rules.txt (to match autogosling-cfg-rules.txt): 🟦🟦🟦
# Count: 168
# track -> color "+" data "+" dataTransforms "+" height "+" mark "+" row "+" width "+" x "+" xe "+" y
# view -> height "+" tracks "+" width "+" x "+" xDomain "+" y
# root -> views "+" xDomain
# track -> color "+" data "+" dataTransforms "+" height "+" mark "+" style "+" width "+" x "+" xe
# track -> color "+" dataTransforms "+" mark "+" style "+" x
# dataTransform -> field "+" oneOf "+" type
# track -> opacity "+" y
# track -> color "+" data "+" dataTransforms "+" height "+" mark "+" width "+" x "+" xe
# track -> color "+" mark "+" x
# track -> dataTransforms "+" mark "+" style "+" text "+" x "+" xe
# track -> color "+" data "+" height "+" mark "+" stroke "+" strokeWidth "+" width "+" x "+" xe
# track -> color "+" data "+" height "+" mark "+" opacity "+" stroke "+" strokeWidth "+" style "+" title "+" width "+" x "+" xe
# track -> color "+" mark "+" opacity "+" strokeWidth "+" x
# type[dataTransform] -> "filter"
# view -> layout "+" tracks "+" xDomain
# type[dataTransform] -> "subjson"
# track -> color "+" data "+" height "+" mark "+" opacity "+" overlayOnPreviousTrack "+" stroke "+" strokeWidth "+" title "+" width "+" x "+" xe "+" y
# view -> alignment "+" data "+" height "+" row "+" size "+" stroke "+" strokeWidth "+" tracks "+" width
# view -> layout "+" linkingId "+" tracks "+" xDomain
# data -> genomicFields "+" type "+" url
# track -> alignment "+" color "+" data "+" height "+" size "+" stroke "+" strokeWidth "+" text "+" tracks "+" width "+" x "+" xe
# dataTransform -> field "+" inRange "+" type
# track -> color "+" data "+" mark "+" strokeWidth "+" y
# track -> color "+" data "+" height "+" mark "+" row "+" width "+" x "+" xe
# track -> color "+" data "+" height "+" mark "+" size "+" width "+" x "+" xe
# view -> tracks "+" xDomain
# view -> alignment "+" color "+" data "+" height "+" layout "+" row "+" tracks "+" width "+" x "+" xDomain "+" xe "+" y
# flip -> "True"
# track -> dataTransforms "+" mark "+" x
# track -> color "+" dataTransforms "+" x "+" xe "+" y
# view -> alignment "+" color "+" data "+" height "+" opacity "+" row "+" title "+" tracks "+" width
# track -> alignment "+" color "+" data "+" height "+" row "+" tracks "+" width
# view -> alignment "+" color "+" data "+" height "+" id "+" row "+" tooltip "+" tracks "+" width "+" x "+" y
# track -> color "+" data "+" mark
# track -> color "+" dataTransforms "+" mark "+" x
# root -> layout "+" linkingId "+" tracks "+" xDomain
# track -> alignment "+" color "+" data "+" height "+" mark "+" tracks "+" width "+" x "+" y
# track -> alignment "+" color "+" data "+" height "+" tracks "+" width
# track -> dataTransforms "+" mark "+" size "+" style "+" text "+" x "+" xe
# track -> color "+" data "+" height "+" id "+" mark "+" opacity "+" row "+" size "+" tooltip "+" width "+" x "+" y
# track -> color "+" data "+" height "+" mark "+" row "+" size "+" width "+" x "+" y
# track -> mark "+" x
# dataTransform -> field "+" include "+" type
# root -> centerRadius "+" layout "+" static "+" tracks "+" xDomain
# track -> color "+" data "+" height "+" id "+" mark "+" width "+" x "+" y
# track -> alignment "+" color "+" data "+" height "+" size "+" stroke "+" strokeWidth "+" title "+" tracks "+" width "+" x "+" xe
# root -> centerRadius "+" layout "+" tracks
# track -> color "+" dataTransforms "+" x "+" xe
# track -> alignment "+" color "+" data "+" height "+" size "+" tracks "+" width "+" x "+" xe
# dataTransform -> endField "+" startField "+" type
# track -> alignment "+" data "+" height "+" opacity "+" tracks "+" width
# track -> color "+" data "+" mark "+" x "+" xe "+" y "+" ye
# track -> alignment "+" color "+" data "+" dataTransforms "+" height "+" mark "+" tracks "+" width "+" x "+" xe
# y -> flip
# track -> color "+" data "+" height "+" id "+" mark "+" width "+" x "+" xe "+" y "+" ye
# track -> dataTransforms "+" mark "+" strokeWidth "+" x "+" xe
# track -> opacity "+" row "+" y
# root -> arrangement "+" centerRadius "+" layout "+" static "+" views "+" xDomain
# view -> alignment "+" height "+" style "+" tracks "+" width
# track -> mark "+" size
# root -> alignment "+" layout "+" static "+" tracks
# track -> color "+" dataTransforms "+" mark "+" size
# track -> color "+" mark "+" opacity "+" size "+" stroke "+" strokeWidth "+" x "+" y
# track -> color "+" data "+" height "+" mark "+" width "+" x "+" y
# track -> color "+" dataTransforms "+" mark "+" style "+" text "+" visibility
# track -> color "+" data "+" height "+" id "+" mark "+" row "+" tooltip "+" width "+" x "+" xe
# track -> mark "+" opacity "+" row "+" size "+" x
# track -> color "+" data "+" height "+" id "+" mark "+" row "+" tooltip "+" width "+" x "+" y
# type[dataTransform] -> "coverage"
# track -> color "+" data "+" mark "+" x "+" xe "+" y
# view -> arrangement "+" spacing "+" views
# track -> alignment "+" color "+" data "+" height "+" size "+" stroke "+" strokeWidth "+" style "+" text "+" title "+" tracks "+" width "+" x "+" xe
# track -> color "+" data "+" mark "+" title
# track -> color "+" dataTransforms "+" mark "+" text "+" x "+" xe
# root -> description "+" views "+" xDomain
# track -> color "+" mark "+" stroke "+" strokeWidth "+" x
# track -> color "+" data "+" height "+" id "+" mark "+" row "+" stroke "+" strokeWidth "+" tooltip "+" width "+" x "+" y
# track -> color "+" data "+" height "+" mark "+" row "+" style "+" width "+" x "+" y
# y -> axis "+" domain "+" field "+" type
# track -> color "+" data "+" mark "+" opacity "+" size "+" stroke "+" strokeWidth "+" x "+" xe "+" y "+" ye
# track -> color "+" data "+" height "+" mark "+" opacity "+" stroke "+" strokeWidth "+" width "+" x "+" xe
# view -> color "+" data "+" height "+" layout "+" row "+" static "+" tracks "+" width "+" x "+" xDomain "+" xe "+" y
# track -> alignment "+" color "+" data "+" height "+" opacity "+" row "+" title "+" tracks "+" width
# track -> color "+" data "+" height "+" mark "+" width "+" x "+" xe "+" y "+" ye
# view -> alignment "+" color "+" data "+" height "+" row "+" title "+" tracks "+" width
# dataTransform -> boundingBox "+" method "+" newField "+" type
# track -> alignment "+" color "+" data "+" height "+" opacity "+" size "+" stroke "+" strokeWidth "+" style "+" title "+" tooltip "+" tracks "+" width
# track -> dataTransforms "+" mark "+" size "+" x "+" xe
# track -> data "+" height "+" layout "+" mark "+" size "+" width "+" x "+" xe "+" y
# track -> color "+" data "+" height "+" id "+" mark "+" opacity "+" stroke "+" strokeWidth "+" width "+" x "+" x1 "+" x1e "+" xe
# track -> color "+" data "+" mark "+" style "+" x "+" xe "+" y "+" ye
# track -> alignment "+" color "+" data "+" height "+" row "+" style "+" title "+" tracks "+" visibility "+" width
# root -> arrangement "+" centerRadius "+" layout "+" static "+" subtitle "+" title "+" views "+" xDomain
# track -> color "+" data "+" height "+" mark "+" row "+" width "+" x "+" y
# track -> dataTransforms "+" mark "+" x "+" xe
# track -> dataTransforms "+" mark
# view -> layout "+" spacing "+" tracks "+" xOffset
# view -> alignment "+" color "+" data "+" height "+" layout "+" row "+" spacing "+" static "+" tracks "+" width "+" x "+" xDomain "+" xe "+" y
# view -> centerRadius "+" layout "+" tracks "+" xDomain
# track -> color "+" dataTransforms "+" mark "+" opacity "+" strokeWidth "+" style "+" x "+" xe
# track -> alignment "+" data "+" height "+" mark "+" row "+" style "+" title "+" tooltip "+" tracks "+" width
# track -> mark "+" x "+" xe
# dataTransform -> field "+" not "+" oneOf "+" type
# track -> color "+" data "+" height "+" mark "+" title "+" width "+" x "+" xe "+" y "+" ye
# view -> alignment "+" data "+" height "+" row "+" size "+" title "+" tracks "+" width
# root -> orientation "+" tracks
# track -> color "+" data "+" dataTransforms "+" height "+" mark "+" style "+" text "+" title "+" width "+" x "+" xe
# track -> alignment "+" data "+" height "+" stroke "+" strokeWidth "+" style "+" title "+" tracks "+" width "+" x "+" xe
# track -> mark
# view -> tracks
# track -> alignment "+" color "+" data "+" dataTransforms "+" height "+" style "+" text "+" title "+" tracks "+" width "+" x "+" xe
# track -> color "+" dataTransforms "+" mark "+" stroke "+" strokeWidth "+" x "+" xe
# track -> color "+" dataTransforms "+" mark "+" strokeWidth "+" x "+" xe
# view -> height "+" linkingId "+" style "+" tracks "+" width "+" x "+" xDomain "+" y
# x1 -> domain "+" field "+" type
# root -> static "+" tracks
# root -> arrangement "+" orientation "+" views
# track -> color "+" data "+" height "+" id "+" mark "+" row "+" stroke "+" strokeWidth "+" tooltip "+" width "+" x "+" xe "+" y "+" ye
# track -> dataTransforms "+" mark "+" size "+" x
# track -> alignment "+" color "+" data "+" height "+" tracks "+" width "+" x "+" xe
# track -> color "+" mark "+" opacity "+" stroke "+" strokeWidth "+" x
# track -> alignment "+" data "+" height "+" size "+" stroke "+" strokeWidth "+" tracks "+" width "+" x "+" xe
# view -> centerRadius "+" layout "+" spacing "+" tracks
# track -> color "+" dataTransforms "+" mark "+" x "+" xe
# view -> color "+" data "+" height "+" layout "+" row "+" tracks "+" width "+" x "+" xDomain "+" xe "+" y
# root -> arrangement "+" layout "+" views
# track -> color "+" data "+" height "+" id "+" mark "+" opacity "+" size "+" tooltip "+" width "+" x "+" y
# track -> color "+" data "+" height "+" id "+" mark "+" tooltip "+" width "+" x "+" y
# view -> height "+" tracks "+" width
# track -> color "+" dataTransforms "+" mark
# track -> dataTransforms "+" mark "+" size "+" style "+" x
# track -> color "+" data "+" dataTransforms "+" height "+" mark "+" style "+" title "+" width "+" x "+" xe
# track -> dataTransforms "+" mark "+" stroke "+" strokeWidth "+" x "+" x1 "+" x1e "+" xe
# view -> layout "+" tracks
# view -> centerRadius "+" layout "+" spacing "+" static "+" tracks "+" xDomain
# dataTransform -> baseGenomicField "+" field "+" genomicField "+" genomicLengthField "+" type
# root -> arrangement "+" centerRadius "+" layout "+" subtitle "+" title "+" views "+" xDomain
# track -> color "+" mark "+" opacity "+" size "+" x "+" y
# track -> color "+" data "+" mark "+" strokeWidth "+" x
# root -> layout "+" spacing "+" tracks "+" xOffset
# type[ye] -> "quantitative"
# track -> alignment "+" color "+" data "+" dataTransforms "+" height "+" style "+" title "+" tracks "+" width "+" x "+" xe
# track -> mark "+" x "+" y
# view -> alignment "+" color "+" data "+" height "+" row "+" tracks "+" width
# track -> color "+" data "+" height "+" mark "+" width "+" x "+" xe
# view -> alignment "+" centerRadius "+" layout "+" spacing "+" tracks "+" xDomain
# track -> dataTransforms "+" mark "+" strokeWidth "+" style "+" x "+" xe
# track -> alignment "+" data "+" height "+" mark "+" style "+" title "+" tracks "+" width
# root -> arrangement "+" spacing "+" views
# track -> alignment "+" color "+" data "+" height "+" row "+" title "+" tracks "+" width
# root -> centerRadius "+" layout "+" spacing "+" tracks
# track -> mark "+" strokeWidth "+" x
# view -> spacing "+" tracks
# root -> arrangement "+" layout "+" subtitle "+" title "+" views
# track -> data "+" height "+" mark "+" width "+" x "+" xe "+" y
# track -> dataTransforms "+" mark "+" x "+" x1 "+" x1e "+" xe
# type[dataTransform] -> "displace"
# y -> field "+" grid "+" type
# view -> arrangement "+" views
# overlayOnPreviousTrack -> "False"
# track -> alignment "+" color "+" data "+" height "+" opacity "+" size "+" stroke "+" strokeWidth "+" tooltip "+" tracks "+" width
# track -> mark "+" row "+" x
# y -> axis "+" domain "+" field "+" grid "+" type
# view -> layout "+" spacing "+" tracks
# track -> color "+" data "+" mark "+" opacity "+" stroke "+" strokeWidth "+" x "+" xe "+" y "+" ye
# track -> data "+" height "+" layout "+" mark "+" size "+" width "+" x "+" y
# track -> alignment "+" color "+" data "+" height "+" id "+" row "+" tooltip "+" tracks "+" width "+" x "+" y
# track -> dataTransforms "+" mark "+" text "+" x "+" xe
#
# 🟨🟨🟨 Rules missing in autogosling-cfg-rules.txt (to match gosling-cfg-rules.txt): 🟨🟨🟨
# Count: 360
# tracks -> color "+" data "+" height "+" mark "+" opacity "+" stroke "+" title "+" width "+" x "+" x1 "+" x1e "+" xe
# tracks -> color "+" data "+" mark "+" strokeWidth "+" x
# dataTransforms -> boundingBox "+" maxRows "+" method "+" newField "+" type
# views -> layout "+" tracks
# startPosition -> field
# flipY -> "True"
# stainStroke -> value
# root -> arrangement "+" centerRadius "+" layout "+" subtitle "+" views
# type[data] -> "bed"
# data -> indexUrl "+" sampleLength "+" type "+" url
# mouseOver -> "True"
# tracks -> alignment "+" color "+" data "+" height "+" size "+" stroke "+" strokeWidth "+" title "+" tracks "+" width "+" x "+" xe
# dataTransforms -> endField "+" startField "+" type
# views -> alignment "+" height "+" static "+" tracks "+" width "+" xDomain
# value[stainStroke] -> STRING
# y -> baseline "+" domain "+" field "+" grid "+" range "+" type
# views -> alignment "+" data "+" height "+" layout "+" static "+" title "+" tracks "+" width "+" x "+" xDomain "+" xe
# tracks -> color "+" data "+" height "+" mark "+" row "+" stroke "+" strokeWidth "+" width "+" x "+" y
# tracks -> mark "+" strokeWidth "+" x
# tracks -> dataTransforms "+" mark "+" text "+" x "+" xe
# stretch -> "True"
# tracks -> dataTransforms "+" mark "+" size "+" style "+" text "+" x "+" xe
# root -> alignment "+" color "+" data "+" height "+" opacity "+" row "+" subtitle "+" title "+" tracks "+" width
# tracks -> color "+" data "+" mark "+" visibility "+" x "+" xe "+" y
# tracks -> dataTransforms "+" mark "+" stroke "+" strokeWidth "+" text "+" x "+" xe
# dataTransforms -> field "+" not "+" oneOf "+" type
# tracks -> alignment "+" data "+" dataTransforms "+" height "+" opacity "+" stroke "+" strokeWidth "+" style "+" tracks "+" width "+" x "+" x1 "+" x1e "+" xe
# tracks -> alignment "+" height "+" tracks "+" width
# root -> alignment "+" color "+" data "+" dataTransforms "+" height "+" id "+" mark "+" opacity "+" row "+" stroke "+" strokeWidth "+" style "+" subtitle "+" tooltip "+" tracks "+" width "+" x
# tracks -> color "+" mark "+" stroke "+" strokeWidth "+" x
# views -> alignment "+" color "+" data "+" dataTransforms "+" height "+" opacity "+" row "+" style "+" title "+" tracks "+" visibility "+" width "+" xDomain
# tracks -> data "+" height "+" layout "+" mark "+" size "+" width "+" x "+" y
# tracks -> dataTransforms "+" mark "+" strokeWidth "+" style "+" x "+" xe
# tracks -> color "+" data "+" dataTransforms "+" mark "+" opacity "+" row "+" size "+" style "+" visibility "+" x
# data -> customFields "+" indexUrl "+" type "+" url
# dataTransforms -> baseGenomicField "+" field "+" genomicField "+" genomicLengthField "+" type
# root -> assembly "+" layout "+" spacing "+" subtitle "+" title "+" views
# mouseEvents -> mouseOver "+" rangeSelect
# views -> spacing "+" views
# tracks -> color "+" data "+" height "+" mark "+" stroke "+" strokeWidth "+" title "+" width "+" x "+" xe "+" y
# sampleLength -> NUMBER
# responsiveSize -> height "+" width
# views -> linkingId "+" tracks "+" xDomain
# assembly -> "unknown"
# type[data] -> "vcf"
# root -> alignment "+" centerRadius "+" layout "+" spacing "+" static "+" tracks
# tracks -> alignment "+" data "+" height "+" opacity "+" tracks "+" width
# tracks -> color "+" data "+" dataTransforms "+" mark "+" opacity "+" row "+" size "+" visibility "+" x
# views -> alignment "+" centerRadius "+" layout "+" spacing "+" tracks "+" xDomain
# fields -> ARRAY
# type[baseBackground] -> "nominal"
# matrixExtent -> "upper-right"
# tracks -> alignment "+" data "+" dataTransforms "+" height "+" opacity "+" style "+" title "+" tracks "+" width "+" x "+" xe "+" y
# matrixExtent -> "lower-left"
# style -> outline "+" outlineWidth
# tracks -> alignment "+" color "+" data "+" height "+" row "+" stroke "+" strokeWidth "+" style "+" tracks "+" width "+" x "+" xe "+" y
# tracks -> color "+" dataTransforms "+" x "+" xe "+" y
# type[dataTransforms] -> "displace"
# views -> centerRadius "+" layout "+" spacing "+" static "+" tracks "+" xDomain
# style -> textAnchor
# style -> linkStyle
# type[dataTransforms] -> "concat"
# tracks -> mark "+" size
# style -> linkConnectionType
# type[dataTransforms] -> "coverage"
# stroke -> STRING
# views -> alignment "+" height "+" tracks "+" width
# root -> centerRadius "+" layout "+" spacing "+" style "+" subtitle "+" title "+" views
# type[displacement] -> "pile"
# tracks -> color "+" data "+" dataTransforms "+" height "+" mark "+" title "+" width "+" x "+" xe "+" y
# tracks -> alignment "+" color "+" data "+" height "+" size "+" stroke "+" strokeWidth "+" style "+" text "+" title "+" tracks "+" width "+" x "+" xe
# text -> value
# tracks -> mark "+" x
# tracks -> color "+" data "+" height "+" mark "+" title "+" width "+" x "+" xe "+" y "+" ye
# tracks -> alignment "+" data "+" height "+" stroke "+" strokeWidth "+" tracks "+" width "+" x "+" xe
# tracks -> data "+" encoding "+" experimental "+" height "+" style "+" template "+" title "+" tooltip "+" width
# tracks -> color "+" data "+" displacement "+" height "+" mark "+" size "+" width "+" x "+" xe
# linkConnectionType -> "corner"
# root -> assembly "+" layout "+" spacing "+" style "+" subtitle "+" title "+" views
# tracks -> dataTransforms "+" mark "+" style "+" text "+" x "+" xe
# tracks -> data "+" mark "+" size "+" stroke "+" strokeWidth "+" title "+" x "+" xe
# tracks -> mark "+" x "+" xe
# displacement -> padding "+" type
# tracks -> alignment "+" color "+" data "+" height "+" tracks "+" width
# type[baseLabelColor] -> "nominal"
# tracks -> color "+" mark "+" opacity "+" stroke "+" strokeWidth "+" x
# brush -> color "+" stroke
# tracks -> color "+" dataTransforms "+" mark "+" size "+" visibility
# views -> tracks
# aggregate -> "max"
# tracks -> color "+" dataTransforms "+" mark
# tracks -> color "+" mark "+" stroke "+" strokeWidth "+" style "+" text
# tracks -> dataTransforms "+" mark "+" size "+" x "+" xe
# views -> alignment "+" layout "+" static "+" tracks
# tracks -> alignment "+" color "+" data "+" height "+" row "+" stroke "+" strokeWidth "+" text "+" title "+" tracks "+" width "+" x
# data -> genomicFieldsToConvert "+" headerNames "+" separator "+" type "+" url
# geneLabelOpacity -> value
# views -> layout "+" spacing "+" tracks "+" xOffset
# views -> arrangement "+" views
# color -> domain "+" field "+" legend "+" type
# tracks -> color "+" data "+" height "+" mark "+" stretch "+" style "+" text "+" width "+" x "+" xe "+" y
# textAnchor -> "end"
# tracks -> color "+" data "+" height "+" mark "+" width "+" x "+" xe "+" y
# value[text] -> STRING
# geneLabelColor -> field "+" range
# tracks -> alignment "+" color "+" data "+" height "+" opacity "+" row "+" title "+" tracks "+" visibility "+" width
# tracks -> color "+" mark "+" size "+" stroke "+" strokeWidth
# stroke -> domain "+" field "+" type
# dataTransforms -> field "+" newField "+" replace "+" type
# attributesToFields -> ARRAY
# baseLabelColor -> field "+" type
# name -> field
# tracks -> alignment "+" data "+" height "+" mark "+" tracks "+" width "+" x "+" y
# flipY -> "False"
# tracks -> alignment "+" color "+" data "+" height "+" size "+" stroke "+" strokeWidth "+" tracks "+" width "+" x "+" xe
# x -> aggregate "+" field "+" type
# tracks -> alignment "+" data "+" height "+" mark "+" row "+" style "+" title "+" tooltip "+" tracks "+" width
# views -> alignment "+" color "+" data "+" height "+" layout "+" row "+" tracks "+" width "+" x "+" xDomain "+" xe "+" y
# tracks -> alignment "+" color "+" data "+" height "+" row "+" stroke "+" strokeWidth "+" text "+" tracks "+" width "+" x
# tracks -> dataTransforms "+" mark "+" stroke "+" strokeWidth "+" x "+" x1 "+" x1e "+" xe
# root -> arrangement "+" linkingId "+" responsiveSize "+" responsiveSpec "+" views
# tracks -> color "+" data "+" dataTransforms "+" height "+" mark "+" opacity "+" overlayOnPreviousTrack "+" size "+" width "+" x "+" xe
# dataTransforms -> fields "+" newField "+" separator "+" type
# tracks -> color "+" dataTransforms "+" mark "+" x
# tracks -> dataTransforms "+" mark "+" size "+" style "+" x
# views -> alignment "+" color "+" data "+" height "+" layout "+" style "+" text "+" tracks "+" width "+" x "+" xDomain
# strandColor -> field "+" range
# style -> inlineLegend
# tracks -> color "+" data "+" mark "+" opacity "+" stroke "+" strokeWidth "+" x "+" xe "+" y "+" ye
# type[encoding] -> field
# views -> orientation "+" views "+" yOffset
# stainLabelColor -> field
# root -> arrangement "+" spacing "+" style "+" subtitle "+" title "+" views
# root -> layout "+" title "+" tracks
# select -> arrange "+" color "+" stroke "+" strokeWidth
# tracks -> dataTransforms "+" mark
# tracks -> dataTransforms "+" mark "+" strokeWidth "+" x "+" xe
# range[geneLabelColor] -> ARRAY
# type[barLength] -> "quantitative"
# views -> alignment "+" centerRadius "+" linkingId "+" tracks "+" xDomain
# data -> attributesToFields "+" indexUrl "+" type "+" url
# tracks -> data "+" height "+" mark "+" opacity "+" style "+" width "+" x "+" y
# geneLabel -> field
# root -> arrangement "+" linkingId "+" spacing "+" style "+" subtitle "+" title "+" views "+" xDomain
# textFontWeight -> "bold"
# style -> mouseOver "+" select
# tracks -> color "+" mark "+" xe
# geneHeight -> value
# tracks -> alignment "+" data "+" height "+" title "+" tracks "+" width "+" x "+" xe
# tracks -> color "+" data "+" dataTransforms "+" mark "+" opacity "+" stroke "+" strokeWidth "+" x "+" xe
# tracks -> dataTransforms "+" mark "+" stroke "+" strokeWidth "+" x "+" xe
# tracks -> color "+" mark "+" text "+" y
# select -> color "+" opacity
# start -> STRING
# responsiveSize -> width
# tracks -> color "+" data "+" height "+" id "+" mark "+" style "+" width "+" x "+" xe "+" y "+" ye
# tracks -> alignment "+" color "+" data "+" height "+" layout "+" row "+" tracks "+" width "+" x "+" y
# root -> responsiveSpec "+" spacing "+" style "+" views
# experimental -> mouseEvents
# geneLabelStrokeThickness -> value
# geneLabelStroke -> value
# views -> spacing "+" tracks "+" xOffset
# inlineLegend -> "True"
# maxRows -> NUMBER
# data -> indexUrl "+" type "+" url
# views -> alignment "+" color "+" data "+" height "+" opacity "+" row "+" title "+" tracks "+" visibility "+" width
# views -> alignment "+" height "+" style "+" tracks "+" width
# root -> spacing "+" style "+" subtitle "+" title "+" views "+" xDomain
# views -> alignment "+" data "+" height "+" row "+" size "+" stroke "+" strokeWidth "+" tracks "+" visibility "+" width
# mouseEvents -> groupMarksByField "+" mouseOver "+" rangeSelect
# click -> "True"
# strokeWidth -> NUMBER
# tracks -> mark "+" y
# tracks -> color "+" dataTransforms "+" mark "+" text "+" visibility
# tracks -> data "+" height "+" layout "+" mark "+" size "+" width "+" x "+" xe "+" y
# tracks -> color "+" data "+" dataTransforms "+" mark "+" row "+" size "+" stroke "+" strokeWidth "+" style "+" title "+" x
# select -> color "+" opacity "+" strokeWidth
# tracks -> alignment "+" color "+" data "+" dataTransforms "+" height "+" style "+" title "+" tracks "+" width "+" x "+" xe
# tracks -> color "+" data "+" dataTransforms "+" height "+" mark "+" size "+" stroke "+" strokeWidth "+" style "+" width "+" x "+" xe
# responsiveSpec -> ARRAY
# value[geneHeight] -> NUMBER
# arrange -> "behind"
# type[startPosition] -> "genomic"
# tracks -> color "+" dataTransforms "+" mark "+" stroke "+" strokeWidth "+" x "+" xe
# tracks -> alignment "+" data "+" height "+" row "+" title "+" tracks "+" width "+" x
# tracks -> color "+" data "+" dataTransforms "+" mark "+" opacity "+" row "+" size "+" visibility "+" x "+" xe
# tracks -> color "+" data "+" height "+" id "+" mark "+" stroke "+" strokeWidth "+" width "+" x "+" xe "+" y
# root -> subtitle "+" title "+" tracks
# boundingBox -> endField "+" startField
# tracks -> data "+" encoding "+" height "+" template "+" width
# baseBackground -> field "+" type
# mouseOver -> color "+" opacity "+" strokeWidth
# type[position] -> "genomic"
# views -> linkingId "+" spacing "+" tracks "+" xDomain
# customFields -> ARRAY
# tracks -> color "+" dataTransforms "+" mark "+" text "+" x "+" xe
# data -> chromosomeField "+" chromosomePrefix "+" genomicFields "+" headerNames "+" longToWideId "+" sampleLength "+" separator "+" type "+" url
# tracks -> alignment "+" data "+" height "+" mark "+" style "+" title "+" tracks "+" width
# tracks -> color "+" data "+" height "+" mark "+" row "+" stroke "+" strokeWidth "+" style "+" width "+" x "+" xe "+" y
# tracks -> alignment "+" color "+" data "+" dataTransforms "+" height "+" style "+" text "+" title "+" tracks "+" width "+" x "+" xe
# tracks -> color "+" data "+" dataTransforms "+" mark "+" opacity "+" row "+" style "+" text "+" visibility "+" x "+" xe
# tracks -> color "+" mark "+" stroke "+" strokeWidth "+" text "+" visibility
# tracks -> color "+" data "+" dataTransforms "+" mark "+" opacity "+" row "+" strokeWidth "+" style "+" visibility "+" x "+" xe
# tracks -> dataTransforms "+" mark "+" size "+" style "+" text "+" visibility
# strandRow -> field
# tracks -> style "+" title "+" type
# root -> style "+" title "+" views
# style -> enableSmoothPath
# root -> assembly "+" subtitle "+" title "+" views "+" xDomain "+" zoomLimits
# tracks -> color "+" data "+" height "+" mark "+" row "+" style "+" width "+" x "+" xe
# value[geneLabelStrokeThickness] -> NUMBER
# tracks -> mark "+" opacity "+" x "+" y
# value[geneLabelStroke] -> STRING
# tracks -> color "+" data "+" dataTransforms "+" height "+" mark "+" style "+" text "+" title "+" width "+" x "+" xe
# data -> genomicFields "+" sampleLength "+" type "+" url
# tracks -> alignment "+" color "+" data "+" height "+" opacity "+" size "+" stroke "+" strokeWidth "+" style "+" title "+" tooltip "+" tracks "+" width
# root -> arrangement "+" linkingId "+" responsiveSize "+" responsiveSpec "+" views "+" xDomain
# groupMarksByField -> STRING
# x1 -> axis "+" domain "+" field "+" type
# tracks -> data "+" height "+" layout "+" mark "+" stroke "+" width "+" x "+" x1 "+" x1e "+" xe
# dataTransforms -> field "+" include "+" type
# tracks -> mark "+" size "+" stroke "+" strokeWidth
# tracks -> color "+" data "+" height "+" mark "+" title "+" width "+" x "+" xe "+" y
# dataTransforms -> field "+" inRange "+" type
# mouseOver -> arrange "+" color "+" stroke "+" strokeWidth
# tracks -> color "+" dataTransforms "+" mark "+" size "+" visibility "+" x "+" xe
# endPosition -> field "+" type
# tracks -> color "+" data "+" dataTransforms "+" mark "+" row "+" size "+" stroke "+" strokeWidth "+" style "+" x
# tracks -> color "+" data "+" height "+" id "+" mark "+" stroke "+" strokeWidth "+" style "+" title "+" width "+" x "+" xe "+" y
# tracks -> alignment "+" color "+" data "+" experimental "+" height "+" row "+" stroke "+" strokeWidth "+" text "+" title "+" tracks "+" width "+" x
# tracks -> color "+" mark "+" stroke "+" strokeWidth
# root -> centerRadius "+" layout "+" spacing "+" static "+" subtitle "+" title "+" tracks "+" xDomain
# tracks -> color "+" dataTransforms "+" mark "+" strokeWidth "+" x "+" xe
# position -> field "+" type
# tracks -> color "+" mark "+" opacity "+" strokeWidth "+" text "+" visibility "+" xe
# mark -> "betweenLink"
# views -> orientation "+" spacing "+" tracks "+" yOffset
# xe -> aggregate "+" field "+" type
# views -> alignment "+" color "+" data "+" height "+" row "+" title "+" tracks "+" visibility "+" width
# root -> arrangement "+" centerRadius "+" layout "+" static "+" subtitle "+" title "+" views
# value[geneLabelFontSize] -> NUMBER
# tracks -> color "+" mark "+" opacity "+" strokeWidth "+" x
# aggregate -> "min"
# value[geneLabelOpacity] -> NUMBER
# color -> STRING
# endPosition -> field
# tracks -> color "+" data "+" experimental "+" height "+" mark "+" style "+" title "+" tooltip "+" width "+" x "+" xe "+" y
# tracks -> alignment "+" color "+" data "+" height "+" row "+" title "+" tracks "+" width
# tracks -> dataTransforms "+" mark "+" size "+" x
# height -> "False"
# views -> arrangement "+" spacing "+" views
# tracks -> size "+" visibility
# type[tracks] -> "dummy-track"
# tracks -> alignment "+" data "+" experimental "+" height "+" size "+" stroke "+" strokeWidth "+" style "+" title "+" tooltip "+" tracks "+" width "+" x "+" xe
# encoding -> barLength "+" baseBackground "+" baseLabelColor "+" endPosition "+" position "+" startPosition
# tracks -> color "+" data "+" mark "+" x "+" xe "+" y
# tracks -> visibility "+" xe
# style -> backgroundOpacity
# data -> binSize "+" categories "+" column "+" end "+" row "+" start "+" type "+" url "+" value
# style -> matrixExtent
# tracks -> color "+" data "+" height "+" mark "+" opacity "+" stroke "+" strokeWidth "+" style "+" title "+" width "+" x "+" xe
# root -> assembly "+" description "+" style "+" views "+" xDomain "+" zoomLimits
# rangeSelect -> "True"
# tracks -> color "+" data "+" dataTransforms "+" height "+" mark "+" style "+" title "+" width "+" x "+" xe
# opacity -> NUMBER
# tracks -> alignment "+" color "+" data "+" height "+" style "+" text "+" title "+" tracks "+" width "+" x
# tracks -> color "+" data "+" mark "+" strokeWidth "+" y
# views -> alignment "+" data "+" height "+" row "+" size "+" title "+" tracks "+" visibility "+" width
# root -> alignment "+" centerRadius "+" layout "+" spacing "+" static "+" title "+" tracks
# data -> categories "+" column "+" end "+" row "+" start "+" type "+" url "+" value
# tracks -> color "+" dataTransforms "+" x "+" xe
# flag -> field "+" value
# tracks -> mark "+" x "+" y
# views -> alignment "+" color "+" data "+" height "+" opacity "+" row "+" tracks "+" visibility "+" width "+" xDomain
# type[dataTransforms] -> "subjson"
# assembly -> ARRAY
# root -> centerRadius "+" spacing "+" style "+" subtitle "+" title "+" views "+" xDomain
# tracks -> mark
# tracks -> color "+" data "+" dataTransforms "+" height "+" id "+" mark "+" opacity "+" tooltip "+" width "+" x "+" y
# enableSmoothPath -> "True"
# replace -> ARRAY
# tracks -> color "+" data "+" flipY "+" height "+" mark "+" opacity "+" size "+" stroke "+" style "+" width "+" x "+" xe
# type[dataTransforms] -> "exonSplit"
# value[flag] -> STRING
# views -> views
# encoding -> endPosition "+" geneHeight "+" geneLabel "+" geneLabelColor "+" geneLabelFontSize "+" geneLabelOpacity "+" geneLabelStroke "+" geneLabelStrokeThickness "+" opacity "+" startPosition "+" strandColor "+" strandRow "+" type
# barLength -> field "+" type
# experimental -> stretchGraphics
# tracks -> alignment "+" color "+" data "+" height "+" opacity "+" size "+" stroke "+" style "+" title "+" tracks "+" width
# views -> height "+" tracks "+" width
# tracks -> alignment "+" color "+" data "+" height "+" stroke "+" strokeWidth "+" style "+" title "+" tracks "+" width "+" x "+" xe
# tracks -> alignment "+" color "+" data "+" dataTransforms "+" height "+" opacity "+" row "+" stroke "+" strokeWidth "+" style "+" tracks "+" width "+" x "+" xe
# stretchGraphics -> "True"
# tracks -> color "+" data "+" height "+" mark "+" stroke "+" strokeWidth "+" width "+" x "+" xe
# tracks -> color "+" dataTransforms "+" mark "+" style "+" x
# tracks -> color "+" data "+" height "+" mark "+" width "+" x "+" y
# data -> chromosomeField "+" genomicFields "+" sampleLength "+" type "+" url
# tracks -> color "+" data "+" dataTransforms "+" height "+" mark "+" opacity "+" stroke "+" strokeWidth "+" width "+" x "+" xe
# tracks ->
# tracks -> color "+" data "+" height "+" layout "+" mark "+" row "+" stroke "+" strokeWidth "+" width "+" x "+" y
# views -> spacing "+" tracks
# tracks -> color "+" mark "+" opacity "+" strokeWidth "+" style
# method -> "spread"
# tracks -> color "+" dataTransforms "+" mark "+" x "+" xe
# data -> binSize "+" column "+" type "+" url "+" value
# root -> title "+" tracks
# tracks -> color "+" mark "+" opacity "+" size "+" stroke "+" strokeWidth "+" visibility "+" x "+" y
# type[endPosition] -> "genomic"
# tracks -> color "+" dataTransforms "+" mark "+" size
# boundingBox -> endField "+" padding "+" startField
# tracks -> color "+" data "+" height "+" mark "+" stroke "+" strokeWidth "+" width "+" x "+" xe "+" y
# color -> domain "+" field "+" type
# tracks -> color "+" data "+" height "+" mark "+" row "+" width "+" x "+" y
# tracks -> alignment "+" color "+" data "+" height "+" row "+" title "+" tracks "+" visibility "+" width
# tracks -> mark "+" opacity "+" row "+" size "+" visibility "+" x
# encoding -> endPosition "+" name "+" stainBackgroundColor "+" stainLabelColor "+" stainStroke "+" startPosition
# tracks -> color "+" data "+" dataTransforms "+" height "+" mark "+" opacity "+" row "+" stroke "+" strokeWidth "+" style "+" title "+" width "+" x "+" xe
# tracks -> color "+" data "+" dataTransforms "+" height "+" mark "+" opacity "+" stroke "+" strokeWidth "+" style "+" title "+" width "+" x "+" xe
# views -> arrangement "+" spacing "+" style "+" views
# views -> layout "+" linkingId "+" tracks "+" xDomain
# views -> orientation "+" spacing "+" tracks "+" xDomain "+" yOffset
# style -> background "+" outlineWidth
# startPosition -> field "+" type
# tracks -> color "+" data "+" mark "+" style "+" x "+" xe "+" y "+" ye
# tracks -> color "+" mark "+" stroke "+" strokeWidth "+" visibility "+" x "+" xe
# row -> domain "+" field "+" legend "+" type
# views -> alignment "+" color "+" data "+" height "+" layout "+" row "+" spacing "+" static "+" tracks "+" width "+" x "+" xDomain "+" xe "+" y
# root -> arrangement "+" layout "+" subtitle "+" title "+" views "+" xDomain
# width -> "True"
# style -> textFontWeight
# tracks -> alignment "+" color "+" data "+" height "+" id "+" opacity "+" row "+" style "+" tracks "+" visibility "+" width
# yOffset -> NUMBER
# tracks -> color "+" data "+" mark "+" opacity "+" size "+" stroke "+" strokeWidth "+" x "+" xe "+" y "+" ye
# type[data] -> "gff"
# zoomLimits -> ARRAY
# tracks -> alignment "+" color "+" data "+" height "+" layout "+" opacity "+" tracks "+" width "+" x "+" xe "+" y
# views -> linkingId "+" spacing "+" tracks
# dataTransforms -> boundingBox "+" method "+" newField "+" type
# stainBackgroundColor -> field
# dataTransforms -> fields "+" flag "+" separator "+" type
# type[dataTransforms] -> "replace"
# tracks -> color "+" mark "+" size
# tracks -> color "+" mark "+" x
# tracks -> color "+" mark "+" size "+" visibility "+" x "+" xe
# template -> STRING
# tracks -> data "+" dataTransforms "+" height "+" mark "+" opacity "+" stroke "+" strokeWidth "+" width "+" x "+" x1 "+" x1e "+" xe
# style -> dy "+" outline
# tracks -> color "+" dataTransforms "+" mark "+" opacity "+" strokeWidth "+" style "+" x "+" xe
# end -> STRING
# range[strandColor] -> ARRAY
# tracks -> alignment "+" data "+" height "+" size "+" stroke "+" strokeWidth "+" style "+" tracks "+" visibility "+" width "+" x "+" xe
# geneLabelFontSize -> value
# type[dataTransforms] -> "filter"
# tracks -> color "+" data "+" height "+" mark "+" row "+" width "+" x "+" xe
# tracks -> alignment "+" color "+" data "+" height "+" style "+" text "+" tracks "+" width "+" x
# dataTransforms -> field "+" oneOf "+" type
# mouseEvents -> click "+" groupMarksByField "+" mouseOver "+" rangeSelect
# style -> brush "+" mouseOver "+" select
# views -> tracks "+" xDomain
# tracks -> color "+" data "+" height "+" mark "+" row "+" stroke "+" strokeWidth "+" text "+" width "+" x

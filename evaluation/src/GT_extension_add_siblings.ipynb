# %% [raw]
# Part 1 from V1

# %%
import pandas as pd
from IPython.display import display_html, HTML

def display_images_with_text_below(df):
    html = """<table border='1' style='border-collapse: collapse; text-align: center;'>
              <tr><th>Query Image</th><th>Groundtruth Image</th></tr>"""

    for _, row in df.iterrows():
        html += "<tr>"

        # Query image and text below
        html += f"""
            <td>
                <img src="{row['image']}" style="width:300px;"><br>
                <div style="padding: 4px; word-break: break-word;">{row['query']}</div>
            </td>
        """

        # Groundtruth image and text below
        html += f"""
            <td>
                <img src="{row['image_original']}" style="width:300px;"><br>
                <div style="padding: 4px; word-break: break-word;">{row['GT_extended']}</div>
            </td>
        """

        html += "</tr>"

    html += "</table>"
    display_html(HTML(html))

# Load the TSV
df = pd.read_csv('query_GT_p1.tsv', sep='\t')

# Construct full image paths
df['image'] = '../data/test_suite/imgs/' + df['query'] + '.png'
df['image_original'] = '../data/unified/imgs/' + df['GT_extended'] + '.png'

# Display
display_images_with_text_below(df)
# Out:
# <table border='1' style='border-collapse: collapse; text-align: center;'>
#               <tr><th>Query Image</th><th>Groundtruth Image</th></tr><tr>
#             <td>
#                 <img src="../data/test_suite/imgs/AREA_sw_0_7_s_0_7_cc_0_query.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">AREA_sw_0_7_s_0_7_cc_0_query</div>
#             </td>
#
#             <td>
#                 <img src="../data/unified/imgs/AREA_sw_1_0_s_1_0_cc_0.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">AREA_sw_1_0_s_1_0_cc_0</div>
#             </td>
#         </tr><tr>
#             <td>
#                 <img src="../data/test_suite/imgs/AREA_sw_0_7_s_0_7_cc_0_query.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">AREA_sw_0_7_s_0_7_cc_0_query</div>
#             </td>
#
#             <td>
#                 <img src="../data/unified/imgs/AREA_sw_1_2_s_1_0_cc_0.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">AREA_sw_1_2_s_1_0_cc_0</div>
#             </td>
#         </tr><tr>
#             <td>
#                 <img src="../data/test_suite/imgs/AREA_sw_0_7_s_0_7_cc_0_query.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">AREA_sw_0_7_s_0_7_cc_0_query</div>
#             </td>
#
#             <td>
#                 <img src="../data/unified/imgs/AREA_sw_0_7_s_1_0_cc_0.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">AREA_sw_0_7_s_1_0_cc_0</div>
#             </td>
#         </tr><tr>
#             <td>
#                 <img src="../data/test_suite/imgs/AREA_sw_0_7_s_0_7_cc_0_query.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">AREA_sw_0_7_s_0_7_cc_0_query</div>
#             </td>
#
#             <td>
#                 <img src="../data/unified/imgs/AREA_sw_1_0_s_1_2_cc_0.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">AREA_sw_1_0_s_1_2_cc_0</div>
#             </td>
#         </tr><tr>
#             <td>
#                 <img src="../data/test_suite/imgs/AREA_sw_0_7_s_0_7_cc_0_query.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">AREA_sw_0_7_s_0_7_cc_0_query</div>
#             </td>
#
#             <td>
#                 <img src="../data/unified/imgs/AREA_sw_1_2_s_0_7_cc_0.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">AREA_sw_1_2_s_0_7_cc_0</div>
#             </td>
#         </tr><tr>
#             <td>
#                 <img src="../data/test_suite/imgs/AREA_sw_0_7_s_0_7_cc_0_query.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">AREA_sw_0_7_s_0_7_cc_0_query</div>
#             </td>
#
#             <td>
#                 <img src="../data/unified/imgs/AREA_sw_0_7_s_0_7_cc_0.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">AREA_sw_0_7_s_0_7_cc_0</div>
#             </td>
#         </tr><tr>
#             <td>
#                 <img src="../data/test_suite/imgs/AREA_sw_0_7_s_0_7_cc_0_query.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">AREA_sw_0_7_s_0_7_cc_0_query</div>
#             </td>
#
#             <td>
#                 <img src="../data/unified/imgs/AREA_sw_0_7_s_1_2_cc_0.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">AREA_sw_0_7_s_1_2_cc_0</div>
#             </td>
#         </tr><tr>
#             <td>
#                 <img src="../data/test_suite/imgs/AREA_sw_0_7_s_0_7_cc_0_query.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">AREA_sw_0_7_s_0_7_cc_0_query</div>
#             </td>
#
#             <td>
#                 <img src="../data/unified/imgs/AREA_sw_1_0_s_0_7_cc_0.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">AREA_sw_1_0_s_0_7_cc_0</div>
#             </td>
#         </tr><tr>
#             <td>
#                 <img src="../data/test_suite/imgs/AREA_sw_0_7_s_0_7_cc_0_query.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">AREA_sw_0_7_s_0_7_cc_0_query</div>
#             </td>
#
#             <td>
#                 <img src="../data/unified/imgs/AREA_sw_1_2_s_1_2_cc_0.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">AREA_sw_1_2_s_1_2_cc_0</div>
#             </td>
#         </tr><tr>
#             <td>
#                 <img src="../data/test_suite/imgs/AREA_sw_0_7_s_1_0_cc_1_query.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">AREA_sw_0_7_s_1_0_cc_1_query</div>
#             </td>
#
#             <td>
#                 <img src="../data/unified/imgs/AREA_sw_1_0_s_0_7_cc_1.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">AREA_sw_1_0_s_0_7_cc_1</div>
#             </td>
#         </tr><tr>
#             <td>
#                 <img src="../data/test_suite/imgs/AREA_sw_0_7_s_1_0_cc_1_query.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">AREA_sw_0_7_s_1_0_cc_1_query</div>
#             </td>
#
#             <td>
#                 <img src="../data/unified/imgs/AREA_sw_1_2_s_1_2_cc_1.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">AREA_sw_1_2_s_1_2_cc_1</div>
#             </td>
#         </tr><tr>
#             <td>
#                 <img src="../data/test_suite/imgs/AREA_sw_0_7_s_1_0_cc_1_query.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">AREA_sw_0_7_s_1_0_cc_1_query</div>
#             </td>
#
#             <td>
#                 <img src="../data/unified/imgs/AREA_sw_0_7_s_1_2_cc_1.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">AREA_sw_0_7_s_1_2_cc_1</div>
#             </td>
#         </tr><tr>
#             <td>
#                 <img src="../data/test_suite/imgs/AREA_sw_0_7_s_1_0_cc_1_query.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">AREA_sw_0_7_s_1_0_cc_1_query</div>
#             </td>
#
#             <td>
#                 <img src="../data/unified/imgs/AREA_sw_0_7_s_0_7_cc_1.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">AREA_sw_0_7_s_0_7_cc_1</div>
#             </td>
#         </tr><tr>
#             <td>
#                 <img src="../data/test_suite/imgs/AREA_sw_0_7_s_1_0_cc_1_query.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">AREA_sw_0_7_s_1_0_cc_1_query</div>
#             </td>
#
#             <td>
#                 <img src="../data/unified/imgs/AREA_sw_1_2_s_1_0_cc_1.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">AREA_sw_1_2_s_1_0_cc_1</div>
#             </td>
#         </tr><tr>
#             <td>
#                 <img src="../data/test_suite/imgs/AREA_sw_0_7_s_1_0_cc_1_query.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">AREA_sw_0_7_s_1_0_cc_1_query</div>
#             </td>
#
#             <td>
#                 <img src="../data/unified/imgs/AREA_sw_1_2_s_0_7_cc_1.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">AREA_sw_1_2_s_0_7_cc_1</div>
#             </td>
#         </tr><tr>
#             <td>
#                 <img src="../data/test_suite/imgs/AREA_sw_0_7_s_1_0_cc_1_query.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">AREA_sw_0_7_s_1_0_cc_1_query</div>
#             </td>

# %%
import os
import pandas as pd

# Load TSV file
df = pd.read_csv("combined_output.tsv", sep="\t")

# Folder A and array B
folder_A = "../data/unified/imgs/"
array_B = ['EX_SPEC_ALIGNMENT_CHART']  # Example: 'a' is the prefix in your case

# Get base filenames (no extensions)
files_in_A = [os.path.splitext(f)[0] for f in os.listdir(folder_A) if os.path.isfile(os.path.join(folder_A, f))]

# Get used combinations of (query, GT_extended) to avoid repeating
used_pairs = set(zip(df["query"].astype(str), df["gt_extended"].astype(str)))

new_rows = []

for _, row in df.iterrows():
    Q = str(row["query"])
    if "_sw" not in Q:
        continue

    X = Q.split("_sw")[0]

    if X in array_B:
        # Find matching files with prefix X
        for file_base in files_in_A:
            if file_base.startswith(X) and (Q, file_base) not in used_pairs:
                new_rows.append({
                    "query": Q,
                    "gt_extended": file_base
                })
                used_pairs.add((Q, file_base))  # Avoid duplicate pair

                # Convert to DataFrame
new_df = pd.DataFrame(new_rows)

# Optional: print or save
new_df.to_csv("addition1.tsv", sep="\t", index=False)
print(new_df)

# %% [markdown]
# Add siblings

# %%
import pandas as pd

# Load both TSV files
df1 = pd.read_csv("query_groundtruth_v1_fit.tsv", sep="\t")
df2 = pd.read_csv("query_groundtruth_v2.tsv", sep="\t")

# Concatenate them
combined_df = pd.concat([df1, df2], ignore_index=True)

# Sort by the "query" field
combined_df = combined_df.sort_values(by="query")

# Optional: save the result
combined_df.to_csv("query_GT_p1_v0.tsv", sep="\t", index=False)

print(combined_df)
# Out:
#                                           query  \
# 0                  AREA_sw_0_7_s_0_7_cc_0_query
# 1                  AREA_sw_0_7_s_0_7_cc_0_query
# 2                  AREA_sw_0_7_s_0_7_cc_0_query
# 3                  AREA_sw_0_7_s_0_7_cc_0_query
# 4                  AREA_sw_0_7_s_0_7_cc_0_query
# ...                                         ...
# 1311  viridis-heatmap_p_0_sw_1_2_s_1_0_oc_query
# 1312  viridis-heatmap_p_0_sw_1_2_s_1_0_oc_query
# 1313  viridis-heatmap_p_0_sw_1_2_s_1_0_oc_query
# 1314  viridis-heatmap_p_0_sw_1_2_s_1_0_oc_query
# 1315                                        NaN
#
#                               GT_extended
# 0                  AREA_sw_1_0_s_1_0_cc_0
# 1                  AREA_sw_1_2_s_1_0_cc_0
# 2                  AREA_sw_0_7_s_1_0_cc_0
# 3                  AREA_sw_1_0_s_1_2_cc_0
# 4                  AREA_sw_1_2_s_0_7_cc_0
# ...                                   ...
# 1311  viridis-heatmap_p_0_sw_1_0_s_1_2_oc
# 1312  viridis-heatmap_p_0_sw_1_2_s_0_7_oc
# 1313  viridis-heatmap_p_0_sw_0_7_s_1_2_oc
# 1314  viridis-heatmap_p_0_sw_1_0_s_1_0_oc
# 1315                                  NaN
#
# [1607 rows x 2 columns]

# %%
def remove_empty_rows(input_file, output_file):
    with open(input_file, 'r', encoding='utf-8') as infile, \
         open(output_file, 'w', encoding='utf-8') as outfile:
        
        # Iterate over each line in the input file
        for line in infile:
            # Strip whitespace; only write non-empty lines to the output file
            if line.strip():
                outfile.write(line)

# Usage
input_tsv = 'query_GT_p1_v0.tsv'
output_tsv = 'query_GT_p1.tsv'
remove_empty_rows(input_tsv, output_tsv)

# %%
import os
import pandas as pd

# Load TSV file
df = pd.read_csv("combined_output.tsv", sep="\t")

# Folder A and array B
folder_A = "../data/unified/imgs/"
array_B = ['EX_SPEC_ALIGNMENT_CHART']  # Example: 'a' is the prefix in your case

# Get base filenames (no extensions)
files_in_A = [os.path.splitext(f)[0] for f in os.listdir(folder_A) if os.path.isfile(os.path.join(folder_A, f))]

# Get used combinations of (query, GT_extended) to avoid repeating
used_pairs = set(zip(df["query"].astype(str), df["gt_extended"].astype(str)))

new_rows = []

for _, row in df.iterrows():
    Q = str(row["query"])
    if "_sw" not in Q:
        continue

    X = Q.split("_sw")[0]

    if X in array_B:
        # Find matching files with prefix X
        for file_base in files_in_A:
            if file_base.startswith(X) and (Q, file_base) not in used_pairs:
                new_rows.append({
                    "query": Q,
                    "gt_extended": file_base
                })
                used_pairs.add((Q, file_base))  # Avoid duplicate pair

                # Convert to DataFrame
new_df = pd.DataFrame(new_rows)

# Save to TSV
# new_df.to_csv("addition1.tsv", sep="\t", index=False)
print(new_df)
# Out:
#                                              query  \
# 0   EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_1_0_oc_query1
# 1   EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_1_0_oc_query1
# 2   EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_1_0_oc_query1
# 3   EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_1_0_oc_query1
# 4   EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_1_0_oc_query1
# 5   EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_1_0_oc_query1
# 6   EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_1_0_oc_query1
# 7   EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_1_0_oc_query1
# 8   EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_1_0_oc_query1
# 9   EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_1_0_oc_query1
# 10  EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_1_0_oc_query1
# 11  EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_1_0_oc_query1
# 12  EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_1_0_oc_query1
# 13  EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_1_0_oc_query1
# 14  EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_1_0_oc_query1
# 15  EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_1_0_oc_query1
# 16  EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_1_0_oc_query1
# 17  EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_1_0_oc_query1
# 18  EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_1_0_oc_query1
# 19  EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_1_0_oc_query1
# 20  EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_1_0_oc_query1
# 21  EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_1_0_oc_query1
# 22  EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_1_0_oc_query1
# 23  EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_1_0_oc_query1
# 24  EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_1_0_oc_query1
# 25  EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_1_0_oc_query1
# 26  EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_1_0_oc_query1
# 27  EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_1_0_oc_query2
# 28  EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_1_0_oc_query2
# 29  EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_1_0_oc_query2
# 30  EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_1_0_oc_query2
# 31  EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_1_0_oc_query2
# 32  EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_1_0_oc_query2
# 33  EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_1_0_oc_query2
# 34  EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_1_0_oc_query2
# 35  EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_1_0_oc_query2
# 36  EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_1_0_oc_query2
# 37  EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_1_0_oc_query2
# 38  EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_1_0_oc_query2
# 39  EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_1_0_oc_query2
# 40  EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_1_0_oc_query2
# 41  EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_1_0_oc_query2
# 42  EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_1_0_oc_query2
# 43  EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_1_0_oc_query2
# 44  EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_1_0_oc_query2
# 45  EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_1_0_oc_query2
# 46  EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_1_0_oc_query2
# 47  EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_1_0_oc_query2
# 48  EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_1_0_oc_query2
# 49  EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_1_0_oc_query2
# 50  EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_1_0_oc_query2
# 51  EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_1_0_oc_query2
# 52  EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_1_0_oc_query2
# 53  EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_1_0_oc_query2
#
#                                   gt_extended
# 0   EX_SPEC_ALIGNMENT_CHART_sw_0_7_s_1_2_cc_1
# 1   EX_SPEC_ALIGNMENT_CHART_sw_0_7_s_1_2_cc_0
# 2   EX_SPEC_ALIGNMENT_CHART_sw_0_7_s_1_2_cc_2
# 3   EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_0_7_cc_0
# 4   EX_SPEC_ALIGNMENT_CHART_sw_1_2_s_1_2_cc_0
# 5   EX_SPEC_ALIGNMENT_CHART_sw_1_2_s_1_2_cc_1
# 6   EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_0_7_cc_1
# 7   EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_0_7_cc_2
# 8   EX_SPEC_ALIGNMENT_CHART_sw_1_2_s_1_2_cc_2
# 9   EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_1_2_cc_2
# 10  EX_SPEC_ALIGNMENT_CHART_sw_1_2_s_0_7_cc_2
# 11  EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_1_2_cc_0
# 12  EX_SPEC_ALIGNMENT_CHART_sw_1_2_s_0_7_cc_0
# 13  EX_SPEC_ALIGNMENT_CHART_sw_1_2_s_0_7_cc_1
# 14  EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_1_2_cc_1
# 15  EX_SPEC_ALIGNMENT_CHART_sw_0_7_s_0_7_cc_2
# 16  EX_SPEC_ALIGNMENT_CHART_sw_0_7_s_0_7_cc_1
# 17  EX_SPEC_ALIGNMENT_CHART_sw_0_7_s_0_7_cc_0
# 18  EX_SPEC_ALIGNMENT_CHART_sw_1_2_s_1_0_cc_2
# 19  EX_SPEC_ALIGNMENT_CHART_sw_1_2_s_1_0_cc_0
# 20  EX_SPEC_ALIGNMENT_CHART_sw_1_2_s_1_0_cc_1
# 21  EX_SPEC_ALIGNMENT_CHART_sw_0_7_s_1_0_cc_2
# 22  EX_SPEC_ALIGNMENT_CHART_sw_0_7_s_1_0_cc_1
# 23  EX_SPEC_ALIGNMENT_CHART_sw_0_7_s_1_0_cc_0
# 24  EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_1_0_cc_0
# 25  EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_1_0_cc_1
# 26  EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_1_0_cc_2
# 27  EX_SPEC_ALIGNMENT_CHART_sw_0_7_s_1_2_cc_1
# 28  EX_SPEC_ALIGNMENT_CHART_sw_0_7_s_1_2_cc_0
# 29  EX_SPEC_ALIGNMENT_CHART_sw_0_7_s_1_2_cc_2
# 30  EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_0_7_cc_0
# 31  EX_SPEC_ALIGNMENT_CHART_sw_1_2_s_1_2_cc_0
# 32  EX_SPEC_ALIGNMENT_CHART_sw_1_2_s_1_2_cc_1
# 33  EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_0_7_cc_1
# 34  EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_0_7_cc_2
# 35  EX_SPEC_ALIGNMENT_CHART_sw_1_2_s_1_2_cc_2
# 36  EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_1_2_cc_2
# 37  EX_SPEC_ALIGNMENT_CHART_sw_1_2_s_0_7_cc_2
# 38  EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_1_2_cc_0
# 39  EX_SPEC_ALIGNMENT_CHART_sw_1_2_s_0_7_cc_0
# 40  EX_SPEC_ALIGNMENT_CHART_sw_1_2_s_0_7_cc_1
# 41  EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_1_2_cc_1
# 42  EX_SPEC_ALIGNMENT_CHART_sw_0_7_s_0_7_cc_2
# 43  EX_SPEC_ALIGNMENT_CHART_sw_0_7_s_0_7_cc_1
# 44  EX_SPEC_ALIGNMENT_CHART_sw_0_7_s_0_7_cc_0
# 45  EX_SPEC_ALIGNMENT_CHART_sw_1_2_s_1_0_cc_2
# 46  EX_SPEC_ALIGNMENT_CHART_sw_1_2_s_1_0_cc_0
# 47  EX_SPEC_ALIGNMENT_CHART_sw_1_2_s_1_0_cc_1
# 48  EX_SPEC_ALIGNMENT_CHART_sw_0_7_s_1_0_cc_2
# 49  EX_SPEC_ALIGNMENT_CHART_sw_0_7_s_1_0_cc_1
# 50  EX_SPEC_ALIGNMENT_CHART_sw_0_7_s_1_0_cc_0
# 51  EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_1_0_cc_0
# 52  EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_1_0_cc_1
# 53  EX_SPEC_ALIGNMENT_CHART_sw_1_0_s_1_0_cc_2

# %%
import os
import pandas as pd

# Load TSV file
df = pd.read_csv("combined_output.tsv", sep="\t")

# Folder A path
folder_A = "../data/unified/imgs/"

# Prefixes and suffixes to match
prefixes = ["hi-c-matrix"]  # Update as needed
suffixes = ["oc"]

# Collect base filenames in folder A that start with a prefix and end with a suffix (before extension)
set_A = []
for f in os.listdir(folder_A):
    if not os.path.isfile(os.path.join(folder_A, f)):
        continue
    base, _ = os.path.splitext(f)
    if any(base.startswith(p) for p in prefixes) and any(base.endswith(s) for s in suffixes):
        set_A.append(base)

# Get used (query, gt_extended) combinations to avoid duplicates
used_pairs = set(zip(df["query"].astype(str), df["gt_extended"].astype(str)))

new_rows = []

for _, row in df.iterrows():
    Q = str(row["query"])
    if Q.startswith("EX_SPEC_MATRIX_sw_0_7_s_0_7_oc_query"):
        for file_base in set_A:
            if (Q, file_base) not in used_pairs:
                new_rows.append({
                    "query": Q,
                    "gt_extended": file_base
                })
                used_pairs.add((Q, file_base))

# Convert to DataFrame
new_df = pd.DataFrame(new_rows)

# Save to TSV
# new_df.to_csv("addition4.tsv", sep="\t", index=False)
print(new_df)
# Out:
#                                     query                          gt_extended
# 0   EX_SPEC_MATRIX_sw_0_7_s_0_7_oc_query1  hi-c-matrix-alt_p_0_sw_1_2_s_1_0_oc
# 1   EX_SPEC_MATRIX_sw_0_7_s_0_7_oc_query1      hi-c-matrix_p_0_sw_0_7_s_1_0_oc
# 2   EX_SPEC_MATRIX_sw_0_7_s_0_7_oc_query1      hi-c-matrix_p_0_sw_1_0_s_1_2_oc
# 3   EX_SPEC_MATRIX_sw_0_7_s_0_7_oc_query1  hi-c-matrix-alt_p_0_sw_0_7_s_0_7_oc
# 4   EX_SPEC_MATRIX_sw_0_7_s_0_7_oc_query1      hi-c-matrix_p_0_sw_1_2_s_0_7_oc
# 5   EX_SPEC_MATRIX_sw_0_7_s_0_7_oc_query1  hi-c-matrix-alt_p_0_sw_1_0_s_0_7_oc
# 6   EX_SPEC_MATRIX_sw_0_7_s_0_7_oc_query1      hi-c-matrix_p_0_sw_0_7_s_1_2_oc
# 7   EX_SPEC_MATRIX_sw_0_7_s_0_7_oc_query1  hi-c-matrix-alt_p_0_sw_1_2_s_1_2_oc
# 8   EX_SPEC_MATRIX_sw_0_7_s_0_7_oc_query1      hi-c-matrix_p_0_sw_1_0_s_1_0_oc
# 9   EX_SPEC_MATRIX_sw_0_7_s_0_7_oc_query1      hi-c-matrix_p_0_sw_0_7_s_0_7_oc
# 10  EX_SPEC_MATRIX_sw_0_7_s_0_7_oc_query1  hi-c-matrix-alt_p_0_sw_1_2_s_0_7_oc
# 11  EX_SPEC_MATRIX_sw_0_7_s_0_7_oc_query1  hi-c-matrix-alt_p_0_sw_1_0_s_1_2_oc
# 12  EX_SPEC_MATRIX_sw_0_7_s_0_7_oc_query1      hi-c-matrix_p_0_sw_1_2_s_1_0_oc
# 13  EX_SPEC_MATRIX_sw_0_7_s_0_7_oc_query1  hi-c-matrix-alt_p_0_sw_0_7_s_1_0_oc
# 14  EX_SPEC_MATRIX_sw_0_7_s_0_7_oc_query1  hi-c-matrix-alt_p_0_sw_1_0_s_1_0_oc
# 15  EX_SPEC_MATRIX_sw_0_7_s_0_7_oc_query1  hi-c-matrix-alt_p_0_sw_0_7_s_1_2_oc
# 16  EX_SPEC_MATRIX_sw_0_7_s_0_7_oc_query1      hi-c-matrix_p_0_sw_1_2_s_1_2_oc
# 17  EX_SPEC_MATRIX_sw_0_7_s_0_7_oc_query1      hi-c-matrix_p_0_sw_1_0_s_0_7_oc
# 18  EX_SPEC_MATRIX_sw_0_7_s_0_7_oc_query2  hi-c-matrix-alt_p_0_sw_1_2_s_1_0_oc
# 19  EX_SPEC_MATRIX_sw_0_7_s_0_7_oc_query2      hi-c-matrix_p_0_sw_0_7_s_1_0_oc
# 20  EX_SPEC_MATRIX_sw_0_7_s_0_7_oc_query2      hi-c-matrix_p_0_sw_1_0_s_1_2_oc
# 21  EX_SPEC_MATRIX_sw_0_7_s_0_7_oc_query2  hi-c-matrix-alt_p_0_sw_0_7_s_0_7_oc
# 22  EX_SPEC_MATRIX_sw_0_7_s_0_7_oc_query2      hi-c-matrix_p_0_sw_1_2_s_0_7_oc
# 23  EX_SPEC_MATRIX_sw_0_7_s_0_7_oc_query2  hi-c-matrix-alt_p_0_sw_1_0_s_0_7_oc
# 24  EX_SPEC_MATRIX_sw_0_7_s_0_7_oc_query2      hi-c-matrix_p_0_sw_0_7_s_1_2_oc
# 25  EX_SPEC_MATRIX_sw_0_7_s_0_7_oc_query2  hi-c-matrix-alt_p_0_sw_1_2_s_1_2_oc
# 26  EX_SPEC_MATRIX_sw_0_7_s_0_7_oc_query2      hi-c-matrix_p_0_sw_1_0_s_1_0_oc
# 27  EX_SPEC_MATRIX_sw_0_7_s_0_7_oc_query2      hi-c-matrix_p_0_sw_0_7_s_0_7_oc
# 28  EX_SPEC_MATRIX_sw_0_7_s_0_7_oc_query2  hi-c-matrix-alt_p_0_sw_1_2_s_0_7_oc
# 29  EX_SPEC_MATRIX_sw_0_7_s_0_7_oc_query2  hi-c-matrix-alt_p_0_sw_1_0_s_1_2_oc
# 30  EX_SPEC_MATRIX_sw_0_7_s_0_7_oc_query2      hi-c-matrix_p_0_sw_1_2_s_1_0_oc
# 31  EX_SPEC_MATRIX_sw_0_7_s_0_7_oc_query2  hi-c-matrix-alt_p_0_sw_0_7_s_1_0_oc
# 32  EX_SPEC_MATRIX_sw_0_7_s_0_7_oc_query2  hi-c-matrix-alt_p_0_sw_1_0_s_1_0_oc
# 33  EX_SPEC_MATRIX_sw_0_7_s_0_7_oc_query2  hi-c-matrix-alt_p_0_sw_0_7_s_1_2_oc
# 34  EX_SPEC_MATRIX_sw_0_7_s_0_7_oc_query2      hi-c-matrix_p_0_sw_1_2_s_1_2_oc
# 35  EX_SPEC_MATRIX_sw_0_7_s_0_7_oc_query2      hi-c-matrix_p_0_sw_1_0_s_0_7_oc

# %%
import pandas as pd
from IPython.display import display_html, HTML

def display_images_with_text_below(df):
    html = """<table border='1' style='border-collapse: collapse; text-align: center;'>
              <tr><th>Query Image</th><th>Groundtruth Image</th></tr>"""

    for _, row in df.iterrows():
        html += "<tr>"

        # Query image and text below
        html += f"""
            <td>
                <img src="{row['query']}" style="width:300px;"><br>
                <div style="padding: 4px; word-break: break-word;">{row['query']}</div>
            </td>
        """

        html += "</tr>"

    html += "</table>"
    display_html(HTML(html))

# Load the TSV
df = pd.read_csv('unmatched_queries.tsv', sep='\t')

# Construct full image paths
df['query'] = '../data/test_suite/imgs/' + df['query'] + '.png'

# Display
display_images_with_text_below(df)
# Out:
# <table border='1' style='border-collapse: collapse; text-align: center;'>
#               <tr><th>Query Image</th><th>Groundtruth Image</th></tr><tr>
#             <td>
#                 <img src="../data/test_suite/imgs/EX_SPEC_CANCER_VARIANT_PROTOTYPE_sw_1_0_s_1_2_query1.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">../data/test_suite/imgs/EX_SPEC_CANCER_VARIANT_PROTOTYPE_sw_1_0_s_1_2_query1.png</div>
#             </td>
#         </tr><tr>
#             <td>
#                 <img src="../data/test_suite/imgs/EX_SPEC_CANCER_VARIANT_PROTOTYPE_sw_1_0_s_1_2_query2.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">../data/test_suite/imgs/EX_SPEC_CANCER_VARIANT_PROTOTYPE_sw_1_0_s_1_2_query2.png</div>
#             </td>
#         </tr><tr>
#             <td>
#                 <img src="../data/test_suite/imgs/EX_SPEC_CYTOBANDS_sw_1_2_s_1_2_oc_circular_query.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">../data/test_suite/imgs/EX_SPEC_CYTOBANDS_sw_1_2_s_1_2_oc_circular_query.png</div>
#             </td>
#         </tr><tr>
#             <td>
#                 <img src="../data/test_suite/imgs/EX_SPEC_GIVE_sw_1_0_s_1_0_query1.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">../data/test_suite/imgs/EX_SPEC_GIVE_sw_1_0_s_1_0_query1.png</div>
#             </td>
#         </tr><tr>
#             <td>
#                 <img src="../data/test_suite/imgs/EX_SPEC_GIVE_sw_1_0_s_1_0_query2.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">../data/test_suite/imgs/EX_SPEC_GIVE_sw_1_0_s_1_0_query2.png</div>
#             </td>
#         </tr><tr>
#             <td>
#                 <img src="../data/test_suite/imgs/EX_SPEC_MATRIX_HFFC6_sw_1_0_s_1_0_hot_query1.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">../data/test_suite/imgs/EX_SPEC_MATRIX_HFFC6_sw_1_0_s_1_0_hot_query1.png</div>
#             </td>
#         </tr><tr>
#             <td>
#                 <img src="../data/test_suite/imgs/EX_SPEC_MATRIX_HFFC6_sw_1_0_s_1_0_hot_query2.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">../data/test_suite/imgs/EX_SPEC_MATRIX_HFFC6_sw_1_0_s_1_0_hot_query2.png</div>
#             </td>
#         </tr><tr>
#             <td>
#                 <img src="../data/test_suite/imgs/EX_SPEC_MATRIX_HFFC6_sw_1_2_s_1_2_recolor_query1.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">../data/test_suite/imgs/EX_SPEC_MATRIX_HFFC6_sw_1_2_s_1_2_recolor_query1.png</div>
#             </td>
#         </tr><tr>
#             <td>
#                 <img src="../data/test_suite/imgs/EX_SPEC_MATRIX_HFFC6_sw_1_2_s_1_2_recolor_query2.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">../data/test_suite/imgs/EX_SPEC_MATRIX_HFFC6_sw_1_2_s_1_2_recolor_query2.png</div>
#             </td>
#         </tr><tr>
#             <td>
#                 <img src="../data/test_suite/imgs/EX_SPEC_MATRIX_sw_0_7_s_0_7_oc_bupu_query1.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">../data/test_suite/imgs/EX_SPEC_MATRIX_sw_0_7_s_0_7_oc_bupu_query1.png</div>
#             </td>
#         </tr><tr>
#             <td>
#                 <img src="../data/test_suite/imgs/EX_SPEC_MATRIX_sw_0_7_s_0_7_oc_bupu_query2.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">../data/test_suite/imgs/EX_SPEC_MATRIX_sw_0_7_s_0_7_oc_bupu_query2.png</div>
#             </td>
#         </tr><tr>
#             <td>
#                 <img src="../data/test_suite/imgs/EX_SPEC_MATRIX_sw_0_7_s_0_7_oc_viridis_query1.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">../data/test_suite/imgs/EX_SPEC_MATRIX_sw_0_7_s_0_7_oc_viridis_query1.png</div>
#             </td>
#         </tr><tr>
#             <td>
#                 <img src="../data/test_suite/imgs/EX_SPEC_MATRIX_sw_0_7_s_0_7_oc_viridis_query2.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">../data/test_suite/imgs/EX_SPEC_MATRIX_sw_0_7_s_0_7_oc_viridis_query2.png</div>
#             </td>
#         </tr><tr>
#             <td>
#                 <img src="../data/test_suite/imgs/breast_cancer_circular_s_2_0_oc_query.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">../data/test_suite/imgs/breast_cancer_circular_s_2_0_oc_query.png</div>
#             </td>
#         </tr><tr>
#             <td>
#                 <img src="../data/test_suite/imgs/circulars_p_3_cc_0_query1.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">../data/test_suite/imgs/circulars_p_3_cc_0_query1.png</div>
#             </td>
#         </tr><tr>
#             <td>
#                 <img src="../data/test_suite/imgs/circulars_p_3_cc_0_query2.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">../data/test_suite/imgs/circulars_p_3_cc_0_query2.png</div>
#             </td>
#         </tr><tr>
#             <td>
#                 <img src="../data/test_suite/imgs/circulars_p_3_cc_0_query3.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">../data/test_suite/imgs/circulars_p_3_cc_0_query3.png</div>
#             </td>
#         </tr><tr>
#             <td>
#                 <img src="../data/test_suite/imgs/circulars_p_3_cc_0_query4.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">../data/test_suite/imgs/circulars_p_3_cc_0_query4.png</div>
#             </td>
#         </tr><tr>
#             <td>
#                 <img src="../data/test_suite/imgs/circulars_p_4_oc_query1.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">../data/test_suite/imgs/circulars_p_4_oc_query1.png</div>
#             </td>
#         </tr><tr>
#             <td>
#                 <img src="../data/test_suite/imgs/circulars_p_4_oc_query2.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">../data/test_suite/imgs/circulars_p_4_oc_query2.png</div>
#             </td>
#         </tr><tr>
#             <td>
#                 <img src="../data/test_suite/imgs/circulars_p_4_oc_query3.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">../data/test_suite/imgs/circulars_p_4_oc_query3.png</div>
#             </td>
#         </tr><tr>
#             <td>
#                 <img src="../data/test_suite/imgs/gene_annotation_p_4_sw_1_0_s_1_0_query1.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">../data/test_suite/imgs/gene_annotation_p_4_sw_1_0_s_1_0_query1.png</div>
#             </td>
#         </tr><tr>
#             <td>
#                 <img src="../data/test_suite/imgs/gene_annotation_p_4_sw_1_0_s_1_0_query2.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">../data/test_suite/imgs/gene_annotation_p_4_sw_1_0_s_1_0_query2.png</div>
#             </td>
#         </tr><tr>
#             <td>
#                 <img src="../data/test_suite/imgs/gene_annotation_p_4_sw_1_0_s_1_0_query3.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">../data/test_suite/imgs/gene_annotation_p_4_sw_1_0_s_1_0_query3.png</div>
#             </td>
#         </tr><tr>
#             <td>
#                 <img src="../data/test_suite/imgs/gene_annotation_p_4_sw_1_0_s_1_0_query4.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">../data/test_suite/imgs/gene_annotation_p_4_sw_1_0_s_1_0_query4.png</div>
#             </td>
#         </tr><tr>
#             <td>
#                 <img src="../data/test

# %%
import pandas as pd
from IPython.display import display_html, HTML

def display_images_with_text_below(df):
    html = """<table border='1' style='border-collapse: collapse; text-align: center;'>
              <tr><th>Query Image</th><th>Groundtruth Image</th></tr>"""

    for _, row in df.iterrows():
        html += "<tr>"

        # Query image and text below
        html += f"""
            <td>
                <img src="{row['image']}" style="width:300px;"><br>
                <div style="padding: 4px; word-break: break-word;">{row['query']}</div>
            </td>
        """

        # Groundtruth image and text below
        html += f"""
            <td>
                <img src="{row['image_original']}" style="width:300px;"><br>
                <div style="padding: 4px; word-break: break-word;">{row['gt_extended']}</div>
            </td>
        """

        html += "</tr>"

    html += "</table>"
    display_html(HTML(html))

# Load the TSV
df = pd.read_csv('addition3.tsv', sep='\t')

# Construct full image paths
df['image'] = '../data/test_suite/imgs/' + df['query'] + '.png'
df['image_original'] = '../data/unified/imgs/' + df['gt_extended'] + '.png'

# Display
display_images_with_text_below(df)
# Out:
# <table border='1' style='border-collapse: collapse; text-align: center;'>
#               <tr><th>Query Image</th><th>Groundtruth Image</th></tr><tr>
#             <td>
#                 <img src="../data/test_suite/imgs/EX_SPEC_MATRIX_sw_0_7_s_0_7_cc_1_query1.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">EX_SPEC_MATRIX_sw_0_7_s_0_7_cc_1_query1</div>
#             </td>
#
#             <td>
#                 <img src="../data/unified/imgs/hi-c-matrix_p_0_sw_0_7_s_1_0_cc_1.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">hi-c-matrix_p_0_sw_0_7_s_1_0_cc_1</div>
#             </td>
#         </tr><tr>
#             <td>
#                 <img src="../data/test_suite/imgs/EX_SPEC_MATRIX_sw_0_7_s_0_7_cc_1_query1.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">EX_SPEC_MATRIX_sw_0_7_s_0_7_cc_1_query1</div>
#             </td>
#
#             <td>
#                 <img src="../data/unified/imgs/hi-c-matrix_p_0_sw_0_7_s_1_0_cc_0.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">hi-c-matrix_p_0_sw_0_7_s_1_0_cc_0</div>
#             </td>
#         </tr><tr>
#             <td>
#                 <img src="../data/test_suite/imgs/EX_SPEC_MATRIX_sw_0_7_s_0_7_cc_1_query1.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">EX_SPEC_MATRIX_sw_0_7_s_0_7_cc_1_query1</div>
#             </td>
#
#             <td>
#                 <img src="../data/unified/imgs/hi-c-matrix_p_0_sw_0_7_s_1_0_cc_2.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">hi-c-matrix_p_0_sw_0_7_s_1_0_cc_2</div>
#             </td>
#         </tr><tr>
#             <td>
#                 <img src="../data/test_suite/imgs/EX_SPEC_MATRIX_sw_0_7_s_0_7_cc_1_query1.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">EX_SPEC_MATRIX_sw_0_7_s_0_7_cc_1_query1</div>
#             </td>
#
#             <td>
#                 <img src="../data/unified/imgs/hi-c-matrix_p_0_sw_1_2_s_1_0_cc_0.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">hi-c-matrix_p_0_sw_1_2_s_1_0_cc_0</div>
#             </td>
#         </tr><tr>
#             <td>
#                 <img src="../data/test_suite/imgs/EX_SPEC_MATRIX_sw_0_7_s_0_7_cc_1_query1.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">EX_SPEC_MATRIX_sw_0_7_s_0_7_cc_1_query1</div>
#             </td>
#
#             <td>
#                 <img src="../data/unified/imgs/hi-c-matrix_p_0_sw_1_2_s_1_0_cc_1.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">hi-c-matrix_p_0_sw_1_2_s_1_0_cc_1</div>
#             </td>
#         </tr><tr>
#             <td>
#                 <img src="../data/test_suite/imgs/EX_SPEC_MATRIX_sw_0_7_s_0_7_cc_1_query1.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">EX_SPEC_MATRIX_sw_0_7_s_0_7_cc_1_query1</div>
#             </td>
#
#             <td>
#                 <img src="../data/unified/imgs/hi-c-matrix_p_0_sw_1_2_s_1_0_cc_2.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">hi-c-matrix_p_0_sw_1_2_s_1_0_cc_2</div>
#             </td>
#         </tr><tr>
#             <td>
#                 <img src="../data/test_suite/imgs/EX_SPEC_MATRIX_sw_0_7_s_0_7_cc_1_query1.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">EX_SPEC_MATRIX_sw_0_7_s_0_7_cc_1_query1</div>
#             </td>
#
#             <td>
#                 <img src="../data/unified/imgs/hi-c-matrix_p_0_sw_1_0_s_1_0_cc_2.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">hi-c-matrix_p_0_sw_1_0_s_1_0_cc_2</div>
#             </td>
#         </tr><tr>
#             <td>
#                 <img src="../data/test_suite/imgs/EX_SPEC_MATRIX_sw_0_7_s_0_7_cc_1_query1.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">EX_SPEC_MATRIX_sw_0_7_s_0_7_cc_1_query1</div>
#             </td>
#
#             <td>
#                 <img src="../data/unified/imgs/hi-c-matrix_p_0_sw_1_0_s_1_0_cc_0.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">hi-c-matrix_p_0_sw_1_0_s_1_0_cc_0</div>
#             </td>
#         </tr><tr>
#             <td>
#                 <img src="../data/test_suite/imgs/EX_SPEC_MATRIX_sw_0_7_s_0_7_cc_1_query1.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">EX_SPEC_MATRIX_sw_0_7_s_0_7_cc_1_query1</div>
#             </td>
#
#             <td>
#                 <img src="../data/unified/imgs/hi-c-matrix_p_0_sw_1_0_s_1_0_cc_1.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">hi-c-matrix_p_0_sw_1_0_s_1_0_cc_1</div>
#             </td>
#         </tr><tr>
#             <td>
#                 <img src="../data/test_suite/imgs/EX_SPEC_MATRIX_sw_0_7_s_0_7_cc_1_query1.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">EX_SPEC_MATRIX_sw_0_7_s_0_7_cc_1_query1</div>
#             </td>
#
#             <td>
#                 <img src="../data/unified/imgs/EX_SPEC_MATRIX_sw_0_7_s_0_7_cc_0.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">EX_SPEC_MATRIX_sw_0_7_s_0_7_cc_0</div>
#             </td>
#         </tr><tr>
#             <td>
#                 <img src="../data/test_suite/imgs/EX_SPEC_MATRIX_sw_0_7_s_0_7_cc_1_query1.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">EX_SPEC_MATRIX_sw_0_7_s_0_7_cc_1_query1</div>
#             </td>
#
#             <td>
#                 <img src="../data/unified/imgs/EX_SPEC_MATRIX_sw_0_7_s_0_7_cc_2.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">EX_SPEC_MATRIX_sw_0_7_s_0_7_cc_2</div>
#             </td>
#         </tr><tr>
#             <td>
#                 <img src="../data/test_suite/imgs/EX_SPEC_MATRIX_sw_0_7_s_0_7_cc_1_query1.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">EX_SPEC_MATRIX_sw_0_7_s_0_7_cc_1_query1</div>
#             </td>
#
#             <td>
#                 <img src="../data/unified/imgs/hi-c-matrix_p_0_sw_1_2_s_1_2_cc_2.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">hi-c-matrix_p_0_sw_1_2_s_1_2_cc_2</div>
#             </td>
#         </tr><tr>
#             <td>
#                 <img src="../data/test_suite/imgs/EX_SPEC_MATRIX_sw_0_7_s_0_7_cc_1_query1.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">EX_SPEC_MATRIX_sw_0_7_s_0_7_cc_1_query1</div>
#             </td>
#
#             <td>
#                 <img src="../data/unified/imgs/hi-c-matrix_p_0_sw_1_0_s_0_7_cc_2.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">hi-c-matrix_p_0_sw_1_0_s_0_7_cc_2</div>
#             </td>
#         </tr><tr>
#             <td>
#                 <img src="../data/test_suite/imgs/EX_SPEC_MATRIX_sw_0_7_s_0_7_cc_1_query1.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">EX_SPEC_MATRIX_sw_0_7_s_0_7_cc_1_query1</div>
#             </td>
#
#             <td>
#                 <img src="../data/unified/imgs/hi-c-matrix_p_0_sw_1_2_s_1_2_cc_0.png" style="width:300px;"><br>
#                 <div style="padding: 4px; word-break: break-word;">hi-c-matrix_p_0_sw_1_2_s_1_2_cc_0</div>
#             </td>
#         </tr><tr>
#             <td>
#                 <img src="../data/test_suite/imgs/EX_SPEC_MATRIX_sw_0_7_s_0_7_cc_1_query1.png" style="width:300px;"><br>
#                 <d

# %%
import pandas as pd
import glob

# Path to your TSV files (adjust the pattern as needed)
tsv_files = glob.glob("components/*.tsv")

# Read and combine all TSV files
all_dfs = []
for file in tsv_files:
    df = pd.read_csv(file, sep='\t', header=None)  # no header assumed
    df = df.dropna(how='all')  # remove completely empty rows
    all_dfs.append(df)

# Concatenate all dataframes
combined_df = pd.concat(all_dfs, ignore_index=True)

# Keep only the first two columns
combined_df = combined_df.iloc[:, :2]
combined_df.columns = ['query', 'gt_extended']

# Optional: drop rows with missing query or gt_extended
combined_df = combined_df.dropna(subset=['query', 'gt_extended'])

# Save or display result
combined_df.to_csv("combined_output.tsv", sep='\t', index=False)
